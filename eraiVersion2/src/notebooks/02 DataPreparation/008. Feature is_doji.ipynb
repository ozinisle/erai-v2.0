# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "008_"
variation_degree=20
requiredMinimumCorrelation = .2
autoConfigFileRelativePath = '\\src\config\\autoConfig\\config.json'
KEY_preProcessedDataFilePath='preProcessedDataFilePath'

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData
from dataPreparation.resolveDataPatterns import getDojiFeatures

_basicDf,_variation_degree,_preProcessedDataFilePath,_autoConfigData,_configFilePath = doBasicOperation(dataName,
       dataFrequency,autoConfigFileRelativePath,KEY_preProcessedDataFilePath,variation_degree)

print('done')
# Out:
# done
# into method doBasicOperation
# jupyterNodePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2
# configFilePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
#  retrieving values configured in >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
import pandas as pd
import numpy as np

featureOfInterest = 'is_bearish_or_bullish_Candle'

m = _basicDf.shape[0]

newFeatureDf = getDojiFeatures(_basicDf)

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf= prepareFeatureWithData(newFeatureDf,
            _basicDf,_variation_degree,_preProcessedDataFilePath,
            _configFilePath,requiredMinimumCorrelation,featureIndexStamp,
            dataName,dataFrequency,useVersion2=True)
# Out:
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['isDoji'][dojiDf['isDoji'] == False]=0
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['isDoji'][dojiDf['isDoji'] == True]=1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDoji'][dojiDf['isDoji'] == 1]=100*(m-matches_isDoji.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDragonFlyDoji'][dojiDf['dragonFlyDoji'] == 1]=100*(m-matches_dragonFlyDoji.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDragonFlyDoji'][dojiDf['dragonFlyDoji'] == 0]=100*(m-matches_not_dragonFlyDoji.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByGraveStoneDoji'][dojiDf['graveStoneDoji'] == 1]=100*(m-matches_graveStoneDoji.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByGraveStoneDoji'][dojiDf['graveStoneDoji'] == 0]=100*(m-matches_not_graveStoneDoji.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['dragonFlyDoji'][(dojiDf['isDoji']==1) & (dojiDf['open']==dojiDf['high'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['graveStoneDoji'][(dojiDf['isDoji']==1) & (dojiDf['open']==dojiDf['low'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['dojiTrend'][dojiDf['isDoji']==1] = 0.1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['dojiTrend'][dojiDf['dragonFlyDoji']==1] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['dojiTrend'][dojiDf['graveStoneDoji']==1] = -1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:219: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDojiTrend'][dojiDf['dojiTrend'] == 0.1]=100*(m-matches_dojiTrend_mild.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:220: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDojiTrend'][dojiDf['dojiTrend'] == 1]=100*(m-matches_dojiTrend_postive.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDojiTrend'][dojiDf['dojiTrend'] == -1]=100*(m-matches_dojiTrend_negative.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dojiDf['scarcityByDojiTrend'][dojiDf['dojiTrend'] == 0]=100*(m-matches_not_dojiTrend.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py:433: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\preProcessedData
# outputFolderPath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features
# featuresFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures
# rawFeaturesFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\filteredFeatures
# filteredFeaturesFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\filteredFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations
# correlationsFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\reasonableCorrelations
# trainableFeaturesListtFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\filteredFeatures\008_isDoji_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures\008_isDoji_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\008_isDoji_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\reasonableCorrelations\008_isDoji_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\filteredFeatures\008_isDoji_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures\008_isDoji_variations_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\008_isDoji_variations_correlation_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\correlations\reasonableCorrelations\008_isDoji_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\features\rawFeatures\008_isDoji_variations_list.csv
# newTrainingSetDf shape>>>8350,700
# trainableFeaturesDf shape>>>8350,18
#  retrieving values configured in >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
# setAutoConfigData >>> configFilePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
#  updating config file >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
#  successfully updated config file >>> (try block) C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json with data >>>{"adani": {"1h": {"preProcessedDataFilePath": "C:\\Users\\kalagi01\\Desktop\\dev\\eraiVersion2\\data\\adani\\processed\\preProcessedData/processedRawData.csv", "trainableFeaturesListtFile": "C:\\Users\\kalagi01\\Desktop\\dev\\eraiVersion2\\data\\adani\\processed\\features\\filteredFeatures\\008_isDoji_trainableFeaturesList.csv", "redGreenCandleSizeBoundaries": [[-0.40000000000000213, 0.44999999999999574], [-0.25, 0.25], [-0.14999999999999858, 0.14999999999999858], [-0.09999999999999432, 0.05000000000000426]]}}}

# %%
_correlation.shape
# Out:
# (362, 700)

# %%
_reasonableCorelation
# Out:
#                                                     open      high       low  \
# open                                            1.000000  0.999541  0.999531
# high                                            0.999541  1.000000  0.999257
# low                                             0.999531  0.999257  1.000000
# close                                           0.999298  0.999678  0.999613
# magnitudeScarcityProductByDojiTrend_exp_inv_1  -0.717493 -0.715753 -0.719347
# magnitudeScarcityProductByDoji_exp_inv_1       -0.717497 -0.715757 -0.719351
# magnitudeScarcityProductByDojiTrend_exp_inv_2  -0.723427 -0.721948 -0.724814
# magnitudeScarcityProductByDoji_exp_inv_2       -0.723427 -0.721948 -0.724814
# magnitudeScarcityProductByDojiTrend_exp_inv_3  -0.627771 -0.626387 -0.629000
# magnitudeScarcityProductByDoji_exp_inv_3       -0.627771 -0.626387 -0.629000
# magnitudeScarcityProductByDojiTrend_exp_inv_4  -0.523593 -0.522307 -0.524710
# magnitudeScarcityProductByDoji_exp_inv_4       -0.523593 -0.522307 -0.524710
# magnitudeScarcityProductByDojiTrend_exp_inv_5  -0.437519 -0.436345 -0.438520
# magnitudeScarcityProductByDoji_exp_inv_5       -0.437519 -0.436345 -0.438520
# magnitudeScarcityProductByDojiTrend_exp_inv_6  -0.372790 -0.371728 -0.373674
# magnitudeScarcityProductByDojiTrend_exp_inv_7  -0.325298 -0.324341 -0.326072
# magnitudeScarcityProductByDojiTrend_exp_inv_8  -0.290203 -0.289340 -0.290879
# magnitudeScarcityProductByDojiTrend_exp_inv_9  -0.263709 -0.262927 -0.264299
# magnitudeScarcityProductByDojiTrend_exp_inv_10 -0.243175 -0.242461 -0.243693
# magnitudeScarcityProductByDojiTrend_exp_inv_11 -0.226835 -0.226180 -0.227293
# magnitudeScarcityProductByDojiTrend_exp_inv_12 -0.213522 -0.212917 -0.213930
# magnitudeScarcityProductByDojiTrend_exp_inv_13 -0.202455 -0.201891 -0.202822
#
#                                                    close    isDoji  \
# open                                            0.999298 -0.086922
# high                                            0.999678 -0.089604
# low                                             0.999613 -0.083769
# close                                           1.000000 -0.086654
# magnitudeScarcityProductByDojiTrend_exp_inv_1  -0.717602 -0.552470
# magnitudeScarcityProductByDoji_exp_inv_1       -0.717607 -0.552466
# magnitudeScarcityProductByDojiTrend_exp_inv_2  -0.723428 -0.353122
# magnitudeScarcityProductByDoji_exp_inv_2       -0.723428 -0.353122
# magnitudeScarcityProductByDojiTrend_exp_inv_3  -0.627729 -0.247031
# magnitudeScarcityProductByDoji_exp_inv_3       -0.627729 -0.247031
# magnitudeScarcityProductByDojiTrend_exp_inv_4  -0.523537 -0.177668
# magnitudeScarcityProductByDoji_exp_inv_4       -0.523537 -0.177668
# magnitudeScarcityProductByDojiTrend_exp_inv_5  -0.437460 -0.131969
# magnitudeScarcityProductByDoji_exp_inv_5       -0.437460 -0.131969
# magnitudeScarcityProductByDojiTrend_exp_inv_6  -0.372730 -0.102163
# magnitudeScarcityProductByDojiTrend_exp_inv_7  -0.325238 -0.082587
# magnitudeScarcityProductByDojiTrend_exp_inv_8  -0.290143 -0.069446
# magnitudeScarcityProductByDojiTrend_exp_inv_9  -0.263649 -0.060345
# magnitudeScarcityProductByDojiTrend_exp_inv_10 -0.243115 -0.053815
# magnitudeScarcityProductByDojiTrend_exp_inv_11 -0.226776 -0.048957
# magnitudeScarcityProductByDojiTrend_exp_inv_12 -0.213464 -0.045220
# magnitudeScarcityProductByDojiTrend_exp_inv_13 -0.202398 -0.042256
#
#                                                 dragonFlyDoji  graveStoneDoji  \
# open                                                -0.031033       -0.028118
# high                                                -0.032049       -0.028155
# low                                                 -0.030721       -0.026820
# close                                               -0.030994       -0.028071
# magnitudeScarcityProductByDojiTrend_exp_inv_1       -0.090705       -0.102670
# magnitudeScarcityProductByDoji_exp_inv_1            -0.090696       -0.102667
# magnitudeScarcityProductByDojiTrend_exp_inv_2       -0.057976       -0.065620
# magnitudeScarcityProductByDoji_exp_inv_2            -0.057976       -0.065620
# magnitudeScarcityProductByDojiTrend_exp_inv_3       -0.040558       -0.045905
# magnitudeScarcityProductByDoji_exp_inv_3            -0.040558       -0.045905
# magnitudeScarcityProductByDojiTrend_exp_inv_4       -0.029170       -0.033016
# magnitudeScarcityProductByDoji_exp_inv_4            -0.029170       -0.033016
# magnitudeScarcityProductByDojiTrend_exp_inv_5       -0.021667       -0.024523
# magnitudeScarcityProductByDoji_exp_inv_5            -0.021667       -0.024523
# magnitudeScarcityProductByDojiTrend_exp_inv_6       -0.016773       -0.018985
# magnitudeScarcityProductByDojiTrend_exp_inv_7       -0.013559       -0.015347
# magnitudeScarcityProductByDojiTrend_exp_inv_8       -0.011402       -0.012905
# magnitudeScarcityProductByDojiTrend_exp_inv_9       -0.009907       -0.011214
# magnitudeScarcityProductByDojiTrend_exp_inv_10      -0.008835       -0.010000
# magnitudeScarcityProductByDojiTrend_exp_inv_11      -0.008038       -0.009098
# magnitudeScarcityProductByDojiTrend_exp_inv_12      -0.007424       -0.008403
# magnitudeScarcityProductByDojiTrend_exp_inv_13      -0.006938       -0.007852
#
#                                                 dojiTrend  \
# open                                            -0.025380
# high                                            -0.026839
# low                                             -0.025131
# close                                           -0.025302
# magnitudeScarcityProductByDojiTrend_exp_inv_1   -0.160509
# magnitudeScarcityProductByDoji_exp_inv_1        -0.160505
# magnitudeScarcityProductByDojiTrend_exp_inv_2   -0.102596
# magnitudeScarcityProductByDoji_exp_inv_2        -0.102596
# magnitudeScarcityProductByDojiTrend_exp_inv_3   -0.071772
# magnitudeScarcityProductByDoji_exp_inv_3        -0.071772
# magnitudeScarcityProductByDojiTrend_exp_inv_4   -0.051620
# magnitudeScarcityProductByDoji_exp_inv_4        -0.051620
# magnitudeScarcityProductByDojiTrend_exp_inv_5   -0.038342
# magnitudeScarcityProductByDoji_exp_inv_5        -0.038342
# magnitudeScarcityProductByDojiTrend_exp_inv_6   -0.029682
# magnitudeScarcityProductByDojiTrend_exp_inv_7   -0.023995
# magnitudeScarcityProductByDojiTrend_exp_inv_8   -0.020177
# magnitudeScarcityProductByDojiTrend_exp_inv_9   -0.017533
# magnitudeScarcityProductByDojiTrend_exp_inv_10  -0.015635
# magnitudeScarcityProductByDojiTrend_exp_inv_11  -0.014224
# magnitudeScarcityProductByDojiTrend_exp_inv_12  -0.013138
# magnitudeScarcityProductByDojiTrend_exp_inv_13  -0.012277
#
#                                                 scarcityByDojiTrend  \
# open                                                      -0.087495
# high                                                      -0.090177
# low                                                       -0.084332
# close                                                     -0.087227
# magnitudeScarcityProductByDojiTrend_exp_inv_1             -0.552231
# magnitudeScarcityProductByDoji_exp_inv_1                  -0.552227
# magnitudeScarcityProductByDojiTrend_exp_inv_2             -0.352969
# magnitudeScarcityProductByDoji_exp_inv_2                  -0.352969
# magnitudeScarcityProductByDojiTrend_exp_inv_3             -0.246925
# magnitudeScarcityProductByDoji_exp_inv_3                  -0.246925
# magnitudeScarcityProductByDojiTrend_exp_inv_4             -0.177592
# magnitudeScarcityProductByDoji_exp_inv_4                  -0.177592
# magnitudeScarcityProductByDojiTrend_exp_inv_5             -0.131912
# magnitudeScarcityProductByDoji_exp_inv_5                  -0.131912
# magnitudeScarcityProductByDojiTrend_exp_inv_6             -0.102119
# magnitudeScarcityProductByDojiTrend_exp_inv_7             -0.082552
# magnitudeScarcityProductByDojiTrend_exp_inv_8             -0.069416
# magnitudeScarcityProductByDojiTrend_exp_inv_9             -0.060319
# magnitudeScarcityProductByDojiTrend_exp_inv_10            -0.053791
# magnitudeScarcityProductByDojiTrend_exp_inv_11            -0.048936
# magnitudeScarcityProductByDojiTrend_exp_inv_12            -0.045200
# magnitudeScarcityProductByDojiTrend_exp_inv_13            -0.042238
#
#                                                 magnitudeScarcityProductByDojiTrend  \
# open                                                                       0.130646
# high                                                                       0.127920
# low                                                                        0.133829
# close                                                                      0.130927
# magnitudeScarcityProductByDojiTrend_exp_inv_1                             -0.624573
# magnitudeScarcityProductByDoji_exp_inv_1                                  -0.624572
# magnitudeScarcityProductByDojiTrend_exp_inv_2                             -0.436241
# magnitudeScarcityProductByDoji_exp_inv_2                                  -0.436241
# magnitudeScarcityProductByDojiTrend_exp_inv_3                             -0.322199
# magnitudeScarcityProductByDoji_exp_inv_3                                  -0.322199
# magnitudeScarcityProductByDojiTrend_exp_inv_4                             -0.241813
# magnitudeScarcityProductByDoji_exp_inv_4                                  -0.241813
# magnitudeScarcityProductByDojiTrend_exp_inv_5                             -0.186412
# magnitudeScarcityProductByDoji_exp_inv_5                                  -0.186412
# magnitudeScarcityProductByDojiTrend_exp_inv_6                             -0.149077
# magnitudeScarcityProductByDojiTrend_exp_inv_7                             -0.123860
# magnitudeScarcityProductByDojiTrend_exp_inv_8                             -0.106481
# magnitudeScarcityProductByDojiTrend_exp_inv_9                             -0.094140
# magnitudeScarcityProductByDojiTrend_exp_inv_10                            -0.085071
# magnitudeScarcityProductByDojiTrend_exp_inv_11                            -0.078176
# magnitudeScarcityProductByDojiTrend_exp_inv_12                            -0.072768
# magnitudeScarcityProductByDojiTrend_exp_inv_13                            -0.068408
#
#                                                 ...  graveStoneDoji_pow_19  \
# open                                            ...              -0.028118
# high                                            ...              -0.028155
# low                                             ...              -0.026820
# close                                           ...              -0.028071
# magnitudeScarcityProductByDojiTrend_exp_inv_1   ...              -0.102670
# magnitudeScarcityProductByDoji_exp_inv_1        ...              -0.102667
# magnitudeScarcityProductByDojiTrend_exp_inv_2   ...              -0.065620
# magnitudeScarcityProductByDoji_exp_inv_2        ...              -0.065620
# magnitudeScarcityProductByDojiTrend_exp_inv_3   ...              -0.045905
# magnitudeScarcityProductByDoji_exp_inv_3        ...              -0.045905
# magnitudeScarcityProductByDojiTrend_exp_inv_4   ...              -0.033016
# magnitudeScarcityProductByDoji_exp_inv_4        ...              -0.033016
# magnitudeScarcityProductByDojiTrend_exp_inv_5   ...              -0.024523
# magnitudeScarcityProductByDoji_exp_inv_5        ...              -0.024523
# magnitudeScarcityProductByDojiTrend_exp_inv_6   ...              -0.018985
# magnitudeScarcityProductByDojiTrend_exp_inv_7   ...              -0.015347
# magnitudeScarcityProductByDojiTrend_exp_inv_8   ...              -0.012905
# magnitudeScarcityProductByDojiTrend_exp_inv_9   ...              -0.011214
# magnitudeScarcityProductByDojiTrend_exp_inv_10  ...              -0.010000
# magnitudeScarcityProductByDojiTrend_exp_inv_11  ...              -0.009098
# magnitudeScarcityProductByDojiTrend_exp_inv_12  ...              -0.008403
# magnitudeScarcityProductByDojiTrend_exp_inv_13  ...              -0.007852
#
#                                                 dojiTrend_pow_19  \
# open                                                    0.000506
# high                                                   -0.000138
# low                                                    -0.000258
# close                                                   0.000497
# magnitudeScarcityProductByDojiTrend_exp_inv_1           0.016800
# magnitudeScarcityProductByDoji_exp_inv_1                0.016804
# magnitudeScarcityProductByDojiTrend_exp_inv_2           0.010735
# magnitudeScarcityProductByDoji_exp_inv_2                0.010735
# magnitudeScarcityProductByDojiTrend_exp_inv_3           0.007510
# magnitudeScarcityProductByDoji_exp_inv_3                0.007510
# magnitudeScarcityProductByDojiTrend_exp_inv_4           0.005401
# magnitudeScarcityProductByDoji_exp_inv_4                0.005401
# magnitudeScarcityProductByDojiTrend_exp_inv_5           0.004012
# magnitudeScarcityProductByDoji_exp_inv_5                0.004012
# magnitudeScarcityProductByDojiTrend_exp_inv_6           0.003106
# magnitudeScarcityProductByDojiTrend_exp_inv_7           0.002511
# magnitudeScarcityProductByDojiTrend_exp_inv_8           0.002111
# magnitudeScarcityProductByDojiTrend_exp_inv_9           0.001835
# magnitudeScarcityProductByDojiTrend_exp_inv_10          0.001636
# magnitudeScarcityProductByDojiTrend_exp_inv_11          0.001488
# magnitudeScarcityProductByDojiTrend_exp_inv_12          0.001375
# magnitudeScarcityProductByDojiTrend_exp_inv_13          0.001285
#
#                                                 scarcityByDojiTrend_pow_19  \
# open                                                             -0.076270
# high                                                             -0.078202
# low                                                              -0.073750
# close                                                            -0.076084
# magnitudeScarcityProductByDojiTrend_exp_inv_1                    -0.391510
# magnitudeScarcityProductByDoji_exp_inv_1                         -0.391502
# magnitudeScarcityProductByDojiTrend_exp_inv_2                    -0.250239
# magnitudeScarcityProductByDoji_exp_inv_2                         -0.250239
# magnitudeScarcityProductByDojiTrend_exp_inv_3                    -0.175058
# magnitudeScarcityProductByDoji_exp_inv_3                         -0.175058
# magnitudeScarcityProductByDojiTrend_exp_inv_4                    -0.125904
# magnitudeScarcityProductByDoji_exp_inv_4                         -0.125904
# magnitudeScarcityProductByDojiTrend_exp_inv_5                    -0.093519
# magnitudeScarcityProductByDoji_exp_inv_5                         -0.093519
# magnitudeScarcityProductByDojiTrend_exp_inv_6                    -0.072397
# magnitudeScarcityProductByDojiTrend_exp_inv_7                    -0.058525
# magnitudeScarcityProductByDojiTrend_exp_inv_8                    -0.049213
# magnitudeScarcityProductByDojiTrend_exp_inv_9                    -0.042763
# magnitudeScarcityProductByDojiTrend_exp_inv_10                   -0.038136
# magnitudeScarcityProductByDojiTrend_exp_inv_11                   -0.034693
# magnitudeScarcityProductByDojiTrend_exp_inv_12                   -0.032045
# magnitudeScarcityProductByDojiTrend_exp_inv_13                   -0.029945
#
#                                                 magnitudeScarcityProductByDojiTrend_pow_19  \
# open                                                                              0.088654
# high                                                                              0.088123
# low                                                                               0.089226
# close                                                                             0.088710
# magnitudeScarcityProductByDojiTrend_exp_inv_1                                    -0.060208
# magnitudeScarcityProductByDoji_exp_inv_1                                         -0.060208
# magnitudeScarcityProductByDojiTrend_exp_inv_2                                    -0.038480
# magnitudeScarcityProductByDoji_exp_inv_2                                         -0.038480
# magnitudeScarcityProductByDojiTrend_exp_inv_3                                    -0.026919
# magnitudeScarcityProductByDoji_exp_inv_3                                         -0.026919
# magnitudeScarcityProductByDojiTrend_exp_inv_4                                    -0.019361
# magnitudeScarcityProductByDoji_exp_inv_4                                         -0.019361
# magnitudeScarcityProductByDojiTrend_exp_inv_5                                    -0.014381
# magnitudeScarcityProductByDoji_exp_inv_5                                         -0.014381
# magnitudeScarcityProductByDojiTrend_exp_inv_6                                    -0.011133
# magnitudeScarcityProductByDojiTrend_exp_inv_7                                    -0.009000
# magnitudeScarcityProductByDojiTrend_exp_inv_8                                    -0.007568
# magnitudeScarcityProductByDojiTrend_exp_inv_9                                    -0.006576
# magnitudeScarcityProductByDojiTrend_exp_inv_10                                   -0.005864
# magnitudeScarcityProductByDojiTrend_exp_inv_11                                   -0.005335
# magnitudeScarcityProductByDojiTrend_exp_inv_12                                   -0.004928
# magnitudeScarcityProductByDojiTrend_exp_inv_13                                   -0.004605
#
#                                                 scarcityByDoji_pow_19  \
# open                                                        -0.086922
# high                                                        -0.089604
# low                                                         -0.083769
# close                                                       -0.086654
# magnitudeScarcityProductByDojiTrend_exp_inv_1               -0.552470
# magnitudeScarcityProductByDoji_exp_inv_1                    -0.552466
# magnitudeScarcityProductByDojiTrend_exp_inv_2               -0.353122
# magnitudeScarcityProductByDoji_exp_inv_2                    -0.353122
# magnitudeScarcityProductByDojiTrend_exp_inv_3               -0.247031
# magnitudeScarcityProductByDoji_exp_inv_3                    -0.247031
# magnitudeScarcityProductByDojiTrend_exp_inv_4               -0.177668
# magnitudeScarcityProductByDoji_exp_inv_4                    -0.177668
# magnitudeScarcityProductByDojiTrend_exp_inv_5               -0.131969
# magnitudeScarcityProductByDoji_exp_inv_5                    -0.131969
# magnitudeScarcityProductByDojiTrend_exp_inv_6               -0.102163
# magnitudeScarcityProductByDojiTrend_exp_inv_7               -0.082587
# magnitudeScarcityProductByDojiTrend_exp_inv_8               -0.069446
# magnitudeScarcityProductByDojiTrend_exp_inv_9               -0.060345
# magnitudeScarcityProductByDojiTrend_exp_inv_10              -0.053815
# magnitudeScarcityProductByDojiTrend_exp_inv_11              -0.048957
# magnitudeScarcityProductByDojiTrend_exp_inv_12              -0.045220
# magnitudeScarcityProductByDojiTrend_exp_inv_13              -0.042256
#
#                                                 scarcityByDragonFlyDoji_pow_19  \
# open                                                                       NaN
# high                                                                       NaN
# low                                                                        NaN
# close                                                                      NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_1                              NaN
# magnitudeScarcityProductByDoji_exp_inv_1                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_2                              NaN
# magnitudeScarcityProductByDoji_exp_inv_2                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_3                              NaN
# magnitudeScarcityProductByDoji_exp_inv_3                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_4                              NaN
# magnitudeScarcityProductByDoji_exp_inv_4                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_5                              NaN
# magnitudeScarcityProductByDoji_exp_inv_5                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_6                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_7                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_8                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_9                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_10                             NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_11                             NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_12                             NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_13                             NaN
#
#                                                 scarcityByGraveStoneDoji_pow_19  \
# open                                                                        NaN
# high                                                                        NaN
# low                                                                         NaN
# close                                                                       NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_1                               NaN
# magnitudeScarcityProductByDoji_exp_inv_1                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_2                               NaN
# magnitudeScarcityProductByDoji_exp_inv_2                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_3                               NaN
# magnitudeScarcityProductByDoji_exp_inv_3                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_4                               NaN
# magnitudeScarcityProductByDoji_exp_inv_4                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_5                               NaN
# magnitudeScarcityProductByDoji_exp_inv_5                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_6                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_7                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_8                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_9                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_10                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_11                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_12                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_13                              NaN
#
#                                                 magnitudeScarcityProductByDoji_pow_19  \
# open                                                                         0.088021
# high                                                                         0.087465
# low                                                                          0.088575
# close                                                                        0.088075
# magnitudeScarcityProductByDojiTrend_exp_inv_1                               -0.059478
# magnitudeScarcityProductByDoji_exp_inv_1                                    -0.059478
# magnitudeScarcityProductByDojiTrend_exp_inv_2                               -0.038014
# magnitudeScarcityProductByDoji_exp_inv_2                                    -0.038014
# magnitudeScarcityProductByDojiTrend_exp_inv_3                               -0.026593
# magnitudeScarcityProductByDoji_exp_inv_3                                    -0.026593
# magnitudeScarcityProductByDojiTrend_exp_inv_4                               -0.019126
# magnitudeScarcityProductByDoji_exp_inv_4                                    -0.019126
# magnitudeScarcityProductByDojiTrend_exp_inv_5                               -0.014206
# magnitudeScarcityProductByDoji_exp_inv_5                                    -0.014206
# magnitudeScarcityProductByDojiTrend_exp_inv_6                               -0.010998
# magnitudeScarcityProductByDojiTrend_exp_inv_7                               -0.008891
# magnitudeScarcityProductByDojiTrend_exp_inv_8                               -0.007476
# magnitudeScarcityProductByDojiTrend_exp_inv_9                               -0.006496
# magnitudeScarcityProductByDojiTrend_exp_inv_10                              -0.005793
# magnitudeScarcityProductByDojiTrend_exp_inv_11                              -0.005270
# magnitudeScarcityProductByDojiTrend_exp_inv_12                              -0.004868
# magnitudeScarcityProductByDojiTrend_exp_inv_13                              -0.004549
#
#                                                 magnitudeScarcityProductByDragonFlyDoji_pow_19  \
# open                                                                                       NaN
# high                                                                                       NaN
# low                                                                                        NaN
# close                                                                                      NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_1                                              NaN
# magnitudeScarcityProductByDoji_exp_inv_1                                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_2                                              NaN
# magnitudeScarcityProductByDoji_exp_inv_2                                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_3                                              NaN
# magnitudeScarcityProductByDoji_exp_inv_3                                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_4                                              NaN
# magnitudeScarcityProductByDoji_exp_inv_4                                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_5                                              NaN
# magnitudeScarcityProductByDoji_exp_inv_5                                                   NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_6                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_7                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_8                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_9                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_10                                             NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_11                                             NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_12                                             NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_13                                             NaN
#
#                                                 magnitudeScarcityProductByGraveStoneDoji_pow_19
# open                                                                                        NaN
# high                                                                                        NaN
# low                                                                                         NaN
# close                                                                                       NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_1                                               NaN
# magnitudeScarcityProductByDoji_exp_inv_1                                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_2                                               NaN
# magnitudeScarcityProductByDoji_exp_inv_2                                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_3                                               NaN
# magnitudeScarcityProductByDoji_exp_inv_3                                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_4                                               NaN
# magnitudeScarcityProductByDoji_exp_inv_4                                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_5                                               NaN
# magnitudeScarcityProductByDoji_exp_inv_5                                                    NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_6                                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_7                                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_8                                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_9                                               NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_10                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_11                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_12                                              NaN
# magnitudeScarcityProductByDojiTrend_exp_inv_13                                              NaN
#
# [22 rows x 700 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)
