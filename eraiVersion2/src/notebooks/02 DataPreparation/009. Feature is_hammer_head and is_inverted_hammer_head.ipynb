# %% [markdown]
# # DO NOT USE THIS
# # Depricated - Contained in getSimpleDataPatternBasedFeatures¶

# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "009_"
variation_degree=20
requiredMinimumCorrelation = .2
autoConfigFileRelativePath = '/src/config/autoConfig/config.json'
KEY_preProcessedDataFilePath='preProcessedDataFilePath'

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData
from dataPreparation.resolveDataPatterns import getHammerHeadFeatures

_basicDf,_variation_degree,_preProcessedDataFilePath,_autoConfigData,_configFilePath = doBasicOperation(dataName,
       dataFrequency,autoConfigFileRelativePath,KEY_preProcessedDataFilePath,variation_degree)

print('done')
# Out:
# done
# into method doBasicOperation
# jupyterNodePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2
# configFilePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2/src/config/autoConfig/config.json
#  retrieving values configured in >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2/src/config/autoConfig/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
import pandas as pd
import numpy as np

featureOfInterest = 'hammer_head'

m = _basicDf.shape[0]

newFeatureDf = getHammerHeadFeatures(_basicDf)

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf= prepareFeatureWithData(newFeatureDf,
            _basicDf,_variation_degree,_preProcessedDataFilePath,
            _configFilePath,requiredMinimumCorrelation,featureIndexStamp,
            dataName,dataFrequency,useVersion2=True)
# Out:
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['is_green'][hammerHeadDf['close']- hammerHeadDf['open']>0] =  1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:299: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['is_red'][hammerHeadDf['close']- hammerHeadDf['open']<0] =  1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:313: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['isLongLeggedCandle'][(hammerHeadDf['high']-hammerHeadDf['low'])>= shortLegBoundary_config]=1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:320: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (hammerHeadDf['open'] >= hammerHeadDf['hammer_boundary'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (hammerHeadDf['close'] >= hammerHeadDf['hammer_boundary'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (hammerHeadDf['close'] <= hammerHeadDf['endboundary_withMargin'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:339: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (hammerHeadDf['open'] <= hammerHeadDf['endboundary_withMargin'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['hammer_pattern'][hammerHeadDf['return_is_hammer'] > 0] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:343: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['hammer_pattern'][hammerHeadDf['return_is_inverted_hammer'] > 0] = -1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['scarcityByIsHammer'][hammerHeadDf['return_is_hammer'] == 1]=100*(m-matches_isHammer.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:354: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['scarcityByIsInvertedHammer'][hammerHeadDf['return_is_inverted_hammer'] == 1]=100*(m-matches_isInvertedHammer.shape[0])/m
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:366: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['magnitudeScarcity_hammer_pattern'][hammerHeadDf['return_is_hammer'] > 0] = hammerHeadDf['magnitudeScarcityIsHammer']
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:367: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   hammerHeadDf['magnitudeScarcity_hammer_pattern'][hammerHeadDf['return_is_inverted_hammer'] > 0] = hammerHeadDf['magnitudeScarcityIsInvertedHammer']
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py:433: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\preProcessedData
# outputFolderPath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features
# featuresFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures
# rawFeaturesFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures
# filteredFeaturesFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations
# correlationsFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures\009_return_is_hammer_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures\009_return_is_hammer_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\009_return_is_hammer_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations\009_return_is_hammer_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures\009_return_is_hammer_trainableFeaturesList.csv
# File deleted >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures\009_return_is_hammer_variations_list.csv
# File deleted >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\009_return_is_hammer_variations_correlation_list.csv
# File deleted >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations\009_return_is_hammer_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures\009_return_is_hammer_variations_list.csv

# %%
#_correlation.shape
_correlation.sort_values('open',ascending=True)
# Out:
#                                                  open      high       low  \
# magnitudeScarcity_hammer_pattern_exp_inv_1  -0.039966 -0.039051 -0.039475
# magnitudeScarcity_hammer_pattern_exp_inv_2  -0.039964 -0.039049 -0.039473
# magnitudeScarcity_hammer_pattern_exp_inv_3  -0.039964 -0.039049 -0.039473
# magnitudeScarcity_hammer_pattern_exp_inv_4  -0.039964 -0.039049 -0.039473
# magnitudeScarcity_hammer_pattern_exp_inv_5  -0.039964 -0.039049 -0.039473
# magnitudeScarcityIsInvertedHammer_exp_inv_1 -0.036611 -0.038773 -0.039775
# magnitudeScarcityIsInvertedHammer_exp_inv_2 -0.036610 -0.038772 -0.039774
# magnitudeScarcityIsInvertedHammer_exp_inv_3 -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_4         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_11        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_1         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_17        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_18        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_6         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_16        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_3         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_14        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_7         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_19        -0.036610 -0.038772 -0.039774
# magnitudeScarcityIsInvertedHammer_exp_inv_4 -0.036610 -0.038772 -0.039774
# scarcityByIsInvertedHammer_exp_inv_1        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_9         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_8         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_12        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_5         -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_10        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_15        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_13        -0.036610 -0.038772 -0.039774
# return_is_inverted_hammer_exp_inv_2         -0.036610 -0.038772 -0.039774
# magnitudeScarcityIsHammer_exp_inv_1         -0.020890 -0.017912 -0.017623
# ...                                               ...       ...       ...
# magnitudeScarcity_hammer_pattern_pow_18      0.132823  0.133256  0.133709
# magnitudeScarcityIsInvertedHammer_pow_6      0.133554  0.135222  0.135859
# magnitudeScarcityIsInvertedHammer_pow_4      0.135477  0.137335  0.138140
# magnitudeScarcityIsInvertedHammer_pow_5      0.135675  0.137430  0.138141
# magnitudeScarcityIsHammer_pow_8              0.135802  0.133853  0.134034
# magnitudeScarcity_hammer_pattern_pow_17      0.137182  0.137600  0.138051
# magnitudeScarcityIsHammer_pow_7              0.138718  0.136668  0.136853
# magnitudeScarcityIsHammer_pow_4              0.139858  0.137345  0.137486
# magnitudeScarcityIsHammer_pow_6              0.141050  0.138878  0.139061
# magnitudeScarcity_hammer_pattern_pow_16      0.141699  0.142098  0.142548
# magnitudeScarcityIsHammer_pow_5              0.141980  0.139657  0.139827
# magnitudeScarcity_hammer_pattern_pow_15      0.146374  0.146751  0.147201
# magnitudeScarcity_hammer_pattern_pow_14      0.151211  0.151561  0.152013
# magnitudeScarcity_hammer_pattern_pow_13      0.156213  0.156531  0.156988
# magnitudeScarcity_hammer_pattern_pow_2       0.161084  0.160370  0.161072
# magnitudeScarcity_hammer_pattern_pow_12      0.161386  0.161665  0.162131
# magnitudeScarcity_hammer_pattern_pow_11      0.166731  0.166967  0.167443
# magnitudeScarcity_hammer_pattern_pow_10      0.172239  0.172423  0.172915
# magnitudeScarcity_hammer_pattern_pow_9       0.177869  0.177993  0.178506
# magnitudeScarcity_hammer_pattern_pow_8       0.183514  0.183568  0.184107
# magnitudeScarcity_hammer_pattern_pow_3       0.186208  0.185673  0.186385
# magnitudeScarcity_hammer_pattern_pow_7       0.188932  0.188904  0.189474
# magnitudeScarcity_hammer_pattern_pow_6       0.193606  0.193482  0.194089
# magnitudeScarcity_hammer_pattern_pow_4       0.195437  0.195063  0.195748
# magnitudeScarcity_hammer_pattern_pow_5       0.196485  0.196247  0.196894
# close                                        0.999298  0.999678  0.999613
# low                                          0.999531  0.999257  1.000000
# high                                         0.999541  1.000000  0.999257
# open                                         1.000000  0.999541  0.999531
# scarcityByIsHammer_exp_8                          NaN       NaN       NaN
#
#                                                 close  return_is_hammer  \
# magnitudeScarcity_hammer_pattern_exp_inv_1  -0.040127         -0.761928
# magnitudeScarcity_hammer_pattern_exp_inv_2  -0.040125         -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_3  -0.040125         -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_4  -0.040125         -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_5  -0.040125         -0.761929
# magnitudeScarcityIsInvertedHammer_exp_inv_1 -0.037055          0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_2 -0.037054          0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_3 -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_4         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_11        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_1         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_17        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_18        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_6         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_16        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_3         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_14        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_7         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_19        -0.037054          0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_4 -0.037054          0.024425
# scarcityByIsInvertedHammer_exp_inv_1        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_9         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_8         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_12        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_5         -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_10        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_15        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_13        -0.037054          0.024425
# return_is_inverted_hammer_exp_inv_2         -0.037054          0.024425
# magnitudeScarcityIsHammer_exp_inv_1         -0.020728         -1.000000
# ...                                               ...               ...
# magnitudeScarcity_hammer_pattern_pow_18      0.133149          0.105585
# magnitudeScarcityIsInvertedHammer_pow_6      0.133892         -0.012380
# magnitudeScarcityIsInvertedHammer_pow_4      0.135850         -0.015243
# magnitudeScarcityIsInvertedHammer_pow_5      0.136028         -0.013603
# magnitudeScarcityIsHammer_pow_8              0.135862          0.429777
# magnitudeScarcity_hammer_pattern_pow_17      0.137507          0.114723
# magnitudeScarcityIsHammer_pow_7              0.138769          0.459023
# magnitudeScarcityIsHammer_pow_4              0.139862          0.617116
# magnitudeScarcityIsHammer_pow_6              0.141090          0.496763
# magnitudeScarcity_hammer_pattern_pow_16      0.142022          0.124624
# magnitudeScarcityIsHammer_pow_5              0.142005          0.547327
# magnitudeScarcity_hammer_pattern_pow_15      0.146695          0.135370
# magnitudeScarcity_hammer_pattern_pow_14      0.151529          0.147066
# magnitudeScarcity_hammer_pattern_pow_13      0.156528          0.159850
# magnitudeScarcity_hammer_pattern_pow_2       0.161337          0.598292
# magnitudeScarcity_hammer_pattern_pow_12      0.161697          0.173905
# magnitudeScarcity_hammer_pattern_pow_11      0.167038          0.189486
# magnitudeScarcity_hammer_pattern_pow_10      0.172542          0.206954
# magnitudeScarcity_hammer_pattern_pow_9       0.178168          0.226838
# magnitudeScarcity_hammer_pattern_pow_8       0.183808          0.249935
# magnitudeScarcity_hammer_pattern_pow_3       0.186477          0.494560
# magnitudeScarcity_hammer_pattern_pow_7       0.189221          0.277503
# magnitudeScarcity_hammer_pattern_pow_6       0.193891          0.311571
# magnitudeScarcity_hammer_pattern_pow_4       0.195713          0.414283
# magnitudeScarcity_hammer_pattern_pow_5       0.196766          0.355451
# close                                        1.000000          0.020726
# low                                          0.999613          0.017621
# high                                         0.999678          0.017911
# open                                         0.999298          0.020889
# scarcityByIsHammer_exp_8                          NaN               NaN
#
#                                              return_is_inverted_hammer  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                   -0.628858
# magnitudeScarcity_hammer_pattern_exp_inv_2                   -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_3                   -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_4                   -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_5                   -0.628857
# magnitudeScarcityIsInvertedHammer_exp_inv_1                  -1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_2                  -1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_3                  -1.000000
# return_is_inverted_hammer_exp_inv_4                          -1.000000
# return_is_inverted_hammer_exp_inv_11                         -1.000000
# return_is_inverted_hammer_exp_inv_1                          -1.000000
# return_is_inverted_hammer_exp_inv_17                         -1.000000
# return_is_inverted_hammer_exp_inv_18                         -1.000000
# return_is_inverted_hammer_exp_inv_6                          -1.000000
# return_is_inverted_hammer_exp_inv_16                         -1.000000
# return_is_inverted_hammer_exp_inv_3                          -1.000000
# return_is_inverted_hammer_exp_inv_14                         -1.000000
# return_is_inverted_hammer_exp_inv_7                          -1.000000
# return_is_inverted_hammer_exp_inv_19                         -1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_4                  -1.000000
# scarcityByIsInvertedHammer_exp_inv_1                         -1.000000
# return_is_inverted_hammer_exp_inv_9                          -1.000000
# return_is_inverted_hammer_exp_inv_8                          -1.000000
# return_is_inverted_hammer_exp_inv_12                         -1.000000
# return_is_inverted_hammer_exp_inv_5                          -1.000000
# return_is_inverted_hammer_exp_inv_10                         -1.000000
# return_is_inverted_hammer_exp_inv_15                         -1.000000
# return_is_inverted_hammer_exp_inv_13                         -1.000000
# return_is_inverted_hammer_exp_inv_2                          -1.000000
# magnitudeScarcityIsHammer_exp_inv_1                           0.024425
# ...                                                                ...
# magnitudeScarcity_hammer_pattern_pow_18                       0.268607
# magnitudeScarcityIsInvertedHammer_pow_6                       0.506845
# magnitudeScarcityIsInvertedHammer_pow_4                       0.624080
# magnitudeScarcityIsInvertedHammer_pow_5                       0.556923
# magnitudeScarcityIsHammer_pow_8                              -0.010497
# magnitudeScarcity_hammer_pattern_pow_17                       0.273920
# magnitudeScarcityIsHammer_pow_7                              -0.011211
# magnitudeScarcityIsHammer_pow_4                              -0.015073
# magnitudeScarcityIsHammer_pow_6                              -0.012133
# magnitudeScarcity_hammer_pattern_pow_16                       0.279405
# magnitudeScarcityIsHammer_pow_5                              -0.013368
# magnitudeScarcity_hammer_pattern_pow_15                       0.285114
# magnitudeScarcity_hammer_pattern_pow_14                       0.291127
# magnitudeScarcity_hammer_pattern_pow_13                       0.297559
# magnitudeScarcity_hammer_pattern_pow_2                        0.560849
# magnitudeScarcity_hammer_pattern_pow_12                       0.304573
# magnitudeScarcity_hammer_pattern_pow_11                       0.312397
# magnitudeScarcity_hammer_pattern_pow_10                       0.321347
# magnitudeScarcity_hammer_pattern_pow_9                        0.331866
# magnitudeScarcity_hammer_pattern_pow_8                        0.344590
# magnitudeScarcity_hammer_pattern_pow_3                        0.497017
# magnitudeScarcity_hammer_pattern_pow_7                        0.360462
# magnitudeScarcity_hammer_pattern_pow_6                        0.380935
# magnitudeScarcity_hammer_pattern_pow_4                        0.445760
# magnitudeScarcity_hammer_pattern_pow_5                        0.408266
# close                                                         0.037054
# low                                                           0.039774
# high                                                          0.038772
# open                                                          0.036610
# scarcityByIsHammer_exp_8                                           NaN
#
#                                              hammer_pattern  \
# magnitudeScarcity_hammer_pattern_exp_inv_1        -0.180788
# magnitudeScarcity_hammer_pattern_exp_inv_2        -0.180789
# magnitudeScarcity_hammer_pattern_exp_inv_3        -0.180789
# magnitudeScarcity_hammer_pattern_exp_inv_4        -0.180789
# magnitudeScarcity_hammer_pattern_exp_inv_5        -0.180789
# magnitudeScarcityIsInvertedHammer_exp_inv_1        0.651018
# magnitudeScarcityIsInvertedHammer_exp_inv_2        0.651018
# magnitudeScarcityIsInvertedHammer_exp_inv_3        0.651018
# return_is_inverted_hammer_exp_inv_4                0.651018
# return_is_inverted_hammer_exp_inv_11               0.651018
# return_is_inverted_hammer_exp_inv_1                0.651018
# return_is_inverted_hammer_exp_inv_17               0.651018
# return_is_inverted_hammer_exp_inv_18               0.651018
# return_is_inverted_hammer_exp_inv_6                0.651018
# return_is_inverted_hammer_exp_inv_16               0.651018
# return_is_inverted_hammer_exp_inv_3                0.651018
# return_is_inverted_hammer_exp_inv_14               0.651018
# return_is_inverted_hammer_exp_inv_7                0.651018
# return_is_inverted_hammer_exp_inv_19               0.651018
# magnitudeScarcityIsInvertedHammer_exp_inv_4        0.651018
# scarcityByIsInvertedHammer_exp_inv_1               0.651018
# return_is_inverted_hammer_exp_inv_9                0.651018
# return_is_inverted_hammer_exp_inv_8                0.651018
# return_is_inverted_hammer_exp_inv_12               0.651018
# return_is_inverted_hammer_exp_inv_5                0.651018
# return_is_inverted_hammer_exp_inv_10               0.651018
# return_is_inverted_hammer_exp_inv_15               0.651018
# return_is_inverted_hammer_exp_inv_13               0.651018
# return_is_inverted_hammer_exp_inv_2                0.651018
# magnitudeScarcityIsHammer_exp_inv_1               -0.774736
# ...                                                     ...
# magnitudeScarcity_hammer_pattern_pow_18           -0.089717
# magnitudeScarcityIsInvertedHammer_pow_6           -0.329966
# magnitudeScarcityIsInvertedHammer_pow_4           -0.406287
# magnitudeScarcityIsInvertedHammer_pow_5           -0.362567
# magnitudeScarcityIsHammer_pow_8                    0.332964
# magnitudeScarcity_hammer_pattern_pow_17           -0.086139
# magnitudeScarcityIsHammer_pow_7                    0.355621
# magnitudeScarcityIsHammer_pow_4                    0.478102
# magnitudeScarcityIsHammer_pow_6                    0.384860
# magnitudeScarcity_hammer_pattern_pow_16           -0.082091
# magnitudeScarcityIsHammer_pow_5                    0.424034
# magnitudeScarcity_hammer_pattern_pow_15           -0.077542
# magnitudeScarcity_hammer_pattern_pow_14           -0.072464
# magnitudeScarcity_hammer_pattern_pow_13           -0.066826
# magnitudeScarcity_hammer_pattern_pow_2             0.099555
# magnitudeScarcity_hammer_pattern_pow_12           -0.060590
# magnitudeScarcity_hammer_pattern_pow_11           -0.053708
# magnitudeScarcity_hammer_pattern_pow_10           -0.046105
# magnitudeScarcity_hammer_pattern_pow_9            -0.037661
# magnitudeScarcity_hammer_pattern_pow_8            -0.028171
# magnitudeScarcity_hammer_pattern_pow_3             0.061164
# magnitudeScarcity_hammer_pattern_pow_7            -0.017278
# magnitudeScarcity_hammer_pattern_pow_6            -0.004359
# magnitudeScarcity_hammer_pattern_pow_4             0.032629
# magnitudeScarcity_hammer_pattern_pow_5             0.011673
# close                                             -0.007699
# low                                               -0.011776
# high                                              -0.010923
# open                                              -0.007294
# scarcityByIsHammer_exp_8                                NaN
#
#                                              scarcityByIsHammer  \
# magnitudeScarcity_hammer_pattern_exp_inv_1            -0.761928
# magnitudeScarcity_hammer_pattern_exp_inv_2            -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_3            -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_4            -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_5            -0.761929
# magnitudeScarcityIsInvertedHammer_exp_inv_1            0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_2            0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_3            0.024425
# return_is_inverted_hammer_exp_inv_4                    0.024425
# return_is_inverted_hammer_exp_inv_11                   0.024425
# return_is_inverted_hammer_exp_inv_1                    0.024425
# return_is_inverted_hammer_exp_inv_17                   0.024425
# return_is_inverted_hammer_exp_inv_18                   0.024425
# return_is_inverted_hammer_exp_inv_6                    0.024425
# return_is_inverted_hammer_exp_inv_16                   0.024425
# return_is_inverted_hammer_exp_inv_3                    0.024425
# return_is_inverted_hammer_exp_inv_14                   0.024425
# return_is_inverted_hammer_exp_inv_7                    0.024425
# return_is_inverted_hammer_exp_inv_19                   0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_4            0.024425
# scarcityByIsInvertedHammer_exp_inv_1                   0.024425
# return_is_inverted_hammer_exp_inv_9                    0.024425
# return_is_inverted_hammer_exp_inv_8                    0.024425
# return_is_inverted_hammer_exp_inv_12                   0.024425
# return_is_inverted_hammer_exp_inv_5                    0.024425
# return_is_inverted_hammer_exp_inv_10                   0.024425
# return_is_inverted_hammer_exp_inv_15                   0.024425
# return_is_inverted_hammer_exp_inv_13                   0.024425
# return_is_inverted_hammer_exp_inv_2                    0.024425
# magnitudeScarcityIsHammer_exp_inv_1                   -1.000000
# ...                                                         ...
# magnitudeScarcity_hammer_pattern_pow_18                0.105585
# magnitudeScarcityIsInvertedHammer_pow_6               -0.012380
# magnitudeScarcityIsInvertedHammer_pow_4               -0.015243
# magnitudeScarcityIsInvertedHammer_pow_5               -0.013603
# magnitudeScarcityIsHammer_pow_8                        0.429777
# magnitudeScarcity_hammer_pattern_pow_17                0.114723
# magnitudeScarcityIsHammer_pow_7                        0.459023
# magnitudeScarcityIsHammer_pow_4                        0.617116
# magnitudeScarcityIsHammer_pow_6                        0.496763
# magnitudeScarcity_hammer_pattern_pow_16                0.124624
# magnitudeScarcityIsHammer_pow_5                        0.547327
# magnitudeScarcity_hammer_pattern_pow_15                0.135370
# magnitudeScarcity_hammer_pattern_pow_14                0.147066
# magnitudeScarcity_hammer_pattern_pow_13                0.159850
# magnitudeScarcity_hammer_pattern_pow_2                 0.598292
# magnitudeScarcity_hammer_pattern_pow_12                0.173905
# magnitudeScarcity_hammer_pattern_pow_11                0.189486
# magnitudeScarcity_hammer_pattern_pow_10                0.206954
# magnitudeScarcity_hammer_pattern_pow_9                 0.226838
# magnitudeScarcity_hammer_pattern_pow_8                 0.249935
# magnitudeScarcity_hammer_pattern_pow_3                 0.494560
# magnitudeScarcity_hammer_pattern_pow_7                 0.277503
# magnitudeScarcity_hammer_pattern_pow_6                 0.311571
# magnitudeScarcity_hammer_pattern_pow_4                 0.414283
# magnitudeScarcity_hammer_pattern_pow_5                 0.355451
# close                                                  0.020726
# low                                                    0.017621
# high                                                   0.017911
# open                                                   0.020889
# scarcityByIsHammer_exp_8                                    NaN
#
#                                              scarcityByIsInvertedHammer  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                    -0.628858
# magnitudeScarcity_hammer_pattern_exp_inv_2                    -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_3                    -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_4                    -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_5                    -0.628857
# magnitudeScarcityIsInvertedHammer_exp_inv_1                   -1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_2                   -1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_3                   -1.000000
# return_is_inverted_hammer_exp_inv_4                           -1.000000
# return_is_inverted_hammer_exp_inv_11                          -1.000000
# return_is_inverted_hammer_exp_inv_1                           -1.000000
# return_is_inverted_hammer_exp_inv_17                          -1.000000
# return_is_inverted_hammer_exp_inv_18                          -1.000000
# return_is_inverted_hammer_exp_inv_6                           -1.000000
# return_is_inverted_hammer_exp_inv_16                          -1.000000
# return_is_inverted_hammer_exp_inv_3                           -1.000000
# return_is_inverted_hammer_exp_inv_14                          -1.000000
# return_is_inverted_hammer_exp_inv_7                           -1.000000
# return_is_inverted_hammer_exp_inv_19                          -1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_4                   -1.000000
# scarcityByIsInvertedHammer_exp_inv_1                          -1.000000
# return_is_inverted_hammer_exp_inv_9                           -1.000000
# return_is_inverted_hammer_exp_inv_8                           -1.000000
# return_is_inverted_hammer_exp_inv_12                          -1.000000
# return_is_inverted_hammer_exp_inv_5                           -1.000000
# return_is_inverted_hammer_exp_inv_10                          -1.000000
# return_is_inverted_hammer_exp_inv_15                          -1.000000
# return_is_inverted_hammer_exp_inv_13                          -1.000000
# return_is_inverted_hammer_exp_inv_2                           -1.000000
# magnitudeScarcityIsHammer_exp_inv_1                            0.024425
# ...                                                                 ...
# magnitudeScarcity_hammer_pattern_pow_18                        0.268607
# magnitudeScarcityIsInvertedHammer_pow_6                        0.506845
# magnitudeScarcityIsInvertedHammer_pow_4                        0.624080
# magnitudeScarcityIsInvertedHammer_pow_5                        0.556923
# magnitudeScarcityIsHammer_pow_8                               -0.010497
# magnitudeScarcity_hammer_pattern_pow_17                        0.273920
# magnitudeScarcityIsHammer_pow_7                               -0.011211
# magnitudeScarcityIsHammer_pow_4                               -0.015073
# magnitudeScarcityIsHammer_pow_6                               -0.012133
# magnitudeScarcity_hammer_pattern_pow_16                        0.279405
# magnitudeScarcityIsHammer_pow_5                               -0.013368
# magnitudeScarcity_hammer_pattern_pow_15                        0.285114
# magnitudeScarcity_hammer_pattern_pow_14                        0.291127
# magnitudeScarcity_hammer_pattern_pow_13                        0.297559
# magnitudeScarcity_hammer_pattern_pow_2                         0.560849
# magnitudeScarcity_hammer_pattern_pow_12                        0.304573
# magnitudeScarcity_hammer_pattern_pow_11                        0.312397
# magnitudeScarcity_hammer_pattern_pow_10                        0.321347
# magnitudeScarcity_hammer_pattern_pow_9                         0.331866
# magnitudeScarcity_hammer_pattern_pow_8                         0.344590
# magnitudeScarcity_hammer_pattern_pow_3                         0.497017
# magnitudeScarcity_hammer_pattern_pow_7                         0.360462
# magnitudeScarcity_hammer_pattern_pow_6                         0.380935
# magnitudeScarcity_hammer_pattern_pow_4                         0.445760
# magnitudeScarcity_hammer_pattern_pow_5                         0.408266
# close                                                          0.037054
# low                                                            0.039774
# high                                                           0.038772
# open                                                           0.036610
# scarcityByIsHammer_exp_8                                            NaN
#
#                                              magnitudeScarcityIsHammer  ...  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                   -0.724740  ...
# magnitudeScarcity_hammer_pattern_exp_inv_2                   -0.724739  ...
# magnitudeScarcity_hammer_pattern_exp_inv_3                   -0.724739  ...
# magnitudeScarcity_hammer_pattern_exp_inv_4                   -0.724739  ...
# magnitudeScarcity_hammer_pattern_exp_inv_5                   -0.724739  ...
# magnitudeScarcityIsInvertedHammer_exp_inv_1                   0.023232  ...
# magnitudeScarcityIsInvertedHammer_exp_inv_2                   0.023232  ...
# magnitudeScarcityIsInvertedHammer_exp_inv_3                   0.023232  ...
# return_is_inverted_hammer_exp_inv_4                           0.023232  ...
# return_is_inverted_hammer_exp_inv_11                          0.023232  ...
# return_is_inverted_hammer_exp_inv_1                           0.023232  ...
# return_is_inverted_hammer_exp_inv_17                          0.023232  ...
# return_is_inverted_hammer_exp_inv_18                          0.023232  ...
# return_is_inverted_hammer_exp_inv_6                           0.023232  ...
# return_is_inverted_hammer_exp_inv_16                          0.023232  ...
# return_is_inverted_hammer_exp_inv_3                           0.023232  ...
# return_is_inverted_hammer_exp_inv_14                          0.023232  ...
# return_is_inverted_hammer_exp_inv_7                           0.023232  ...
# return_is_inverted_hammer_exp_inv_19                          0.023232  ...
# magnitudeScarcityIsInvertedHammer_exp_inv_4                   0.023232  ...
# scarcityByIsInvertedHammer_exp_inv_1                          0.023232  ...
# return_is_inverted_hammer_exp_inv_9                           0.023232  ...
# return_is_inverted_hammer_exp_inv_8                           0.023232  ...
# return_is_inverted_hammer_exp_inv_12                          0.023232  ...
# return_is_inverted_hammer_exp_inv_5                           0.023232  ...
# return_is_inverted_hammer_exp_inv_10                          0.023232  ...
# return_is_inverted_hammer_exp_inv_15                          0.023232  ...
# return_is_inverted_hammer_exp_inv_13                          0.023232  ...
# return_is_inverted_hammer_exp_inv_2                           0.023232  ...
# magnitudeScarcityIsHammer_exp_inv_1                          -0.951192  ...
# ...                                                                ...  ...
# magnitudeScarcity_hammer_pattern_pow_18                       0.170484  ...
# magnitudeScarcityIsInvertedHammer_pow_6                      -0.011775  ...
# magnitudeScarcityIsInvertedHammer_pow_4                      -0.014499  ...
# magnitudeScarcityIsInvertedHammer_pow_5                      -0.012939  ...
# magnitudeScarcityIsHammer_pow_8                               0.636891  ...
# magnitudeScarcity_hammer_pattern_pow_17                       0.184437  ...
# magnitudeScarcityIsHammer_pow_7                               0.668853  ...
# magnitudeScarcityIsHammer_pow_4                               0.815332  ...
# magnitudeScarcityIsHammer_pow_6                               0.707526  ...
# magnitudeScarcity_hammer_pattern_pow_16                       0.199439  ...
# magnitudeScarcityIsHammer_pow_5                               0.755392  ...
# magnitudeScarcity_hammer_pattern_pow_15                       0.215575  ...
# magnitudeScarcity_hammer_pattern_pow_14                       0.232950  ...
# magnitudeScarcity_hammer_pattern_pow_13                       0.251700  ...
# magnitudeScarcity_hammer_pattern_pow_2                        0.692540  ...
# magnitudeScarcity_hammer_pattern_pow_12                       0.272001  ...
# magnitudeScarcity_hammer_pattern_pow_11                       0.294090  ...
# magnitudeScarcity_hammer_pattern_pow_10                       0.318285  ...
# magnitudeScarcity_hammer_pattern_pow_9                        0.345025  ...
# magnitudeScarcity_hammer_pattern_pow_8                        0.374930  ...
# magnitudeScarcity_hammer_pattern_pow_3                        0.619385  ...
# magnitudeScarcity_hammer_pattern_pow_7                        0.408897  ...
# magnitudeScarcity_hammer_pattern_pow_6                        0.448255  ...
# magnitudeScarcity_hammer_pattern_pow_4                        0.551473  ...
# magnitudeScarcity_hammer_pattern_pow_5                        0.494945  ...
# close                                                         0.072710  ...
# low                                                           0.069571  ...
# high                                                          0.069714  ...
# open                                                          0.072830  ...
# scarcityByIsHammer_exp_8                                           NaN  ...
#
#                                              magnitudeScarcityIsInvertedHammer_exp_inv_19  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                                       0.628858
# magnitudeScarcity_hammer_pattern_exp_inv_2                                       0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_3                                       0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_4                                       0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_5                                       0.628857
# magnitudeScarcityIsInvertedHammer_exp_inv_1                                      1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_2                                      1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_3                                      1.000000
# return_is_inverted_hammer_exp_inv_4                                              1.000000
# return_is_inverted_hammer_exp_inv_11                                             1.000000
# return_is_inverted_hammer_exp_inv_1                                              1.000000
# return_is_inverted_hammer_exp_inv_17                                             1.000000
# return_is_inverted_hammer_exp_inv_18                                             1.000000
# return_is_inverted_hammer_exp_inv_6                                              1.000000
# return_is_inverted_hammer_exp_inv_16                                             1.000000
# return_is_inverted_hammer_exp_inv_3                                              1.000000
# return_is_inverted_hammer_exp_inv_14                                             1.000000
# return_is_inverted_hammer_exp_inv_7                                              1.000000
# return_is_inverted_hammer_exp_inv_19                                             1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_4                                      1.000000
# scarcityByIsInvertedHammer_exp_inv_1                                             1.000000
# return_is_inverted_hammer_exp_inv_9                                              1.000000
# return_is_inverted_hammer_exp_inv_8                                              1.000000
# return_is_inverted_hammer_exp_inv_12                                             1.000000
# return_is_inverted_hammer_exp_inv_5                                              1.000000
# return_is_inverted_hammer_exp_inv_10                                             1.000000
# return_is_inverted_hammer_exp_inv_15                                             1.000000
# return_is_inverted_hammer_exp_inv_13                                             1.000000
# return_is_inverted_hammer_exp_inv_2                                              1.000000
# magnitudeScarcityIsHammer_exp_inv_1                                             -0.024425
# ...                                                                                   ...
# magnitudeScarcity_hammer_pattern_pow_18                                         -0.268607
# magnitudeScarcityIsInvertedHammer_pow_6                                         -0.506845
# magnitudeScarcityIsInvertedHammer_pow_4                                         -0.624080
# magnitudeScarcityIsInvertedHammer_pow_5                                         -0.556923
# magnitudeScarcityIsHammer_pow_8                                                  0.010497
# magnitudeScarcity_hammer_pattern_pow_17                                         -0.273920
# magnitudeScarcityIsHammer_pow_7                                                  0.011211
# magnitudeScarcityIsHammer_pow_4                                                  0.015073
# magnitudeScarcityIsHammer_pow_6                                                  0.012133
# magnitudeScarcity_hammer_pattern_pow_16                                         -0.279405
# magnitudeScarcityIsHammer_pow_5                                                  0.013368
# magnitudeScarcity_hammer_pattern_pow_15                                         -0.285114
# magnitudeScarcity_hammer_pattern_pow_14                                         -0.291127
# magnitudeScarcity_hammer_pattern_pow_13                                         -0.297559
# magnitudeScarcity_hammer_pattern_pow_2                                          -0.560849
# magnitudeScarcity_hammer_pattern_pow_12                                         -0.304573
# magnitudeScarcity_hammer_pattern_pow_11                                         -0.312397
# magnitudeScarcity_hammer_pattern_pow_10                                         -0.321347
# magnitudeScarcity_hammer_pattern_pow_9                                          -0.331866
# magnitudeScarcity_hammer_pattern_pow_8                                          -0.344590
# magnitudeScarcity_hammer_pattern_pow_3                                          -0.497017
# magnitudeScarcity_hammer_pattern_pow_7                                          -0.360462
# magnitudeScarcity_hammer_pattern_pow_6                                          -0.380935
# magnitudeScarcity_hammer_pattern_pow_4                                          -0.445760
# magnitudeScarcity_hammer_pattern_pow_5                                          -0.408266
# close                                                                           -0.037054
# low                                                                             -0.039774
# high                                                                            -0.038772
# open                                                                            -0.036610
# scarcityByIsHammer_exp_8                                                              NaN
#
#                                              magnitudeScarcity_hammer_pattern_exp_inv_19  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                                      1.000000
# magnitudeScarcity_hammer_pattern_exp_inv_2                                      1.000000
# magnitudeScarcity_hammer_pattern_exp_inv_3                                      1.000000
# magnitudeScarcity_hammer_pattern_exp_inv_4                                      1.000000
# magnitudeScarcity_hammer_pattern_exp_inv_5                                      1.000000
# magnitudeScarcityIsInvertedHammer_exp_inv_1                                     0.628857
# magnitudeScarcityIsInvertedHammer_exp_inv_2                                     0.628857
# magnitudeScarcityIsInvertedHammer_exp_inv_3                                     0.628857
# return_is_inverted_hammer_exp_inv_4                                             0.628857
# return_is_inverted_hammer_exp_inv_11                                            0.628857
# return_is_inverted_hammer_exp_inv_1                                             0.628857
# return_is_inverted_hammer_exp_inv_17                                            0.628857
# return_is_inverted_hammer_exp_inv_18                                            0.628857
# return_is_inverted_hammer_exp_inv_6                                             0.628857
# return_is_inverted_hammer_exp_inv_16                                            0.628857
# return_is_inverted_hammer_exp_inv_3                                             0.628857
# return_is_inverted_hammer_exp_inv_14                                            0.628857
# return_is_inverted_hammer_exp_inv_7                                             0.628857
# return_is_inverted_hammer_exp_inv_19                                            0.628857
# magnitudeScarcityIsInvertedHammer_exp_inv_4                                     0.628857
# scarcityByIsInvertedHammer_exp_inv_1                                            0.628857
# return_is_inverted_hammer_exp_inv_9                                             0.628857
# return_is_inverted_hammer_exp_inv_8                                             0.628857
# return_is_inverted_hammer_exp_inv_12                                            0.628857
# return_is_inverted_hammer_exp_inv_5                                             0.628857
# return_is_inverted_hammer_exp_inv_10                                            0.628857
# return_is_inverted_hammer_exp_inv_15                                            0.628857
# return_is_inverted_hammer_exp_inv_13                                            0.628857
# return_is_inverted_hammer_exp_inv_2                                             0.628857
# magnitudeScarcityIsHammer_exp_inv_1                                             0.761929
# ...                                                                                  ...
# magnitudeScarcity_hammer_pattern_pow_18                                        -0.256137
# magnitudeScarcityIsInvertedHammer_pow_6                                        -0.318733
# magnitudeScarcityIsInvertedHammer_pow_4                                        -0.392457
# magnitudeScarcityIsInvertedHammer_pow_5                                        -0.350225
# magnitudeScarcityIsHammer_pow_8                                                -0.327460
# magnitudeScarcity_hammer_pattern_pow_17                                        -0.266686
# magnitudeScarcityIsHammer_pow_7                                                -0.349743
# magnitudeScarcityIsHammer_pow_4                                                -0.470199
# magnitudeScarcityIsHammer_pow_6                                                -0.378498
# magnitudeScarcity_hammer_pattern_pow_16                                        -0.277940
# magnitudeScarcityIsHammer_pow_5                                                -0.417025
# magnitudeScarcity_hammer_pattern_pow_15                                        -0.289997
# magnitudeScarcity_hammer_pattern_pow_14                                        -0.302989
# magnitudeScarcity_hammer_pattern_pow_13                                        -0.317098
# magnitudeScarcity_hammer_pattern_pow_2                                         -0.828672
# magnitudeScarcity_hammer_pattern_pow_12                                        -0.332573
# magnitudeScarcity_hammer_pattern_pow_11                                        -0.349761
# magnitudeScarcity_hammer_pattern_pow_10                                        -0.369145
# magnitudeScarcity_hammer_pattern_pow_9                                         -0.391424
# magnitudeScarcity_hammer_pattern_pow_8                                         -0.417632
# magnitudeScarcity_hammer_pattern_pow_3                                         -0.706640
# magnitudeScarcity_hammer_pattern_pow_7                                         -0.449355
# magnitudeScarcity_hammer_pattern_pow_6                                         -0.489116
# magnitudeScarcity_hammer_pattern_pow_4                                         -0.610997
# magnitudeScarcity_hammer_pattern_pow_5                                         -0.540949
# close                                                                          -0.040125
# low                                                                            -0.039473
# high                                                                           -0.039049
# open                                                                           -0.039964
# scarcityByIsHammer_exp_8                                                             NaN
#
#                                              return_is_hammer_pow_19  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                 -0.761928
# magnitudeScarcity_hammer_pattern_exp_inv_2                 -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_3                 -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_4                 -0.761929
# magnitudeScarcity_hammer_pattern_exp_inv_5                 -0.761929
# magnitudeScarcityIsInvertedHammer_exp_inv_1                 0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_2                 0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_3                 0.024425
# return_is_inverted_hammer_exp_inv_4                         0.024425
# return_is_inverted_hammer_exp_inv_11                        0.024425
# return_is_inverted_hammer_exp_inv_1                         0.024425
# return_is_inverted_hammer_exp_inv_17                        0.024425
# return_is_inverted_hammer_exp_inv_18                        0.024425
# return_is_inverted_hammer_exp_inv_6                         0.024425
# return_is_inverted_hammer_exp_inv_16                        0.024425
# return_is_inverted_hammer_exp_inv_3                         0.024425
# return_is_inverted_hammer_exp_inv_14                        0.024425
# return_is_inverted_hammer_exp_inv_7                         0.024425
# return_is_inverted_hammer_exp_inv_19                        0.024425
# magnitudeScarcityIsInvertedHammer_exp_inv_4                 0.024425
# scarcityByIsInvertedHammer_exp_inv_1                        0.024425
# return_is_inverted_hammer_exp_inv_9                         0.024425
# return_is_inverted_hammer_exp_inv_8                         0.024425
# return_is_inverted_hammer_exp_inv_12                        0.024425
# return_is_inverted_hammer_exp_inv_5                         0.024425
# return_is_inverted_hammer_exp_inv_10                        0.024425
# return_is_inverted_hammer_exp_inv_15                        0.024425
# return_is_inverted_hammer_exp_inv_13                        0.024425
# return_is_inverted_hammer_exp_inv_2                         0.024425
# magnitudeScarcityIsHammer_exp_inv_1                        -1.000000
# ...                                                              ...
# magnitudeScarcity_hammer_pattern_pow_18                     0.105585
# magnitudeScarcityIsInvertedHammer_pow_6                    -0.012380
# magnitudeScarcityIsInvertedHammer_pow_4                    -0.015243
# magnitudeScarcityIsInvertedHammer_pow_5                    -0.013603
# magnitudeScarcityIsHammer_pow_8                             0.429777
# magnitudeScarcity_hammer_pattern_pow_17                     0.114723
# magnitudeScarcityIsHammer_pow_7                             0.459023
# magnitudeScarcityIsHammer_pow_4                             0.617116
# magnitudeScarcityIsHammer_pow_6                             0.496763
# magnitudeScarcity_hammer_pattern_pow_16                     0.124624
# magnitudeScarcityIsHammer_pow_5                             0.547327
# magnitudeScarcity_hammer_pattern_pow_15                     0.135370
# magnitudeScarcity_hammer_pattern_pow_14                     0.147066
# magnitudeScarcity_hammer_pattern_pow_13                     0.159850
# magnitudeScarcity_hammer_pattern_pow_2                      0.598292
# magnitudeScarcity_hammer_pattern_pow_12                     0.173905
# magnitudeScarcity_hammer_pattern_pow_11                     0.189486
# magnitudeScarcity_hammer_pattern_pow_10                     0.206954
# magnitudeScarcity_hammer_pattern_pow_9                      0.226838
# magnitudeScarcity_hammer_pattern_pow_8                      0.249935
# magnitudeScarcity_hammer_pattern_pow_3                      0.494560
# magnitudeScarcity_hammer_pattern_pow_7                      0.277503
# magnitudeScarcity_hammer_pattern_pow_6                      0.311571
# magnitudeScarcity_hammer_pattern_pow_4                      0.414283
# magnitudeScarcity_hammer_pattern_pow_5                      0.355451
# close                                                       0.020726
# low                                                         0.017621
# high                                                        0.017911
# open                                                        0.020889
# scarcityByIsHammer_exp_8                                         NaN
#
#                                              return_is_inverted_hammer_pow_19  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                          -0.628858
# magnitudeScarcity_hammer_pattern_exp_inv_2                          -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_3                          -0.628857
# magnitudeScarcity_hammer_pattern_exp_inv_4                          -0.628857
# ...
#
#                                              magnitudeScarcityIsHammer_pow_19  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                          -0.220413
# magnitudeScarcity_hammer_pattern_exp_inv_2                          -0.220412
# magnitudeScarcity_hammer_pattern_exp_inv_3                          -0.220412
# magnitudeScarcity_hammer_pattern_exp_inv_4                          -0.220412
# magnitudeScarcity_hammer_pattern_exp_inv_5                          -0.220412
# magnitudeScarcityIsInvertedHammer_exp_inv_1                          0.007066
# magnitudeScarcityIsInvertedHammer_exp_inv_2                          0.007066
# magnitudeScarcityIsInvertedHammer_exp_inv_3                          0.007066
# return_is_inverted_hammer_exp_inv_4                                  0.007066
# return_is_inverted_hammer_exp_inv_11                                 0.007066
# return_is_inverted_hammer_exp_inv_1                                  0.007066
# return_is_inverted_hammer_exp_inv_17                                 0.007066
# return_is_inverted_hammer_exp_inv_18                                 0.007066
# return_is_inverted_hammer_exp_inv_6                                  0.007066
# return_is_inverted_hammer_exp_inv_16                                 0.007066
# return_is_inverted_hammer_exp_inv_3                                  0.007066
# return_is_inverted_hammer_exp_inv_14                                 0.007066
# return_is_inverted_hammer_exp_inv_7                                  0.007066
# return_is_inverted_hammer_exp_inv_19                                 0.007066
# magnitudeScarcityIsInvertedHammer_exp_inv_4                          0.007066
# scarcityByIsInvertedHammer_exp_inv_1                                 0.007066
# return_is_inverted_hammer_exp_inv_9                                  0.007066
# return_is_inverted_hammer_exp_inv_8                                  0.007066
# return_is_inverted_hammer_exp_inv_12                                 0.007066
# return_is_inverted_hammer_exp_inv_5                                  0.007066
# return_is_inverted_hammer_exp_inv_10                                 0.007066
# return_is_inverted_hammer_exp_inv_15                                 0.007066
# return_is_inverted_hammer_exp_inv_13                                 0.007066
# return_is_inverted_hammer_exp_inv_2                                  0.007066
# magnitudeScarcityIsHammer_exp_inv_1                                 -0.289283
# ...                                                                       ...
# magnitudeScarcity_hammer_pattern_pow_18                              0.376145
# magnitudeScarcityIsInvertedHammer_pow_6                             -0.003581
# magnitudeScarcityIsInvertedHammer_pow_4                             -0.004409
# magnitudeScarcityIsInvertedHammer_pow_5                             -0.003935
# magnitudeScarcityIsHammer_pow_8                                      0.919182
# magnitudeScarcity_hammer_pattern_pow_17                              0.396202
# magnitudeScarcityIsHammer_pow_7                                      0.895844
# magnitudeScarcityIsHammer_pow_4                                      0.776522
# magnitudeScarcityIsHammer_pow_6                                      0.866177
# magnitudeScarcity_hammer_pattern_pow_16                              0.416400
# magnitudeScarcityIsHammer_pow_5                                      0.827751
# magnitudeScarcity_hammer_pattern_pow_15                              0.436546
# magnitudeScarcity_hammer_pattern_pow_14                              0.456414
# magnitudeScarcity_hammer_pattern_pow_13                              0.475738
# magnitudeScarcity_hammer_pattern_pow_2                               0.437485
# magnitudeScarcity_hammer_pattern_pow_12                              0.494203
# magnitudeScarcity_hammer_pattern_pow_11                              0.511432
# magnitudeScarcity_hammer_pattern_pow_10                              0.526961
# magnitudeScarcity_hammer_pattern_pow_9                               0.540205
# magnitudeScarcity_hammer_pattern_pow_8                               0.550398
# magnitudeScarcity_hammer_pattern_pow_3                               0.497720
# magnitudeScarcity_hammer_pattern_pow_7                               0.556504
# magnitudeScarcity_hammer_pattern_pow_6                               0.557079
# magnitudeScarcity_hammer_pattern_pow_4                               0.532093
# magnitudeScarcity_hammer_pattern_pow_5                               0.550029
# close                                                                0.107194
# low                                                                  0.105754
# high                                                                 0.105724
# open                                                                 0.107085
# scarcityByIsHammer_exp_8                                                  NaN
#
#                                              magnitudeScarcityIsInvertedHammer_pow_19  \
# magnitudeScarcity_hammer_pattern_exp_inv_1                                  -0.179010
# magnitudeScarcity_hammer_pattern_exp_inv_2                                  -0.179009
# magnitudeScarcity_hammer_pattern_exp_inv_3                                  -0.179009
# magnitudeScarcity_hammer_pattern_exp_inv_4                                  -0.179009
# magnitudeScarcity_hammer_pattern_exp_inv_5                                  -0.179009
# magnitudeScarcityIsInvertedHammer_exp_inv_1                                 -0.284658
# magnitudeScarcityIsInvertedHammer_exp_inv_2                                 -0.284657
# magnitudeScarcityIsInvertedHammer_exp_inv_3                                 -0.284657
# return_is_inverted_hammer_exp_inv_4                                         -0.284657
# return_is_inverted_hammer_exp_inv_11                                        -0.284657
# return_is_inverted_hammer_exp_inv_1                                         -0.284657
# return_is_inverted_hammer_exp_inv_17                                        -0.284657
# return_is_inverted_hammer_exp_inv_18                                        -0.284657
# return_is_inverted_hammer_exp_inv_6                                         -0.284657
# return_is_inverted_hammer_exp_inv_16                                        -0.284657
# return_is_inverted_hammer_exp_inv_3                                         -0.284657
# return_is_inverted_hammer_exp_inv_14                                        -0.284657
# return_is_inverted_hammer_exp_inv_7                                         -0.284657
# return_is_inverted_hammer_exp_inv_19                                        -0.284657
# magnitudeScarcityIsInvertedHammer_exp_inv_4                                 -0.284657
# scarcityByIsInvertedHammer_exp_inv_1                                        -0.284657
# return_is_inverted_hammer_exp_inv_9                                         -0.284657
# return_is_inverted_hammer_exp_inv_8                                         -0.284657
# return_is_inverted_hammer_exp_inv_12                                        -0.284657
# return_is_inverted_hammer_exp_inv_5                                         -0.284657
# return_is_inverted_hammer_exp_inv_10                                        -0.284657
# return_is_inverted_hammer_exp_inv_15                                        -0.284657
# return_is_inverted_hammer_exp_inv_13                                        -0.284657
# return_is_inverted_hammer_exp_inv_2                                         -0.284657
# magnitudeScarcityIsHammer_exp_inv_1                                          0.006953
# ...                                                                               ...
# magnitudeScarcity_hammer_pattern_pow_18                                      0.925331
# magnitudeScarcityIsInvertedHammer_pow_6                                      0.851924
# magnitudeScarcityIsInvertedHammer_pow_4                                      0.757712
# magnitudeScarcityIsInvertedHammer_pow_5                                      0.811069
# magnitudeScarcityIsHammer_pow_8                                             -0.002988
# magnitudeScarcity_hammer_pattern_pow_17                                      0.915372
# magnitudeScarcityIsHammer_pow_7                                             -0.003191
# magnitudeScarcityIsHammer_pow_4                                             -0.004291
# magnitudeScarcityIsHammer_pow_6                                             -0.003454
# magnitudeScarcity_hammer_pattern_pow_16                                      0.903600
# magnitudeScarcityIsHammer_pow_5                                             -0.003805
# magnitudeScarcity_hammer_pattern_pow_15                                      0.889880
# magnitudeScarcity_hammer_pattern_pow_14                                      0.874080
# magnitudeScarcity_hammer_pattern_pow_13                                      0.856073
# magnitudeScarcity_hammer_pattern_pow_2                                       0.401390
# magnitudeScarcity_hammer_pattern_pow_12                                      0.835724
# magnitudeScarcity_hammer_pattern_pow_11                                      0.812884
# magnitudeScarcity_hammer_pattern_pow_10                                      0.787364
# magnitudeScarcity_hammer_pattern_pow_9                                       0.758907
# magnitudeScarcity_hammer_pattern_pow_8                                       0.727142
# magnitudeScarcity_hammer_pattern_pow_3                                       0.485056
# magnitudeScarcity_hammer_pattern_pow_7                                       0.691524
# magnitudeScarcity_hammer_pattern_pow_6                                       0.651238
# magnitudeScarcity_hammer_pattern_pow_4                                       0.550867
# magnitudeScarcity_hammer_pattern_pow_5                                       0.605037
# close                                                                        0.096909
# low                                                                          0.098076
# high                                                                         0.097598
# open                                                                         0.096601
# scarcityByIsHammer_exp_8                                                          NaN
#
#                                              magnitudeScarcity_hammer_pattern_pow_19
# magnitudeScarcity_hammer_pattern_exp_inv_1                                 -0.246223
# magnitudeScarcity_hammer_pattern_exp_inv_2                                 -0.246221
# magnitudeScarcity_hammer_pattern_exp_inv_3                                 -0.246221
# magnitudeScarcity_hammer_pattern_exp_inv_4                                 -0.246221
# magnitudeScarcity_hammer_pattern_exp_inv_5                                 -0.246221
# magnitudeScarcityIsInvertedHammer_exp_inv_1                                -0.263436
# magnitudeScarcityIsInvertedHammer_exp_inv_2                                -0.263435
# magnitudeScarcityIsInvertedHammer_exp_inv_3                                -0.263435
# return_is_inverted_hammer_exp_inv_4                                        -0.263435
# return_is_inverted_hammer_exp_inv_11                                       -0.263435
# return_is_inverted_hammer_exp_inv_1                                        -0.263435
# return_is_inverted_hammer_exp_inv_17                                       -0.263435
# return_is_inverted_hammer_exp_inv_18                                       -0.263435
# return_is_inverted_hammer_exp_inv_6                                        -0.263435
# return_is_inverted_hammer_exp_inv_16                                       -0.263435
# return_is_inverted_hammer_exp_inv_3                                        -0.263435
# return_is_inverted_hammer_exp_inv_14                                       -0.263435
# return_is_inverted_hammer_exp_inv_7                                        -0.263435
# return_is_inverted_hammer_exp_inv_19                                       -0.263435
# magnitudeScarcityIsInvertedHammer_exp_inv_4                                -0.263435
# scarcityByIsInvertedHammer_exp_inv_1                                       -0.263435
# return_is_inverted_hammer_exp_inv_9                                        -0.263435
# return_is_inverted_hammer_exp_inv_8                                        -0.263435
# return_is_inverted_hammer_exp_inv_12                                       -0.263435
# return_is_inverted_hammer_exp_inv_5                                        -0.263435
# return_is_inverted_hammer_exp_inv_10                                       -0.263435
# return_is_inverted_hammer_exp_inv_15                                       -0.263435
# return_is_inverted_hammer_exp_inv_13                                       -0.263435
# return_is_inverted_hammer_exp_inv_2                                        -0.263435
# magnitudeScarcityIsHammer_exp_inv_1                                        -0.097145
# ...                                                                              ...
# magnitudeScarcity_hammer_pattern_pow_18                                     0.999334
# magnitudeScarcityIsInvertedHammer_pow_6                                     0.794703
# magnitudeScarcityIsInvertedHammer_pow_4                                     0.706380
# magnitudeScarcityIsInvertedHammer_pow_5                                     0.756404
# magnitudeScarcityIsHammer_pow_8                                             0.326523
# magnitudeScarcity_hammer_pattern_pow_17                                     0.997215
# magnitudeScarcityIsHammer_pow_7                                             0.317971
# magnitudeScarcityIsHammer_pow_4                                             0.274195
# magnitudeScarcityIsHammer_pow_6                                             0.307097
# magnitudeScarcity_hammer_pattern_pow_16                                     0.993452
# magnitudeScarcityIsHammer_pow_5                                             0.293002
# magnitudeScarcity_hammer_pattern_pow_15                                     0.987850
# magnitudeScarcity_hammer_pattern_pow_14                                     0.980206
# magnitudeScarcity_hammer_pattern_pow_13                                     0.970304
# magnitudeScarcity_hammer_pattern_pow_2                                      0.531772
# magnitudeScarcity_hammer_pattern_pow_12                                     0.957907
# magnitudeScarcity_hammer_pattern_pow_11                                     0.942740
# magnitudeScarcity_hammer_pattern_pow_10                                     0.924459
# magnitudeScarcity_hammer_pattern_pow_9                                      0.902616
# magnitudeScarcity_hammer_pattern_pow_8                                      0.876588
# magnitudeScarcity_hammer_pattern_pow_3                                      0.631524
# magnitudeScarcity_hammer_pattern_pow_7                                      0.845496
# magnitudeScarcity_hammer_pattern_pow_6                                      0.808062
# magnitudeScarcity_hammer_pattern_pow_4                                      0.705329
# magnitudeScarcity_hammer_pattern_pow_5                                      0.762368
# close                                                                       0.128950
# low                                                                         0.129524
# high                                                                        0.129067
# open                                                                        0.128623
# scarcityByIsHammer_exp_8                                                         NaN
#
# [284 rows x 468 columns]

# %%
_reasonableCorelation.sort_values('open',ascending=True)
# Out:
#            open      high       low     close  return_is_hammer  \
# close  0.999298  0.999678  0.999613  1.000000          0.020726
# low    0.999531  0.999257  1.000000  0.999613          0.017621
# high   0.999541  1.000000  0.999257  0.999678          0.017911
# open   1.000000  0.999541  0.999531  0.999298          0.020889
#
#        return_is_inverted_hammer  hammer_pattern  scarcityByIsHammer  \
# close                   0.037054       -0.007699            0.020726
# low                     0.039774       -0.011776            0.017621
# high                    0.038772       -0.010923            0.017911
# open                    0.036610       -0.007294            0.020889
#
#        scarcityByIsInvertedHammer  magnitudeScarcityIsHammer  ...  \
# close                    0.037054                   0.072710  ...
# low                      0.039774                   0.069571  ...
# high                     0.038772                   0.069714  ...
# open                     0.036610                   0.072830  ...
#
#        magnitudeScarcityIsInvertedHammer_exp_inv_19  \
# close                                     -0.037054
# low                                       -0.039774
# high                                      -0.038772
# open                                      -0.036610
#
#        magnitudeScarcity_hammer_pattern_exp_inv_19  return_is_hammer_pow_19  \
# close                                    -0.040125                 0.020726
# low                                      -0.039473                 0.017621
# high                                     -0.039049                 0.017911
# open                                     -0.039964                 0.020889
#
#        return_is_inverted_hammer_pow_19  hammer_pattern_pow_19  \
# close                          0.037054              -0.007699
# low                            0.039774              -0.011776
# high                           0.038772              -0.010923
# open                           0.036610              -0.007294
#
#        scarcityByIsHammer_pow_19  scarcityByIsInvertedHammer_pow_19  \
# close                   0.020726                           0.037054
# low                     0.017621                           0.039774
# high                    0.017911                           0.038772
# open                    0.020889                           0.036610
#
#        magnitudeScarcityIsHammer_pow_19  \
# close                          0.107194
# low                            0.105754
# high                           0.105724
# open                           0.107085
#
#        magnitudeScarcityIsInvertedHammer_pow_19  \
# close                                  0.096909
# low                                    0.098076
# high                                   0.097598
# open                                   0.096601
#
#        magnitudeScarcity_hammer_pattern_pow_19
# close                                 0.128950
# low                                   0.129524
# high                                  0.129067
# open                                  0.128623
#
# [4 rows x 468 columns]

# %%
_reasonableCorelation.sort_values('open',ascending=False)
# Out:
#            open      high       low     close  return_is_hammer  \
# open   1.000000  0.999541  0.999531  0.999298          0.020889
# high   0.999541  1.000000  0.999257  0.999678          0.017911
# low    0.999531  0.999257  1.000000  0.999613          0.017621
# close  0.999298  0.999678  0.999613  1.000000          0.020726
#
#        return_is_inverted_hammer  hammer_pattern  scarcityByIsHammer  \
# open                    0.036610       -0.007294            0.020889
# high                    0.038772       -0.010923            0.017911
# low                     0.039774       -0.011776            0.017621
# close                   0.037054       -0.007699            0.020726
#
#        scarcityByIsInvertedHammer  magnitudeScarcityIsHammer  ...  \
# open                     0.036610                   0.072830  ...
# high                     0.038772                   0.069714  ...
# low                      0.039774                   0.069571  ...
# close                    0.037054                   0.072710  ...
#
#        magnitudeScarcityIsInvertedHammer_exp_inv_19  \
# open                                      -0.036610
# high                                      -0.038772
# low                                       -0.039774
# close                                     -0.037054
#
#        magnitudeScarcity_hammer_pattern_exp_inv_19  return_is_hammer_pow_19  \
# open                                     -0.039964                 0.020889
# high                                     -0.039049                 0.017911
# low                                      -0.039473                 0.017621
# close                                    -0.040125                 0.020726
#
#        return_is_inverted_hammer_pow_19  hammer_pattern_pow_19  \
# open                           0.036610              -0.007294
# high                           0.038772              -0.010923
# low                            0.039774              -0.011776
# close                          0.037054              -0.007699
#
#        scarcityByIsHammer_pow_19  scarcityByIsInvertedHammer_pow_19  \
# open                    0.020889                           0.036610
# high                    0.017911                           0.038772
# low                     0.017621                           0.039774
# close                   0.020726                           0.037054
#
#        magnitudeScarcityIsHammer_pow_19  \
# open                           0.107085
# high                           0.105724
# low                            0.105754
# close                          0.107194
#
#        magnitudeScarcityIsInvertedHammer_pow_19  \
# open                                   0.096601
# high                                   0.097598
# low                                    0.098076
# close                                  0.096909
#
#        magnitudeScarcity_hammer_pattern_pow_19
# open                                  0.128623
# high                                  0.129067
# low                                   0.129524
# close                                 0.128950
#
# [4 rows x 468 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)
