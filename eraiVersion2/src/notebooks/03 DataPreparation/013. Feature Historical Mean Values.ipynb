# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "013_"
requiredMinimumCorrelation = -1

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *
from config import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import getHistoricalMeanFeatures
from dataPreparation.featurePreparation import prepareFeatureWithData

_basicDf = doBasicOperation(dataName, dataFrequency)
print('done')
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
newFeatureDf = getHistoricalMeanFeatures(_basicDf)

featureOfInterest = 'historical mean'

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf = prepareFeatureWithData(dataName,
                dataFrequency,newFeatureDf,
              _basicDf,featureIndexStamp,requiredMinimumCorrelation=requiredMinimumCorrelation)

_newTrainingSetDf.shape,_trainableFeaturesDf.shape
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.7
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py:158: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/013_open_mean60_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/013_open_mean60_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/013_open_mean60_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/013_open_mean60_variations_reasonable_correlation_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/013_open_mean60_trainableFeaturesList.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/013_open_mean60_variations_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/013_open_mean60_variations_correlation_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/013_open_mean60_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/013_open_mean60_variations_list.csv
# newTrainingSetDf shape>>>8350,1628
# trainableFeaturesDf shape>>>8350,252
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  updating config file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  successfully updated config file >>> (try block) /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json with data >>>{"variationDegreeForFeatureGeneration": 20, "requiredMinimumFeatureCorrelationWithOutputData": 0.7, "adani": {"1h": {"preProcessedDataFilePath": "/data/adani/processed/1h/preProcessedData/processedRawData.csv", "trainableFeaturesListFile": "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/013_open_mean60_trainableFeaturesList.csv"}}}
# ((8350, 1628), (8350, 252))

# %%
newFeatureDf.head()
# Out:
#    open_mean60  open_mean50  open_mean40  open_mean30  open_mean20  \
# 0     0.000000        0.000      0.00000     0.000000       0.0000
# 1     0.501667        0.602      0.75250     1.003333       1.5050
# 2     0.997500        1.197      1.49625     1.995000       2.9925
# 3     1.488333        1.786      2.23250     2.976667       4.4650
# 4     1.978333        2.374      2.96750     3.956667       5.9350
#
#    open_mean10  open_mean5  close_mean60  close_mean50  close_mean40  ...  \
# 0        0.000        0.00      0.000000         0.000       0.00000  ...
# 1        3.010        6.02      0.495833         0.595       0.74375  ...
# 2        5.985       11.97      0.986667         1.184       1.48000  ...
# 3        8.930       17.86      1.476667         1.772       2.21500  ...
# 4       11.870       23.74      1.965833         2.359       2.94875  ...
#
#    high_mean20  high_mean10  high_mean5  low_mean60  low_mean50  low_mean40  \
# 0       0.0000        0.000        0.00    0.000000       0.000      0.0000
# 1       1.5100        3.020        6.04    0.495000       0.594      0.7425
# 2       3.0000        6.000       12.00    0.985000       1.182      1.4775
# 3       4.4875        8.975       17.95    1.473333       1.768      2.2100
# 4       5.9600       11.920       23.84    1.958333       2.350      2.9375
#
#    low_mean30  low_mean20  low_mean10  low_mean5
# 0    0.000000       0.000        0.00       0.00
# 1    0.990000       1.485        2.97       5.94
# 2    1.970000       2.955        5.91      11.82
# 3    2.946667       4.420        8.84      17.68
# 4    3.916667       5.875       11.75      23.50
#
# [5 rows x 28 columns]

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(_reasonableCorelation)
# print('done')

_reasonableCorelation.shape
# Out:
# (256, 1628)

# %%
_correlation.corr().sort_values('open',ascending=True)
# Out:
#                             open      high       low     close  open_mean60  \
# low_mean60_exp_inv_1   -0.700156 -0.699943 -0.700084 -0.699921    -0.719368
# close_mean60_exp_inv_1 -0.700119 -0.699906 -0.700047 -0.699884    -0.719331
# open_mean60_exp_inv_1  -0.700107 -0.699894 -0.700035 -0.699872    -0.719316
# high_mean60_exp_inv_1  -0.700069 -0.699856 -0.699998 -0.699834    -0.719277
# low_mean50_exp_inv_1   -0.699258 -0.699045 -0.699187 -0.699023    -0.718420
# ...                          ...       ...       ...       ...          ...
# low_mean40_exp_19            NaN       NaN       NaN       NaN          NaN
# low_mean30_exp_19            NaN       NaN       NaN       NaN          NaN
# low_mean20_exp_19            NaN       NaN       NaN       NaN          NaN
# low_mean10_exp_19            NaN       NaN       NaN       NaN          NaN
# low_mean5_exp_19             NaN       NaN       NaN       NaN          NaN
#
#                         open_mean50  open_mean40  open_mean30  open_mean20  \
# low_mean60_exp_inv_1      -0.720127    -0.720941    -0.721470    -0.721561
# close_mean60_exp_inv_1    -0.720090    -0.720904    -0.721433    -0.721524
# open_mean60_exp_inv_1     -0.720075    -0.720890    -0.721419    -0.721510
# high_mean60_exp_inv_1     -0.720037    -0.720852    -0.721381    -0.721472
# low_mean50_exp_inv_1      -0.719184    -0.720005    -0.720540    -0.720638
# ...                             ...          ...          ...          ...
# low_mean40_exp_19               NaN          NaN          NaN          NaN
# low_mean30_exp_19               NaN          NaN          NaN          NaN
# low_mean20_exp_19               NaN          NaN          NaN          NaN
# low_mean10_exp_19               NaN          NaN          NaN          NaN
# low_mean5_exp_19                NaN          NaN          NaN          NaN
#
#                         open_mean10  ...  high_mean20_pow_19  \
# low_mean60_exp_inv_1      -0.720082  ...           -0.773557
# close_mean60_exp_inv_1    -0.720045  ...           -0.773568
# open_mean60_exp_inv_1     -0.720032  ...           -0.773613
# high_mean60_exp_inv_1     -0.719994  ...           -0.773630
# low_mean50_exp_inv_1      -0.719168  ...           -0.774323
# ...                             ...  ...                 ...
# low_mean40_exp_19               NaN  ...                 NaN
# low_mean30_exp_19               NaN  ...                 NaN
# low_mean20_exp_19               NaN  ...                 NaN
# low_mean10_exp_19               NaN  ...                 NaN
# low_mean5_exp_19                NaN  ...                 NaN
#
#                         high_mean10_pow_19  high_mean5_pow_19  \
# low_mean60_exp_inv_1             -0.770123          -0.767062
# close_mean60_exp_inv_1           -0.770134          -0.767072
# open_mean60_exp_inv_1            -0.770178          -0.767115
# high_mean60_exp_inv_1            -0.770195          -0.767131
# low_mean50_exp_inv_1             -0.770873          -0.767789
# ...                                    ...                ...
# low_mean40_exp_19                      NaN                NaN
# low_mean30_exp_19                      NaN                NaN
# low_mean20_exp_19                      NaN                NaN
# low_mean10_exp_19                      NaN                NaN
# low_mean5_exp_19                       NaN                NaN
#
#                         low_mean60_pow_19  low_mean50_pow_19  \
# low_mean60_exp_inv_1            -0.774078          -0.774780
# close_mean60_exp_inv_1          -0.774084          -0.774787
# open_mean60_exp_inv_1           -0.774123          -0.774829
# high_mean60_exp_inv_1           -0.774134          -0.774842
# low_mean50_exp_inv_1            -0.774669          -0.775436
# ...                                   ...                ...
# low_mean40_exp_19                     NaN                NaN
# low_mean30_exp_19                     NaN                NaN
# low_mean20_exp_19                     NaN                NaN
# low_mean10_exp_19                     NaN                NaN
# low_mean5_exp_19                      NaN                NaN
#
#                         low_mean40_pow_19  low_mean30_pow_19  \
# low_mean60_exp_inv_1            -0.775781          -0.775883
# close_mean60_exp_inv_1          -0.775791          -0.775894
# open_mean60_exp_inv_1           -0.775835          -0.775939
# high_mean60_exp_inv_1           -0.775850          -0.775956
# low_mean50_exp_inv_1            -0.776503          -0.776647
# ...                                   ...                ...
# low_mean40_exp_19                     NaN                NaN
# low_mean30_exp_19                     NaN                NaN
# low_mean20_exp_19                     NaN                NaN
# low_mean10_exp_19                     NaN                NaN
# low_mean5_exp_19                      NaN                NaN
#
#                         low_mean20_pow_19  low_mean10_pow_19  low_mean5_pow_19
# low_mean60_exp_inv_1            -0.773873          -0.770472         -0.767514
# close_mean60_exp_inv_1          -0.773884          -0.770483         -0.767524
# open_mean60_exp_inv_1           -0.773929          -0.770528         -0.767569
# high_mean60_exp_inv_1           -0.773947          -0.770544         -0.767585
# low_mean50_exp_inv_1            -0.774645          -0.771228         -0.768251
# ...                                   ...                ...               ...
# low_mean40_exp_19                     NaN                NaN               NaN
# low_mean30_exp_19                     NaN                NaN               NaN
# low_mean20_exp_19                     NaN                NaN               NaN
# low_mean10_exp_19                     NaN                NaN               NaN
# low_mean5_exp_19                      NaN                NaN               NaN
#
# [1628 rows x 1628 columns]

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(_reasonableCorelation)
# print('done')

# %%
# manullyDecidedIndexList=['open','high','low','close',
#                                              'open_high_diff_exp_1','close_high_diff_exp_1',
#                                             'open_low_diff_exp_inv_1','close_low_diff_exp_inv_2',
#                                              'high_low_diff_exp_inv_2'
#                                             ]
# manuallyDecidedListDf = _reasonableCorelation[manullyDecidedIndexList]

# manuallyDecidedListDf[manuallyDecidedListDf.index.isin(manullyDecidedIndexList)]

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(manuallyDecidedListDf)
# print('done')
