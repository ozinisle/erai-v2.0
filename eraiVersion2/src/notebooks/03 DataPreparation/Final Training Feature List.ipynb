# %%
dataName = 'adani'
dataFrequency = '1h'

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  

module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

# %%
from dataPreparation.featurePreparation import createFinalTrainingFeatureList

result = createFinalTrainingFeatureList(dataName,dataFrequency)
trainingFeatureDF = result[0]
    
trainingFeatureDF.head()
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# filteredFeaturesFolderPath >>> /data/adani/processed/1h/features/filteredFeatures
# declared csv_pattern
# obtained file_list
# initialized trainingFeatureDF
# looping through all the files to create input data
# reading input file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2//data/adani/processed/1h/features/filteredFeatures/006_is_red_candle_trainableFeaturesList.csv ...
# File read - SUCCESS
# reading input file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2//data/adani/processed/1h/features/filteredFeatures/013_open_mean60_trainableFeaturesList.csv ...
# File read - SUCCESS
# reading input file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2//data/adani/processed/1h/features/filteredFeatures/007_redCandlesBySize_trainableFeaturesList.csv ...
# File read - SUCCESS
# reading input file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2//data/adani/processed/1h/features/filteredFeatures/002_open_close_mid_trainableFeaturesList.csv ...
# File read - SUCCESS
# reading input file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2//data/adani/processed/1h/features/filteredFeatures/003_data_magnitude_trainableFeaturesList.csv ...
# File read - SUCCESS
# creating finalTrainingFeatureList in location >>> /data/adani/processed/1h/features/finalTrainingFeatureList.csv
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  updating config file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  successfully updated config file >>> (try block) /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json with data >>>{"variationDegreeForFeatureGeneration": 20, "requiredMinimumFeatureCorrelationWithOutputData": 0.7, "adani": {"1h": {"preProcessedDataFilePath": "/data/adani/processed/1h/preProcessedData/processedRawData.csv", "trainableFeaturesListFile": "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/007_redCandlesBySize_trainableFeaturesList.csv", "finalTrainingFeaturesListFile": "/data/adani/processed/1h/features/finalTrainingFeatureList.csv", "redGreenCandleSizeBoundaries": [[-0.40000000000000213, 0.44999999999999574], [-0.25, 0.25], [-0.14999999999999858, 0.14999999999999858], [-0.09999999999999432, 0.05000000000000426]]}}}
# updated config file with data >>>> finalTrainingFeaturesListFile:/data/adani/processed/1h/features/finalTrainingFeatureList.csv
#     open   high    low  close  green_red_vector_pow_2  green_red_vector_pow_4  \
# 0  30.10  30.20  29.70  29.75              224.075156            50209.675648
# 1  29.75  29.80  29.40  29.45              219.047812            47981.944161
# 2  29.45  29.75  29.30  29.40              217.200938            47176.247251
# 3  29.40  29.45  29.10  29.35              214.993437            46222.178168
# 4  29.35  30.65  29.25  30.50              224.166094            50250.437587
#
#    green_red_vector_pow_6  green_red_vector_pow_8  open_mean60  open_mean50  \
# 0            1.125074e+07            2.521012e+09     0.000000        0.000
# 1            1.051034e+07            2.302267e+09     0.501667        0.602
# 2            1.024673e+07            2.225598e+09     0.997500        1.197
# 3            9.937465e+06            2.136490e+09     1.488333        1.786
# 4            1.126444e+07            2.525106e+09     1.978333        2.374
#
#    ...  high_low_mid_pow_9  data_magnitude  data_magnitude_pow_2  \
# 0  ...        1.938972e+13       14.969140            224.075156
# 1  ...        1.744317e+13       14.800264            219.047812
# 2  ...        1.704940e+13       14.737739            217.200938
# 3  ...        1.579327e+13       14.662655            214.993437
# 4  ...        1.938972e+13       14.972177            224.166094
#
#    data_magnitude_pow_3  data_magnitude_pow_4  data_magnitude_pow_5  \
# 0           3354.212414          50209.675648         751595.670695
# 1           3241.965439          47981.944161         710145.437624
# 2           3201.050629          47176.247251         695271.197645
# 3           3152.374498          46222.178168         677739.829525
# 4           3356.254505          50250.437587         752358.462044
#
#    data_magnitude_pow_6  data_magnitude_pow_7  data_magnitude_pow_8  \
# 0          1.125074e+07          1.684139e+08          2.521012e+09
# 1          1.051034e+07          1.555558e+08          2.302267e+09
# 2          1.024673e+07          1.510136e+08          2.225598e+09
# 3          9.937465e+06          1.457096e+08          2.136490e+09
# 4          1.126444e+07          1.686533e+08          2.525106e+09
#
#    data_magnitude_pow_9
# 0          3.773737e+10
# 1          3.407416e+10
# 2          3.280029e+10
# 3          3.132661e+10
# 4          3.780634e+10
#
# [5 rows x 327 columns]
