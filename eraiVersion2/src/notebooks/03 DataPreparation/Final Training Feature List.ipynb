# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "000_"
variation_degree=20
requiredMinimumCorrelation = .2
autoConfigFileRelativePath = '\\src\config\\autoConfig\\config.json'
KEY_preProcessedDataFilePath='preProcessedDataFilePath'

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  

module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

# %%
from dataPreparation.featurePreparation import createFinalTrainingFeatureList

result = createFinalTrainingFeatureList(dataName,dataFrequency,autoConfigFileRelativePath,KEY_preProcessedDataFilePath,variation_degree)
trainingFeatureDF = result[0]
    
trainingFeatureDF.head()
# Out:
# into method doBasicOperation
# jupyterNodePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2
# configFilePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
#  retrieving values configured in >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\config\autoConfig\config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# filteredFeaturesFolderPath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures
# declared csv_pattern
# obtained file_list
# initialized trainingFeatureDF
# looping through all the files to create input data
# reading input file >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures\001_open_close_diff_trainableFeaturesList.csv ...
# File read - SUCCESS
# ...
