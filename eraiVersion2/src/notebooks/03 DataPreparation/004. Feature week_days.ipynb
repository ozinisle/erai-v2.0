# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "004_"

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *
from config import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData

_basicDf = doBasicOperation(dataName,dataFrequency)
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation

# %%
import pandas as pd
from utilities.fileFolderManipulations import getJupyterRootDirectory
from config.environment import getAppConfigData

featureOfInterest = 'week_days'

projectRootDirectory = getJupyterRootDirectory()
configData=getAppConfigData()
inputRawProcessedDataDF = pd.read_csv(projectRootDirectory+'/'+configData[dataName][dataFrequency]['preProcessedDataFilePath']) 

newFeatureDf = pd.to_datetime(inputRawProcessedDataDF['date-time'])
newFeatureDf = newFeatureDf.dt.weekday+1
newFeatureDf = pd.concat([newFeatureDf.rename(featureOfInterest)],axis=1)

_correlation, _reasonableCorelation ,_newTrainingSetDf ,_trainableFeaturesDf = prepareFeatureWithData(dataName,dataFrequency,newFeatureDf,
            _basicDf,featureIndexStamp
            )

print('done')
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.7
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/004_week_days_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/004_week_days_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/004_week_days_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/004_week_days_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/004_week_days_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/004_week_days_variations_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/004_week_days_variations_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/004_week_days_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/004_week_days_variations_list.csv
# done

# %%
_reasonableCorelation
# Out:
#            open      high       low     close  week_days  week_days_exp_1  \
# open   1.000000  0.999541  0.999531  0.999298   0.012883         0.018821
# high   0.999541  1.000000  0.999257  0.999678   0.012384         0.018469
# low    0.999531  0.999257  1.000000  0.999613   0.012899         0.018539
# close  0.999298  0.999678  0.999613  1.000000   0.012346         0.018214
#
#        week_days_exp_inv_1  week_days_pow_1  week_days_exp_2  \
# open             -0.008516         0.012883         0.016881
# high             -0.008028         0.012384         0.016659
# low              -0.008848         0.012899         0.016730
# close            -0.008104         0.012346         0.016397
#
#        week_days_exp_inv_2  ...  week_days_pow_16  week_days_exp_17  \
# open             -0.006414  ...          0.012401          0.005469
# high             -0.005997  ...          0.012232          0.005331
# low              -0.006854  ...          0.012375          0.005655
# close            -0.006075  ...          0.012035          0.005223
#
#        week_days_exp_inv_17  week_days_pow_17  week_days_exp_18  \
# open              -0.005228          0.011367          0.005469
# high              -0.004869          0.011204          0.005331
# low               -0.005710          0.011372          0.005655
# close             -0.004931          0.011021          0.005223
#
#        week_days_exp_inv_18  week_days_pow_18  week_days_exp_19  \
# open              -0.005228          0.010487          0.005469
# high              -0.004869          0.010329          0.005331
# low               -0.005710          0.010518          0.005655
# close             -0.004931          0.010158          0.005223
#
#        week_days_exp_inv_19  week_days_pow_19
# open              -0.005228          0.009742
# high              -0.004869          0.009587
# low               -0.005710          0.009795
# close             -0.004931          0.009426
#
# [4 rows x 62 columns]

# %%
_correlation.sort_values('open',ascending=True)
# Out:
#                          open      high       low     close  week_days  \
# week_days_exp_inv_1 -0.008516 -0.008028 -0.008848 -0.008104  -0.884923
# week_days_exp_inv_2 -0.006414 -0.005997 -0.006854 -0.006075  -0.776447
# week_days_exp_inv_3 -0.005655 -0.005273 -0.006124 -0.005343  -0.731977
# week_days_exp_inv_4 -0.005384 -0.005016 -0.005861 -0.005081  -0.715384
# week_days_exp_inv_5 -0.005285 -0.004923 -0.005765 -0.004986  -0.709263
# ...                       ...       ...       ...       ...        ...
# week_days_pow_9      0.021474  0.021210  0.021145  0.020878   0.579891
# close                0.999298  0.999678  0.999613  1.000000   0.012346
# low                  0.999531  0.999257  1.000000  0.999613   0.012899
# high                 0.999541  1.000000  0.999257  0.999678   0.012384
# open                 1.000000  0.999541  0.999531  0.999298   0.012883
#
#                      week_days_exp_1  week_days_exp_inv_1  week_days_pow_1  \
# week_days_exp_inv_1        -0.567778             1.000000        -0.884923
# week_days_exp_inv_2        -0.442545             0.976511        -0.776447
# week_days_exp_inv_3        -0.401295             0.956264        -0.731977
# week_days_exp_inv_4        -0.387069             0.947351        -0.715384
# week_days_exp_inv_5        -0.381967             0.943881        -0.709263
# ...                              ...                  ...              ...
# week_days_pow_9             0.894706            -0.336961         0.579891
# close                       0.018214            -0.008104         0.012346
# low                         0.018539            -0.008848         0.012899
# high                        0.018469            -0.008028         0.012384
# open                        0.018821            -0.008516         0.012883
#
#                      week_days_exp_2  week_days_exp_inv_2  ...  \
# week_days_exp_inv_1        -0.181690             0.976511  ...
# week_days_exp_inv_2        -0.134420             1.000000  ...
# week_days_exp_inv_3        -0.120372             0.996657  ...
# week_days_exp_inv_4        -0.115687             0.993736  ...
# week_days_exp_inv_5        -0.114026             0.992431  ...
# ...                              ...                  ...  ...
# week_days_pow_9             0.912324            -0.249433  ...
# close                       0.016397            -0.006075  ...
# low                         0.016730            -0.006854  ...
# high                        0.016659            -0.005997  ...
# open                        0.016881            -0.006414  ...
#
#                      week_days_pow_16  week_days_exp_17  week_days_exp_inv_17  \
# week_days_exp_inv_1         -0.058499         -0.016232              0.941815
# week_days_exp_inv_2         -0.042219         -0.011288              0.991614
# week_days_exp_inv_3         -0.037709         -0.010071              0.998846
# week_days_exp_inv_4         -0.036225         -0.009674              0.999843
# week_days_exp_inv_5         -0.035701         -0.009534              0.999979
# ...                               ...               ...                   ...
# week_days_pow_9              0.772353          0.684644             -0.209576
# close                        0.012035          0.005223             -0.004931
# low                          0.012375          0.005655             -0.005710
# high                         0.012232          0.005331             -0.004869
# open                         0.012401          0.005469             -0.005228
#
#                      week_days_pow_17  week_days_exp_18  week_days_exp_inv_18  \
# week_days_exp_inv_1         -0.046864         -0.016232              0.941815
# week_days_exp_inv_2         -0.033680         -0.011288              0.991614
# week_days_exp_inv_3         -0.030078         -0.010071              0.998846
# week_days_exp_inv_4         -0.028894         -0.009674              0.999843
# week_days_exp_inv_5         -0.028476         -0.009534              0.999979
# ...                               ...               ...                   ...
# week_days_pow_9              0.752709          0.684644             -0.209576
# close                        0.011021          0.005223             -0.004931
# low                          0.011372          0.005655             -0.005710
# high                         0.011204          0.005331             -0.004869
# open                         0.011367          0.005469             -0.005228
#
#                      week_days_pow_18  week_days_exp_19  week_days_exp_inv_19  \
# week_days_exp_inv_1         -0.038477         -0.016232              0.941815
# week_days_exp_inv_2         -0.027533         -0.011288              0.991614
# week_days_exp_inv_3         -0.024584         -0.010071              0.998846
# week_days_exp_inv_4         -0.023616         -0.009674              0.999843
# week_days_exp_inv_5         -0.023275         -0.009534              0.999979
# ...                               ...               ...                   ...
# week_days_pow_9              0.737616          0.684644             -0.209576
# close                        0.010158          0.005223             -0.004931
# low                          0.010518          0.005655             -0.005710
# high                         0.010329          0.005331             -0.004869
# open                         0.010487          0.005469             -0.005228
#
#                      week_days_pow_19
# week_days_exp_inv_1         -0.032435
# week_days_exp_inv_2         -0.023108
# week_days_exp_inv_3         -0.020630
# week_days_exp_inv_4         -0.019818
# week_days_exp_inv_5         -0.019531
# ...                               ...
# week_days_pow_9              0.726072
# close                        0.009426
# low                          0.009795
# high                         0.009587
# open                         0.009742
#
# [61 rows x 62 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)
print('done')
# Out:
# done
