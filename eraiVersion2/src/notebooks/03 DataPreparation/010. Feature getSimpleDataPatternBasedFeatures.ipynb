# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "010_"
variation_degree=20
requiredMinimumCorrelation = .2
autoConfigFileRelativePath = '/src/config/autoConfig/config.json'
KEY_preProcessedDataFilePath='preProcessedDataFilePath'

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData
from dataPreparation.resolveDataPatterns import getSimpleDataPatternBasedFeatures

_basicDf,_variation_degree,_preProcessedDataFilePath,_autoConfigData,_configFilePath = doBasicOperation(dataName,
       dataFrequency,autoConfigFileRelativePath,KEY_preProcessedDataFilePath,variation_degree)

print('done')
# Out:
# done
# into method doBasicOperation
# jupyterNodePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2
# configFilePath >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2/src/config/autoConfig/config.json
#  retrieving values configured in >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2/src/config/autoConfig/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
import pandas as pd
import numpy as np

featureOfInterest = 'Simple Data Patterns'

m = _basicDf.shape[0]

newFeatureDf = getSimpleDataPatternBasedFeatures(_basicDf)

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf= prepareFeatureWithData(newFeatureDf,
            _basicDf,_variation_degree,_preProcessedDataFilePath,
            _configFilePath,requiredMinimumCorrelation,featureIndexStamp,
            dataName,dataFrequency,useVersion2=True)
# Out:
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_green'][calcDf['close']- calcDf['open']>0] =  1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:186: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_red'][calcDf['close']- calcDf['open']<0] =  1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_doji'][calcDf['relativeOpenCloseValuePercent'] <= relativeOpenCloseValuePercent_config] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['isLongLeggedCandle'][(calcDf['high']-calcDf['low'])>= shortLegBoundary_config] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:222: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:228: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:247: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:253: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:272: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:279: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:300: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:307: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:334: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (calcDf['open'] >= calcDf['hanging_man_boundary'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (calcDf['close'] >= calcDf['hanging_man_boundary'])] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:366: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_Marubozu'][calcDf['highLowDiffAbsolute']==calcDf['openCloseDiffAbsolute']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:371: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_shavenHead'][(calcDf['is_Marubozu']==0) & ((calcDf['open']==calcDf['high']) | (calcDf['close']==calcDf['high']))] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_shavenBottom'][(calcDf['is_Marubozu']==0) & ((calcDf['open']==calcDf['low']) | (calcDf['close']==calcDf['low']))] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:409: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_shooting_star'][(calcDf['is_long_lower_shadow']==1) & (calcDf['is_green']==1)] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:453: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py:433: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\preProcessedData
# outputFolderPath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features
# featuresFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures
# rawFeaturesFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures
# filteredFeaturesFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations
# correlationsFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures\009_is_doji_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures\009_is_doji_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\009_is_doji_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations\009_is_doji_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\filteredFeatures\009_is_doji_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures\009_is_doji_variations_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\009_is_doji_variations_correlation_list.csv
# cannot delete file as the file does not exist >>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\correlations\reasonableCorrelations\009_is_doji_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\rawFeatures\009_is_doji_variations_list.csv

# %%
#_correlation.shape
_correlation.sort_values('open',ascending=True)
# Out:
#                                   open      high       low     close  \
# is_longLeggedDoji_exp_inv_5  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_10 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_1  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_4  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_14 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_9  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_12 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_17 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_7  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_13 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_11 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_15 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_18 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_19 -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_6  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_3  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_8  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_2  -0.121614 -0.124127 -0.120369 -0.122474
# is_longLeggedDoji_exp_inv_16 -0.121614 -0.124127 -0.120369 -0.122474
# is_shavenBottom_exp_15       -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_1        -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_17       -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_6        -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_10       -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_2        -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_16       -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_4        -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_9        -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom_exp_12       -0.073292 -0.069724 -0.067256 -0.069361
# is_shavenBottom              -0.073292 -0.069724 -0.067256 -0.069361
# ...                                ...       ...       ...       ...
# is_shavenBottom_exp_inv_4     0.073292  0.069724  0.067256  0.069361
# is_shavenBottom_exp_inv_5     0.073292  0.069724  0.067256  0.069361
# is_shavenBottom_exp_inv_9     0.073292  0.069724  0.067256  0.069361
# is_shavenBottom_exp_inv_3     0.073292  0.069724  0.067256  0.069361
# is_shavenBottom_exp_inv_14    0.073292  0.069724  0.067256  0.069361
# is_shavenBottom_exp_inv_18    0.073292  0.069724  0.067256  0.069361
# is_longLeggedDoji             0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_12      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_2       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_4       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_16      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_18      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_5       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_9       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_17      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_13      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_8       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_10      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_19      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_15      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_11      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_14      0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_1       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_6       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_3       0.121614  0.124127  0.120369  0.122474
# is_longLeggedDoji_exp_7       0.121614  0.124127  0.120369  0.122474
# close                         0.999298  0.999678  0.999613  1.000000
# low                           0.999531  0.999257  1.000000  0.999613
# high                          0.999541  1.000000  0.999257  0.999678
# open                          1.000000  0.999541  0.999531  0.999298
#
#                                is_doji  is_longLeggedDoji  is_dragonFlyDoji  \
# is_longLeggedDoji_exp_inv_5  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_10 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_1  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_4  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_14 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_9  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_12 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_17 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_7  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_13 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_11 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_15 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_18 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_19 -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_6  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_3  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_8  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_2  -0.052799          -1.000000         -0.080029
# is_longLeggedDoji_exp_inv_16 -0.052799          -1.000000         -0.080029
# is_shavenBottom_exp_15       -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_1        -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_17       -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_6        -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_10       -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_2        -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_16       -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_4        -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_9        -0.007738          -0.028658         -0.016143
# is_shavenBottom_exp_12       -0.007738          -0.028658         -0.016143
# is_shavenBottom              -0.007738          -0.028658         -0.016143
# ...                                ...                ...               ...
# is_shavenBottom_exp_inv_4     0.007738           0.028658          0.016143
# is_shavenBottom_exp_inv_5     0.007738           0.028658          0.016143
# is_shavenBottom_exp_inv_9     0.007738           0.028658          0.016143
# is_shavenBottom_exp_inv_3     0.007738           0.028658          0.016143
# is_shavenBottom_exp_inv_14    0.007738           0.028658          0.016143
# is_shavenBottom_exp_inv_18    0.007738           0.028658          0.016143
# is_longLeggedDoji             0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_12      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_2       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_4       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_16      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_18      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_5       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_9       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_17      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_13      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_8       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_10      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_19      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_15      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_11      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_14      0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_1       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_6       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_3       0.052799           1.000000          0.080029
# is_longLeggedDoji_exp_7       0.052799           1.000000          0.080029
# close                         0.011473           0.122474          0.051644
# low                           0.022954           0.120369          0.049248
# high                          0.000967           0.124127          0.050754
# open                          0.011508           0.121614          0.051282
#
#                               is_graveStoneDoji  is_hammer  \
# is_longLeggedDoji_exp_inv_5           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_10          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_1           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_4           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_14          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_9           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_12          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_17          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_7           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_13          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_11          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_15          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_18          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_19          -0.058481   0.002407
# is_longLeggedDoji_exp_inv_6           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_3           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_8           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_2           -0.058481   0.002407
# is_longLeggedDoji_exp_inv_16          -0.058481   0.002407
# is_shavenBottom_exp_15                 0.107178  -0.009019
# is_shavenBottom_exp_1                  0.107178  -0.009019
# is_shavenBottom_exp_17                 0.107178  -0.009019
# is_shavenBottom_exp_6                  0.107178  -0.009019
# is_shavenBottom_exp_10                 0.107178  -0.009019
# is_shavenBottom_exp_2                  0.107178  -0.009019
# is_shavenBottom_exp_16                 0.107178  -0.009019
# is_shavenBottom_exp_4                  0.107178  -0.009019
# is_shavenBottom_exp_9                  0.107178  -0.009019
# is_shavenBottom_exp_12                 0.107178  -0.009019
# is_shavenBottom                        0.107178  -0.009019
# ...                                         ...        ...
# is_shavenBottom_exp_inv_4             -0.107178   0.009019
# is_shavenBottom_exp_inv_5             -0.107178   0.009019
# is_shavenBottom_exp_inv_9             -0.107178   0.009019
# is_shavenBottom_exp_inv_3             -0.107178   0.009019
# is_shavenBottom_exp_inv_14            -0.107178   0.009019
# is_shavenBottom_exp_inv_18            -0.107178   0.009019
# is_longLeggedDoji                      0.058481  -0.002407
# is_longLeggedDoji_exp_12               0.058481  -0.002407
# is_longLeggedDoji_exp_2                0.058481  -0.002407
# is_longLeggedDoji_exp_4                0.058481  -0.002407
# is_longLeggedDoji_exp_16               0.058481  -0.002407
# is_longLeggedDoji_exp_18               0.058481  -0.002407
# is_longLeggedDoji_exp_5                0.058481  -0.002407
# is_longLeggedDoji_exp_9                0.058481  -0.002407
# is_longLeggedDoji_exp_17               0.058481  -0.002407
# is_longLeggedDoji_exp_13               0.058481  -0.002407
# is_longLeggedDoji_exp_8                0.058481  -0.002407
# is_longLeggedDoji_exp_10               0.058481  -0.002407
# is_longLeggedDoji_exp_19               0.058481  -0.002407
# is_longLeggedDoji_exp_15               0.058481  -0.002407
# is_longLeggedDoji_exp_11               0.058481  -0.002407
# is_longLeggedDoji_exp_14               0.058481  -0.002407
# is_longLeggedDoji_exp_1                0.058481  -0.002407
# is_longLeggedDoji_exp_6                0.058481  -0.002407
# is_longLeggedDoji_exp_3                0.058481  -0.002407
# is_longLeggedDoji_exp_7                0.058481  -0.002407
# close                                  0.057968  -0.007578
# low                                    0.058282  -0.010262
# high                                   0.059554  -0.007307
# open                                   0.056989  -0.007044
#
#                               is_inverted_hammer  ...  is_hammer_pow_19  \
# is_longLeggedDoji_exp_inv_5             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_10            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_1             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_4             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_14            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_9             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_12            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_17            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_7             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_13            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_11            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_15            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_18            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_19            0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_6             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_3             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_8             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_2             0.016737  ...          0.002407
# is_longLeggedDoji_exp_inv_16            0.016737  ...          0.002407
# is_shavenBottom_exp_15                  0.066772  ...         -0.009019
# is_shavenBottom_exp_1                   0.066772  ...         -0.009019
# is_shavenBottom_exp_17                  0.066772  ...         -0.009019
# is_shavenBottom_exp_6                   0.066772  ...         -0.009019
# is_shavenBottom_exp_10                  0.066772  ...         -0.009019
# is_shavenBottom_exp_2                   0.066772  ...         -0.009019
# is_shavenBottom_exp_16                  0.066772  ...         -0.009019
# is_shavenBottom_exp_4                   0.066772  ...         -0.009019
# is_shavenBottom_exp_9                   0.066772  ...         -0.009019
# is_shavenBottom_exp_12                  0.066772  ...         -0.009019
# is_shavenBottom                         0.066772  ...         -0.009019
# ...                                          ...  ...               ...
# is_shavenBottom_exp_inv_4              -0.066772  ...          0.009019
# is_shavenBottom_exp_inv_5              -0.066772  ...          0.009019
# is_shavenBottom_exp_inv_9              -0.066772  ...          0.009019
# is_shavenBottom_exp_inv_3              -0.066772  ...          0.009019
# is_shavenBottom_exp_inv_14             -0.066772  ...          0.009019
# is_shavenBottom_exp_inv_18             -0.066772  ...          0.009019
# is_longLeggedDoji                      -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_12               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_2                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_4                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_16               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_18               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_5                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_9                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_17               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_13               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_8                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_10               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_19               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_15               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_11               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_14               -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_1                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_6                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_3                -0.016737  ...         -0.002407
# is_longLeggedDoji_exp_7                -0.016737  ...         -0.002407
# close                                  -0.005006  ...         -0.007578
# low                                    -0.001771  ...         -0.010262
# high                                    0.003560  ...         -0.007307
# open                                    0.005612  ...         -0.007044
#
#                               is_inverted_hammer_pow_19  is_HangingMan_pow_19  \
# is_longLeggedDoji_exp_inv_5                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_10                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_1                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_4                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_14                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_9                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_12                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_17                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_7                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_13                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_11                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_15                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_18                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_19                   0.016737             -0.029940
# is_longLeggedDoji_exp_inv_6                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_3                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_8                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_2                    0.016737             -0.029940
# is_longLeggedDoji_exp_inv_16                   0.016737             -0.029940
# is_shavenBottom_exp_15                         0.066772             -0.156551
# is_shavenBottom_exp_1                          0.066772             -0.156551
# is_shavenBottom_exp_17                         0.066772             -0.156551
# is_shavenBottom_exp_6                          0.066772             -0.156551
# is_shavenBottom_exp_10                         0.066772             -0.156551
# is_shavenBottom_exp_2                          0.066772             -0.156551
# is_shavenBottom_exp_16                         0.066772             -0.156551
# is_shavenBottom_exp_4                          0.066772             -0.156551
# is_shavenBottom_exp_9                          0.066772             -0.156551
# is_shavenBottom_exp_12                         0.066772             -0.156551
# is_shavenBottom                                0.066772             -0.156551
# ...                                                 ...                   ...
# is_shavenBottom_exp_inv_4                     -0.066772              0.156551
# is_shavenBottom_exp_inv_5                     -0.066772              0.156551
# is_shavenBottom_exp_inv_9                     -0.066772              0.156551
# is_shavenBottom_exp_inv_3                     -0.066772              0.156551
# is_shavenBottom_exp_inv_14                    -0.066772              0.156551
# is_shavenBottom_exp_inv_18                    -0.066772              0.156551
# is_longLeggedDoji                             -0.016737              0.029940
# is_longLeggedDoji_exp_12                      -0.016737              0.029940
# is_longLeggedDoji_exp_2                       -0.016737              0.029940
# is_longLeggedDoji_exp_4                       -0.016737              0.029940
# is_longLeggedDoji_exp_16                      -0.016737              0.029940
# is_longLeggedDoji_exp_18                      -0.016737              0.029940
# is_longLeggedDoji_exp_5                       -0.016737              0.029940
# is_longLeggedDoji_exp_9                       -0.016737              0.029940
# is_longLeggedDoji_exp_17                      -0.016737              0.029940
# is_longLeggedDoji_exp_13                      -0.016737              0.029940
# is_longLeggedDoji_exp_8                       -0.016737              0.029940
# is_longLeggedDoji_exp_10                      -0.016737              0.029940
# is_longLeggedDoji_exp_19                      -0.016737              0.029940
# is_longLeggedDoji_exp_15                      -0.016737              0.029940
# is_longLeggedDoji_exp_11                      -0.016737              0.029940
# is_longLeggedDoji_exp_14                      -0.016737              0.029940
# is_longLeggedDoji_exp_1                       -0.016737              0.029940
# is_longLeggedDoji_exp_6                       -0.016737              0.029940
# is_longLeggedDoji_exp_3                       -0.016737              0.029940
# is_longLeggedDoji_exp_7                       -0.016737              0.029940
# close                                         -0.005006              0.005412
# low                                           -0.001771              0.002323
# high                                           0.003560              0.000860
# open                                           0.005612              0.006416
#
#                               is_Marubozu_pow_19  is_shavenHead_pow_19  \
# is_longLeggedDoji_exp_inv_5             0.012076              0.031291
# is_longLeggedDoji_exp_inv_10            0.012076              0.031291
# is_longLeggedDoji_exp_inv_1             0.012076              0.031291
# is_longLeggedDoji_exp_inv_4             0.012076              0.031291
# is_longLeggedDoji_exp_inv_14            0.012076              0.031291
# is_longLeggedDoji_exp_inv_9             0.012076              0.031291
# is_longLeggedDoji_exp_inv_12            0.012076              0.031291
# is_longLeggedDoji_exp_inv_17            0.012076              0.031291
# is_longLeggedDoji_exp_inv_7             0.012076              0.031291
# is_longLeggedDoji_exp_inv_13            0.012076              0.031291
# is_longLeggedDoji_exp_inv_11            0.012076              0.031291
# is_longLeggedDoji_exp_inv_15            0.012076              0.031291
# is_longLeggedDoji_exp_inv_18            0.012076              0.031291
# is_longLeggedDoji_exp_inv_19            0.012076              0.031291
# is_longLeggedDoji_exp_inv_6             0.012076              0.031291
# is_longLeggedDoji_exp_inv_3             0.012076              0.031291
# is_longLeggedDoji_exp_inv_8             0.012076              0.031291
# is_longLeggedDoji_exp_inv_2             0.012076              0.031291
# is_longLeggedDoji_exp_inv_16            0.012076              0.031291
# is_shavenBottom_exp_15                 -0.045235             -0.144338
# is_shavenBottom_exp_1                  -0.045235             -0.144338
# is_shavenBottom_exp_17                 -0.045235             -0.144338
# is_shavenBottom_exp_6                  -0.045235             -0.144338
# is_shavenBottom_exp_10                 -0.045235             -0.144338
# is_shavenBottom_exp_2                  -0.045235             -0.144338
# is_shavenBottom_exp_16                 -0.045235             -0.144338
# is_shavenBottom_exp_4                  -0.045235             -0.144338
# is_shavenBottom_exp_9                  -0.045235             -0.144338
# is_shavenBottom_exp_12                 -0.045235             -0.144338
# is_shavenBottom                        -0.045235             -0.144338
# ...                                          ...                   ...
# is_shavenBottom_exp_inv_4               0.045235              0.144338
# is_shavenBottom_exp_inv_5               0.045235              0.144338
# is_shavenBottom_exp_inv_9               0.045235              0.144338
# is_shavenBottom_exp_inv_3               0.045235              0.144338
# is_shavenBottom_exp_inv_14              0.045235              0.144338
# is_shavenBottom_exp_inv_18              0.045235              0.144338
# is_longLeggedDoji                      -0.012076             -0.031291
# is_longLeggedDoji_exp_12               -0.012076             -0.031291
# is_longLeggedDoji_exp_2                -0.012076             -0.031291
# is_longLeggedDoji_exp_4                -0.012076             -0.031291
# is_longLeggedDoji_exp_16               -0.012076             -0.031291
# is_longLeggedDoji_exp_18               -0.012076             -0.031291
# is_longLeggedDoji_exp_5                -0.012076             -0.031291
# is_longLeggedDoji_exp_9                -0.012076             -0.031291
# is_longLeggedDoji_exp_17               -0.012076             -0.031291
# is_longLeggedDoji_exp_13               -0.012076             -0.031291
# is_longLeggedDoji_exp_8                -0.012076             -0.031291
# is_longLeggedDoji_exp_10               -0.012076             -0.031291
# is_longLeggedDoji_exp_19               -0.012076             -0.031291
# is_longLeggedDoji_exp_15               -0.012076             -0.031291
# is_longLeggedDoji_exp_11               -0.012076             -0.031291
# is_longLeggedDoji_exp_14               -0.012076             -0.031291
# is_longLeggedDoji_exp_1                -0.012076             -0.031291
# is_longLeggedDoji_exp_6                -0.012076             -0.031291
# is_longLeggedDoji_exp_3                -0.012076             -0.031291
# is_longLeggedDoji_exp_7                -0.012076             -0.031291
# close                                  -0.040017             -0.063553
# low                                    -0.039221             -0.063003
# high                                   -0.041092             -0.064480
# open                                   -0.040354             -0.058150
#
#                               is_shavenBottom_pow_19  \
# is_longLeggedDoji_exp_inv_5                 0.028658
# is_longLeggedDoji_exp_inv_10                0.028658
# is_longLeggedDoji_exp_inv_1                 0.028658
# is_longLeggedDoji_exp_inv_4                 0.028658
# is_longLeggedDoji_exp_inv_14                0.028658
# is_longLeggedDoji_exp_inv_9                 0.028658
# is_longLeggedDoji_exp_inv_12                0.028658
# is_longLeggedDoji_exp_inv_17                0.028658
# is_longLeggedDoji_exp_inv_7                 0.028658
# is_longLeggedDoji_exp_inv_13                0.028658
# is_longLeggedDoji_exp_inv_11                0.028658
# is_longLeggedDoji_exp_inv_15                0.028658
# is_longLeggedDoji_exp_inv_18                0.028658
# is_longLeggedDoji_exp_inv_19                0.028658
# is_longLeggedDoji_exp_inv_6                 0.028658
# is_longLeggedDoji_exp_inv_3                 0.028658
# is_longLeggedDoji_exp_inv_8                 0.028658
# is_longLeggedDoji_exp_inv_2                 0.028658
# is_longLeggedDoji_exp_inv_16                0.028658
# is_shavenBottom_exp_15                      1.000000
# is_shavenBottom_exp_1                       1.000000
# is_shavenBottom_exp_17                      1.000000
# is_shavenBottom_exp_6                       1.000000
# is_shavenBottom_exp_10                      1.000000
# is_shavenBottom_exp_2                       1.000000
# is_shavenBottom_exp_16                      1.000000
# is_shavenBottom_exp_4                       1.000000
# is_shavenBottom_exp_9                       1.000000
# is_shavenBottom_exp_12                      1.000000
# is_shavenBottom                             1.000000
# ...                                              ...
# is_shavenBottom_exp_inv_4                  -1.000000
# is_shavenBottom_exp_inv_5                  -1.000000
# is_shavenBottom_exp_inv_9                  -1.000000
# is_shavenBottom_exp_inv_3                  -1.000000
# is_shavenBottom_exp_inv_14                 -1.000000
# is_shavenBottom_exp_inv_18                 -1.000000
# is_longLeggedDoji                          -0.028658
# is_longLeggedDoji_exp_12                   -0.028658
# is_longLeggedDoji_exp_2                    -0.028658
# is_longLeggedDoji_exp_4                    -0.028658
# is_longLeggedDoji_exp_16                   -0.028658
# is_longLeggedDoji_exp_18                   -0.028658
# is_longLeggedDoji_exp_5                    -0.028658
# is_longLeggedDoji_exp_9                    -0.028658
# is_longLeggedDoji_exp_17                   -0.028658
# is_longLeggedDoji_exp_13                   -0.028658
# is_longLeggedDoji_exp_8                    -0.028658
# is_longLeggedDoji_exp_10                   -0.028658
# is_longLeggedDoji_exp_19                   -0.028658
# is_longLeggedDoji_exp_15                   -0.028658
# is_longLeggedDoji_exp_11                   -0.028658
# is_longLeggedDoji_exp_14                   -0.028658
# is_longLeggedDoji_exp_1                    -0.028658
# is_longLeggedDoji_exp_6                    -0.028658
# is_longLeggedDoji_exp_3                    -0.028658
# is_longLeggedDoji_exp_7                    -0.028658
# close                                      -0.069361
# low                                        -0.067256
# high                                       -0.069724
# open                                       -0.073292
#
#                               is_long_lower_shadow_pow_19  \
# is_longLeggedDoji_exp_inv_5                      0.028169
# is_longLeggedDoji_exp_inv_10                     0.028169
# is_longLeggedDoji_exp_inv_1                      0.028169
# is_longLeggedDoji_exp_inv_4                      0.028169
# is_longLeggedDoji_exp_inv_14                     0.028169
# is_longLeggedDoji_exp_inv_9                      0.028169
# is_longLeggedDoji_exp_inv_12                     0.028169
# is_longLeggedDoji_exp_inv_17                     0.028169
# is_longLeggedDoji_exp_inv_7                      0.028169
# is_longLeggedDoji_exp_inv_13                     0.028169
# is_longLeggedDoji_exp_inv_11                     0.028169
# is_longLeggedDoji_exp_inv_15                     0.028169
# is_longLeggedDoji_exp_inv_18                     0.028169
# is_longLeggedDoji_exp_inv_19                     0.028169
# is_longLeggedDoji_exp_inv_6                      0.028169
# is_longLeggedDoji_exp_inv_3                      0.028169
# is_longLeggedDoji_exp_inv_8                      0.028169
# is_longLeggedDoji_exp_inv_2                      0.028169
# is_longLeggedDoji_exp_inv_16                     0.028169
# is_shavenBottom_exp_15                          -0.105521
# is_shavenBottom_exp_1                           -0.105521
# is_shavenBottom_exp_17                          -0.105521
# is_shavenBottom_exp_6                           -0.105521
# is_shavenBottom_exp_10                          -0.105521
# is_shavenBottom_exp_2                           -0.105521
# is_shavenBottom_exp_16                          -0.105521
# is_shavenBottom_exp_4                           -0.105521
# is_shavenBottom_exp_9                           -0.105521
# is_shavenBottom_exp_12                          -0.105521
# is_shavenBottom                                 -0.105521
# ...                                                   ...
# is_shavenBottom_exp_inv_4                        0.105521
# is_shavenBottom_exp_inv_5                        0.105521
# is_shavenBottom_exp_inv_9                        0.105521
# is_shavenBottom_exp_inv_3                        0.105521
# is_shavenBottom_exp_inv_14                       0.105521
# is_shavenBottom_exp_inv_18                       0.105521
# is_longLeggedDoji                               -0.028169
# is_longLeggedDoji_exp_12                        -0.028169
# is_longLeggedDoji_exp_2                         -0.028169
# is_longLeggedDoji_exp_4                         -0.028169
# is_longLeggedDoji_exp_16                        -0.028169
# is_longLeggedDoji_exp_18                        -0.028169
# is_longLeggedDoji_exp_5                         -0.028169
# is_longLeggedDoji_exp_9                         -0.028169
# is_longLeggedDoji_exp_17                        -0.028169
# is_longLeggedDoji_exp_13                        -0.028169
# is_longLeggedDoji_exp_8                         -0.028169
# is_longLeggedDoji_exp_10                        -0.028169
# is_longLeggedDoji_exp_19                        -0.028169
# is_longLeggedDoji_exp_15                        -0.028169
# is_longLeggedDoji_exp_11                        -0.028169
# is_longLeggedDoji_exp_14                        -0.028169
# is_longLeggedDoji_exp_1                         -0.028169
# is_longLeggedDoji_exp_6                         -0.028169
# is_longLeggedDoji_exp_3                         -0.028169
# is_longLeggedDoji_exp_7                         -0.028169
# close                                           -0.028299
# low                                             -0.030427
# high                                            -0.032673
# open                                            -0.028143
#
#                               is_long_upper_shadow_pow_19  \
# is_longLeggedDoji_exp_inv_5                      0.028385
# is_longLeggedDoji_exp_inv_10                     0.028385
# is_longLeggedDoji_exp_inv_1                      0.028385
# is_longLeggedDoji_exp_inv_4                      0.028385
# is_longLeggedDoji_exp_inv_14                     0.028385
# is_longLeggedDoji_exp_inv_9                      0.028385
# is_longLeggedDoji_exp_inv_12                     0.028385
# is_longLeggedDoji_exp_inv_17                     0.028385
# is_longLeggedDoji_exp_inv_7                      0.028385
# is_longLeggedDoji_exp_inv_13                     0.028385
# is_longLeggedDoji_exp_inv_11                     0.028385
# is_longLeggedDoji_exp_inv_15                     0.028385
# is_longLeggedDoji_exp_inv_18                     0.028385
# is_longLeggedDoji_exp_inv_19                     0.028385
# is_longLeggedDoji_exp_inv_6                      0.028385
# is_longLeggedDoji_exp_inv_3                      0.028385
# is_longLeggedDoji_exp_inv_8                      0.028385
# is_longLeggedDoji_exp_inv_2                      0.028385
# is_longLeggedDoji_exp_inv_16                     0.028385
# is_shavenBottom_exp_15                           0.204074
# is_shavenBottom_exp_1                            0.204074
# is_shavenBottom_exp_17                           0.204074
# is_shavenBottom_exp_6                            0.204074
# is_shavenBottom_exp_10                           0.204074
# is_shavenBottom_exp_2                            0.204074
# is_shavenBottom_exp_16                           0.204074
# is_shavenBottom_exp_4                            0.204074
# is_shavenBottom_exp_9                            0.204074
# is_shavenBottom_exp_12                           0.204074
# is_shavenBottom                                  0.204074
# ...                                                   ...
# is_shavenBottom_exp_inv_4                       -0.204074
# is_shavenBottom_exp_inv_5                       -0.204074
# is_shavenBottom_exp_inv_9                       -0.204074
# is_shavenBottom_exp_inv_3                       -0.204074
# is_shavenBottom_exp_inv_14                      -0.204074
# is_shavenBottom_exp_inv_18                      -0.204074
# is_longLeggedDoji                               -0.028385
# is_longLeggedDoji_exp_12                        -0.028385
# is_longLeggedDoji_exp_2                         -0.028385
# is_longLeggedDoji_exp_4                         -0.028385
# is_longLeggedDoji_exp_16                        -0.028385
# is_longLeggedDoji_exp_18                        -0.028385
# is_longLeggedDoji_exp_5                         -0.028385
# is_longLeggedDoji_exp_9                         -0.028385
# is_longLeggedDoji_exp_17                        -0.028385
# is_longLeggedDoji_exp_13                        -0.028385
# is_longLeggedDoji_exp_8                         -0.028385
# is_longLeggedDoji_exp_10                        -0.028385
# is_longLeggedDoji_exp_19                        -0.028385
# is_longLeggedDoji_exp_15                        -0.028385
# is_longLeggedDoji_exp_11                        -0.028385
# is_longLeggedDoji_exp_14                        -0.028385
# is_longLeggedDoji_exp_1                         -0.028385
# is_longLeggedDoji_exp_6                         -0.028385
# is_longLeggedDoji_exp_3                         -0.028385
# is_longLeggedDoji_exp_7                         -0.028385
# close                                           -0.004403
# low                                              0.000278
# high                                            -0.003061
# open                                            -0.004913
#
#                               is_shooting_star_pow_19  is_spinningTop_pow_19
# is_longLeggedDoji_exp_inv_5                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_10                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_1                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_4                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_14                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_9                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_12                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_17                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_7                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_13                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_11                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_15                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_18                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_19                 0.013791               0.041365
# is_longLeggedDoji_exp_inv_6                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_3                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_8                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_2                  0.013791               0.041365
# is_longLeggedDoji_exp_inv_16                 0.013791               0.041365
# is_shavenBottom_exp_15                      -0.051661              -0.154956
# is_shavenBottom_exp_1                       -0.051661              -0.154956
# is_shavenBottom_exp_17                      -0.051661              -0.154956
# is_shavenBottom_exp_6                       -0.051661              -0.154956
# is_shavenBottom_exp_10                      -0.051661              -0.154956
# is_shavenBottom_exp_2                       -0.051661              -0.154956
# is_shavenBottom_exp_16                      -0.051661              -0.154956
# is_shavenBottom_exp_4                       -0.051661              -0.154956
# is_shavenBottom_exp_9                       -0.051661              -0.154956
# is_shavenBottom_exp_12                      -0.051661              -0.154956
# is_shavenBottom                             -0.051661              -0.154956
# ...                                               ...                    ...
# is_shavenBottom_exp_inv_4                    0.051661               0.154956
# is_shavenBottom_exp_inv_5                    0.051661               0.154956
# is_shavenBottom_exp_inv_9                    0.051661               0.154956
# is_shavenBottom_exp_inv_3                    0.051661               0.154956
# is_shavenBottom_exp_inv_14                   0.051661               0.154956
# is_shavenBottom_exp_inv_18                   0.051661               0.154956
# is_longLeggedDoji                           -0.013791              -0.041365
# is_longLeggedDoji_exp_12                    -0.013791              -0.041365
# is_longLeggedDoji_exp_2                     -0.013791              -0.041365
# is_longLeggedDoji_exp_4                     -0.013791              -0.041365
# is_longLeggedDoji_exp_16                    -0.013791              -0.041365
# is_longLeggedDoji_exp_18                    -0.013791              -0.041365
# is_longLeggedDoji_exp_5                     -0.013791              -0.041365
# is_longLeggedDoji_exp_9                     -0.013791              -0.041365
# is_longLeggedDoji_exp_17                    -0.013791              -0.041365
# is_longLeggedDoji_exp_13                    -0.013791              -0.041365
# is_longLeggedDoji_exp_8                     -0.013791              -0.041365
# is_longLeggedDoji_exp_10                    -0.013791              -0.041365
# is_longLeggedDoji_exp_19                    -0.013791              -0.041365
# is_longLeggedDoji_exp_15                    -0.013791              -0.041365
# is_longLeggedDoji_exp_11                    -0.013791              -0.041365
# is_longLeggedDoji_exp_14                    -0.013791              -0.041365
# is_longLeggedDoji_exp_1                     -0.013791              -0.041365
# is_longLeggedDoji_exp_6                     -0.013791              -0.041365
# is_longLeggedDoji_exp_3                     -0.013791              -0.041365
# is_longLeggedDoji_exp_7                     -0.013791              -0.041365
# close                                        0.002623               0.018171
# low                                          0.000325               0.007492
# high                                        -0.000138               0.027073
# open                                         0.001569               0.016620
#
# [550 rows x 816 columns]

# %%
_reasonableCorelation.sort_values('open',ascending=True)
# Out:
#            open      high       low     close   is_doji  is_longLeggedDoji  \
# close  0.999298  0.999678  0.999613  1.000000  0.011473           0.122474
# low    0.999531  0.999257  1.000000  0.999613  0.022954           0.120369
# high   0.999541  1.000000  0.999257  0.999678  0.000967           0.124127
# open   1.000000  0.999541  0.999531  0.999298  0.011508           0.121614
#
#        is_dragonFlyDoji  is_graveStoneDoji  is_hammer  is_inverted_hammer  \
# close          0.051644           0.057968  -0.007578           -0.005006
# low            0.049248           0.058282  -0.010262           -0.001771
# high           0.050754           0.059554  -0.007307            0.003560
# open           0.051282           0.056989  -0.007044            0.005612
#
#        ...  is_hammer_pow_19  is_inverted_hammer_pow_19  is_HangingMan_pow_19  \
# close  ...         -0.007578                  -0.005006              0.005412
# low    ...         -0.010262                  -0.001771              0.002323
# high   ...         -0.007307                   0.003560              0.000860
# open   ...         -0.007044                   0.005612              0.006416
#
#        is_Marubozu_pow_19  is_shavenHead_pow_19  is_shavenBottom_pow_19  \
# close           -0.040017             -0.063553               -0.069361
# low             -0.039221             -0.063003               -0.067256
# high            -0.041092             -0.064480               -0.069724
# open            -0.040354             -0.058150               -0.073292
#
#        is_long_lower_shadow_pow_19  is_long_upper_shadow_pow_19  \
# close                    -0.028299                    -0.004403
# low                      -0.030427                     0.000278
# high                     -0.032673                    -0.003061
# open                     -0.028143                    -0.004913
#
#        is_shooting_star_pow_19  is_spinningTop_pow_19
# close                 0.002623               0.018171
# low                   0.000325               0.007492
# high                 -0.000138               0.027073
# open                  0.001569               0.016620
#
# [4 rows x 816 columns]

# %%
_reasonableCorelation.sort_values('open',ascending=False)
# Out:
#            open      high       low     close   is_doji  is_longLeggedDoji  \
# open   1.000000  0.999541  0.999531  0.999298  0.011508           0.121614
# high   0.999541  1.000000  0.999257  0.999678  0.000967           0.124127
# low    0.999531  0.999257  1.000000  0.999613  0.022954           0.120369
# close  0.999298  0.999678  0.999613  1.000000  0.011473           0.122474
#
#        is_dragonFlyDoji  is_graveStoneDoji  is_hammer  is_inverted_hammer  \
# open           0.051282           0.056989  -0.007044            0.005612
# high           0.050754           0.059554  -0.007307            0.003560
# low            0.049248           0.058282  -0.010262           -0.001771
# close          0.051644           0.057968  -0.007578           -0.005006
#
#        ...  is_hammer_pow_19  is_inverted_hammer_pow_19  is_HangingMan_pow_19  \
# open   ...         -0.007044                   0.005612              0.006416
# high   ...         -0.007307                   0.003560              0.000860
# low    ...         -0.010262                  -0.001771              0.002323
# close  ...         -0.007578                  -0.005006              0.005412
#
#        is_Marubozu_pow_19  is_shavenHead_pow_19  is_shavenBottom_pow_19  \
# open            -0.040354             -0.058150               -0.073292
# high            -0.041092             -0.064480               -0.069724
# low             -0.039221             -0.063003               -0.067256
# close           -0.040017             -0.063553               -0.069361
#
#        is_long_lower_shadow_pow_19  is_long_upper_shadow_pow_19  \
# open                     -0.028143                    -0.004913
# high                     -0.032673                    -0.003061
# low                      -0.030427                     0.000278
# close                    -0.028299                    -0.004403
#
#        is_shooting_star_pow_19  is_spinningTop_pow_19
# open                  0.001569               0.016620
# high                 -0.000138               0.027073
# low                   0.000325               0.007492
# close                 0.002623               0.018171
#
# [4 rows x 816 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)
