# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "003_"

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *
from config import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData

_basicDf = doBasicOperation(dataName,dataFrequency)
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation

# %%
import pandas as pd
import numpy as np
from config.environment import getAppConfigData
from utilities.fileFolderManipulations import getJupyterRootDirectory

featureOfInterest = 'data_magnitude'

projectRootDirectory = getJupyterRootDirectory()
configData=getAppConfigData()
inputRawProcessedDataDF = pd.read_csv(projectRootDirectory+'/'+configData[dataName][dataFrequency]['preProcessedDataFilePath']) 

newFeatureDf = np.divide(np.sqrt(np.sum(np.square(inputRawProcessedDataDF[['open','close','high','low']]),axis=1)),4)
newFeatureDf = pd.concat([newFeatureDf.rename(featureOfInterest)],axis=1)

_correlation, _reasonableCorelation ,_newTrainingSetDf ,_trainableFeaturesDf = prepareFeatureWithData(dataName,dataFrequency,
                                                        newFeatureDf,_basicDf,featureIndexStamp)

print('done')
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.7
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/003_data_magnitude_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/003_data_magnitude_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/003_data_magnitude_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/003_data_magnitude_variations_reasonable_correlation_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/003_data_magnitude_trainableFeaturesList.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/003_data_magnitude_variations_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/003_data_magnitude_variations_correlation_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/003_data_magnitude_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/003_data_magnitude_variations_list.csv
# newTrainingSetDf shape>>>8350,62
# trainableFeaturesDf shape>>>8350,9
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  updating config file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  successfully updated config file >>> (try block) /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json with data >>>{"variationDegreeForFeatureGeneration": 20, "requiredMinimumFeatureCorrelationWithOutputData": 0.7, "adani": {"1h": {"preProcessedDataFilePath": "/data/adani/processed/1h/preProcessedData/processedRawData.csv", "trainableFeaturesListFile": "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/003_data_magnitude_trainableFeaturesList.csv"}}}
# done

# %%
_reasonableCorelation
# Out:
#                           open      high       low     close  data_magnitude  \
# open                  1.000000  0.999541  0.999531  0.999298        0.999786
# high                  0.999541  1.000000  0.999257  0.999678        0.999819
# low                   0.999531  0.999257  1.000000  0.999613        0.999785
# close                 0.999298  0.999678  0.999613  1.000000        0.999840
# data_magnitude        0.999786  0.999819  0.999785  0.999840        1.000000
# data_magnitude_pow_2  0.988834  0.989003  0.988842  0.988944        0.989096
# data_magnitude_pow_3  0.961797  0.962063  0.961852  0.961958        0.962102
# data_magnitude_pow_4  0.925297  0.925630  0.925414  0.925498        0.925636
# data_magnitude_pow_5  0.884018  0.884397  0.884196  0.884248        0.884382
# data_magnitude_pow_6  0.841177  0.841588  0.841405  0.841426        0.841558
# data_magnitude_pow_7  0.798764  0.799196  0.799030  0.799022        0.799154
# data_magnitude_pow_8  0.757823  0.758266  0.758111  0.758081        0.758213
# data_magnitude_pow_9  0.718771  0.719220  0.719072  0.719025        0.719157
#
#                       data_magnitude_exp_1  data_magnitude_exp_inv_1  \
# open                              0.238011                 -0.257936
# high                              0.238191                 -0.257285
# low                               0.237927                 -0.258370
# close                             0.238059                 -0.257871
# data_magnitude                    0.238094                 -0.257912
# data_magnitude_pow_2              0.286377                 -0.189151
# data_magnitude_pow_3              0.337000                 -0.144116
# data_magnitude_pow_4              0.388712                 -0.114964
# data_magnitude_pow_5              0.440292                 -0.095707
# data_magnitude_pow_6              0.490832                 -0.082440
# data_magnitude_pow_7              0.539743                 -0.072808
# data_magnitude_pow_8              0.586637                 -0.065436
# data_magnitude_pow_9              0.631217                 -0.059525
#
#                       data_magnitude_pow_1  data_magnitude_exp_2  \
# open                              0.999786              0.135206
# high                              0.999819              0.135320
# low                               0.999785              0.134984
# close                             0.999840              0.135191
# data_magnitude                    1.000000              0.135202
# data_magnitude_pow_2              0.989096              0.166173
# data_magnitude_pow_3              0.962102              0.200036
# data_magnitude_pow_4              0.925636              0.236069
# data_magnitude_pow_5              0.884382              0.273467
# data_magnitude_pow_6              0.841558              0.311549
# data_magnitude_pow_7              0.799154              0.349801
# data_magnitude_pow_8              0.758213              0.387822
# data_magnitude_pow_9              0.719157              0.425266
#
#                       data_magnitude_exp_inv_2  ...  data_magnitude_pow_16  \
# open                                 -0.166041  ...               0.496434
# high                                 -0.165653  ...               0.496815
# low                                  -0.166220  ...               0.496656
# close                                -0.165990  ...               0.496601
# data_magnitude                       -0.166007  ...               0.496721
# data_magnitude_pow_2                 -0.117144  ...               0.571075
# data_magnitude_pow_3                 -0.086712  ...               0.640791
# data_magnitude_pow_4                 -0.067877  ...               0.704323
# data_magnitude_pow_5                 -0.055894  ...               0.760705
# data_magnitude_pow_6                 -0.047871  ...               0.809751
# data_magnitude_pow_7                 -0.042160  ...               0.851814
# data_magnitude_pow_8                 -0.037842  ...               0.887465
# data_magnitude_pow_9                 -0.034403  ...               0.917277
#
#                       data_magnitude_exp_17  data_magnitude_exp_inv_17  \
# open                                    0.0                  -0.065152
# high                                    0.0                  -0.065092
# low                                     0.0                  -0.065200
# close                                   0.0                  -0.065139
# data_magnitude                          0.0                  -0.065159
# data_magnitude_pow_2                    0.0                  -0.045102
# data_magnitude_pow_3                    0.0                  -0.032971
# data_magnitude_pow_4                    0.0                  -0.025631
# data_magnitude_pow_5                    0.0                  -0.021036
# data_magnitude_pow_6                    0.0                  -0.017992
# data_magnitude_pow_7                    0.0                  -0.015837
# data_magnitude_pow_8                    0.0                  -0.014212
# data_magnitude_pow_9                    0.0                  -0.012920
#
#                       data_magnitude_pow_17  data_magnitude_exp_18  \
# open                               0.471356                    0.0
# high                               0.471721                    0.0
# low                                0.471558                    0.0
# close                              0.471511                    0.0
# data_magnitude                     0.471626                    0.0
# data_magnitude_pow_2               0.544331                    0.0
# data_magnitude_pow_3               0.613269                    0.0
# data_magnitude_pow_4               0.676847                    0.0
# data_magnitude_pow_5               0.733999                    0.0
# data_magnitude_pow_6               0.784407                    0.0
# data_magnitude_pow_7               0.828291                    0.0
# data_magnitude_pow_8               0.866099                    0.0
# data_magnitude_pow_9               0.898303                    0.0
#
#                       data_magnitude_exp_inv_18  data_magnitude_pow_18  \
# open                                  -0.063277               0.447886
# high                                  -0.063223               0.448236
# low                                   -0.063324               0.448067
# close                                 -0.063264               0.448030
# data_magnitude                        -0.063285               0.448141
# data_magnitude_pow_2                  -0.043799               0.519116
# data_magnitude_pow_3                  -0.032015               0.587108
# data_magnitude_pow_4                  -0.024887               0.650497
# data_magnitude_pow_5                  -0.020425               0.708139
# data_magnitude_pow_6                  -0.017469               0.759604
# data_magnitude_pow_7                  -0.015377               0.804994
# data_magnitude_pow_8                  -0.013799               0.844646
# data_magnitude_pow_9                  -0.012544               0.878940
#
#                       data_magnitude_exp_19  data_magnitude_exp_inv_19  \
# open                                    0.0                  -0.061531
# high                                    0.0                  -0.061482
# low                                     0.0                  -0.061577
# close                                   0.0                  -0.061518
# data_magnitude                          0.0                  -0.061540
# data_magnitude_pow_2                    0.0                  -0.042586
# data_magnitude_pow_3                    0.0                  -0.031126
# data_magnitude_pow_4                    0.0                  -0.024195
# data_magnitude_pow_5                    NaN                  -0.019857
# data_magnitude_pow_6                    NaN                  -0.016983
# data_magnitude_pow_7                    NaN                  -0.014949
# data_magnitude_pow_8                    NaN                  -0.013415
# data_magnitude_pow_9                    NaN                  -0.012195
#
#                       data_magnitude_pow_19
# open                               0.425996
# high                               0.426330
# low                                0.426155
# close                              0.426129
# data_magnitude                     0.426234
# data_magnitude_pow_2               0.495445
# data_magnitude_pow_3               0.562375
# data_magnitude_pow_4               0.625392
# data_magnitude_pow_5               0.683295
# data_magnitude_pow_6               0.735558
# data_magnitude_pow_7               0.782179
# data_magnitude_pow_8               0.823397
# data_magnitude_pow_9               0.859503
#
# [13 rows x 62 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)
print('done')
# Out:
# done
