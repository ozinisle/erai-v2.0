# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "001_"
requiredMinimumCorrelation = -1

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *
from config import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import getAttributeDifferenceBasedFeatures
from dataPreparation.featurePreparation import prepareFeatureWithData

_basicDf = doBasicOperation(dataName, dataFrequency)
print('done')
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
featureOfInterest = 'attribute_value_difference'

newFeatureDf = getAttributeDifferenceBasedFeatures(_basicDf)

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf = prepareFeatureWithData(dataName,dataFrequency,newFeatureDf,
            _basicDf,featureIndexStamp,requiredMinimumCorrelation=requiredMinimumCorrelation)

_newTrainingSetDf.shape,_trainableFeaturesDf.shape
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.2
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py:158: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/001_open_close_diff_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/001_open_close_diff_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/001_open_close_diff_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/001_open_close_diff_variations_reasonable_correlation_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/001_open_close_diff_trainableFeaturesList.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/001_open_close_diff_variations_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/001_open_close_diff_variations_correlation_list.csv
# File deleted >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/001_open_close_diff_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/001_open_close_diff_variations_list.csv
# newTrainingSetDf shape>>>8350,352
# trainableFeaturesDf shape>>>8350,65
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# Error executing method >>>
# Traceback (most recent call last):
#   File "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py", line 328, in prepareFeatureWithData
#     setAppConfigData(autoConfigData)
#   File "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/environment.py", line 31, in setAppConfigData
#     print('setAppConfigData >>> configFilePath >>> '+configFilePath)
# UnboundLocalError: local variable 'configFilePath' referenced before assignment
#
# Traceback (most recent call last):
#   File "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py", line 328, in prepareFeatureWithData
# UnboundLocalError: [<FrameSummary file /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py, line 328 in prepareFeatureWithData>, <FrameSummary file /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/environment.py, line 31 in setAppConfigData>]
# ((8350, 352), (8350, 65))

# %%
_reasonableCorelation.sort_values('open')
# Out:
#                              open      high       low     close  \
# high_low_diff_exp_inv_2 -0.453788 -0.466815 -0.440574 -0.454519
# high_low_diff_exp_inv_1 -0.453328 -0.468398 -0.438450 -0.454647
# high_low_diff_exp_inv_3 -0.439941 -0.451554 -0.427954 -0.440356
# high_low_diff_exp_inv_4 -0.421851 -0.432396 -0.410829 -0.422072
# high_low_diff_exp_inv_5 -0.402809 -0.412505 -0.392576 -0.402905
# ...                           ...       ...       ...       ...
# high_low_diff            0.377220  0.394869  0.359155  0.378575
# close                    0.999298  0.999678  0.999613  1.000000
# low                      0.999531  0.999257  1.000000  0.999613
# high                     0.999541  1.000000  0.999257  0.999678
# open                     1.000000  0.999541  0.999531  0.999298
#
#                          open_close_diff  open_high_diff  open_low_diff  \
# high_low_diff_exp_inv_2         0.016298        0.533174      -0.527977
# high_low_diff_exp_inv_1         0.031979        0.598545      -0.580366
# high_low_diff_exp_inv_3         0.007963        0.484322      -0.485863
# high_low_diff_exp_inv_4         0.002931        0.445468      -0.451016
# high_low_diff_exp_inv_5        -0.000275        0.413405      -0.421440
# ...                                  ...             ...            ...
# high_low_diff                  -0.033495       -0.661852       0.662266
# close                          -0.011658       -0.266519       0.234767
# low                             0.004885       -0.245595       0.229973
# high                            0.003426       -0.269109       0.253747
# open                            0.025801       -0.239823       0.259656
#
#                          close_high_diff  close_low_diff  high_low_diff  ...  \
# high_low_diff_exp_inv_2         0.603120       -0.600296      -0.801401  ...
# high_low_diff_exp_inv_1         0.657929       -0.678226      -0.890333  ...
# high_low_diff_exp_inv_3         0.557428       -0.543225      -0.732702  ...
# high_low_diff_exp_inv_4         0.518853       -0.498439      -0.677043  ...
# high_low_diff_exp_inv_5         0.485697       -0.461819      -0.630493  ...
# ...                                  ...             ...            ...  ...
# high_low_diff                  -0.730129        0.770022       1.000000  ...
# close                          -0.296573        0.272683       0.378575  ...
# low                            -0.295146        0.245822       0.359155  ...
# high                           -0.320709        0.273801       0.394869  ...
# open                           -0.317624        0.251061       0.377220  ...
#
#                          open_low_diff_exp_inv_19  close_high_diff_exp_inv_19  \
# high_low_diff_exp_inv_2                  0.234954                   -0.021450
# high_low_diff_exp_inv_1                  0.207875                   -0.035105
# high_low_diff_exp_inv_3                  0.250338                   -0.016283
# high_low_diff_exp_inv_4                  0.259718                   -0.013424
# high_low_diff_exp_inv_5                  0.265392                   -0.011555
# ...                                           ...                         ...
# high_low_diff                           -0.141300                    0.195654
# close                                   -0.133370                    0.000722
# low                                     -0.134458                    0.000384
# high                                    -0.138201                    0.008461
# open                                    -0.146362                    0.008691
#
#                          close_low_diff_exp_inv_19  high_low_diff_exp_inv_19  \
# high_low_diff_exp_inv_2                   0.388660                  0.598343
# high_low_diff_exp_inv_1                   0.356844                  0.498540
# high_low_diff_exp_inv_3                   0.404525                  0.673940
# high_low_diff_exp_inv_4                   0.412406                  0.734605
# high_low_diff_exp_inv_5                   0.415580                  0.784496
# ...                                            ...                       ...
# high_low_diff                            -0.268434                 -0.327627
# close                                    -0.162674                 -0.225934
# low                                      -0.152291                 -0.220818
# high                                     -0.161007                 -0.230911
# open                                     -0.154759                 -0.226078
#
#                          open_close_diff_pow_19  open_high_diff_pow_19  \
# high_low_diff_exp_inv_2               -0.021444               0.034576
# high_low_diff_exp_inv_1               -0.035096               0.056252
# high_low_diff_exp_inv_3               -0.016279               0.026249
# high_low_diff_exp_inv_4               -0.013420               0.021640
# high_low_diff_exp_inv_5               -0.011552               0.018627
# ...                                         ...                    ...
# high_low_diff                          0.195631              -0.179003
# close                                  0.000715              -0.026015
# low                                    0.000379              -0.018935
# high                                   0.008455              -0.026034
# open                                   0.008687              -0.018409
#
#                          open_low_diff_pow_19  close_high_diff_pow_19  \
# high_low_diff_exp_inv_2             -0.029990                0.021500
# high_low_diff_exp_inv_1             -0.049084                0.035188
# high_low_diff_exp_inv_3             -0.022766                0.016321
# high_low_diff_exp_inv_4             -0.018769                0.013456
# high_low_diff_exp_inv_5             -0.016156                0.011582
# ...                                       ...                     ...
# high_low_diff                        0.285299               -0.196162
# close                                0.004596               -0.000737
# low                                  0.002344               -0.000392
# high                                 0.014093               -0.008489
# open                                 0.013862               -0.008718
#
#                          close_low_diff_pow_19  high_low_diff_pow_19
# high_low_diff_exp_inv_2              -0.022417             -0.024870
# high_low_diff_exp_inv_1              -0.036491             -0.040706
# high_low_diff_exp_inv_3              -0.017018             -0.018880
# high_low_diff_exp_inv_4              -0.014030             -0.015565
# high_low_diff_exp_inv_5              -0.012076             -0.013398
# ...                                        ...                   ...
# high_low_diff                         0.117989              0.246371
# close                                 0.020404              0.006798
# low                                   0.015367              0.003449
# high                                  0.020002              0.013572
# open                                  0.014982              0.012921
#
# [69 rows x 352 columns]

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(_reasonableCorelation)
# print('done')

_reasonableCorelation.shape
# Out:
# (69, 352)

# %%
outputFeatureLength=4
corrBatchSizeForInspection = 10
totalCorrLen = len(_reasonableCorelation.index)
featureLen = totalCorrLen-outputFeatureLength
limit = featureLen/corrBatchSizeForInspection
quotient = int(limit)
reminder = featureLen - quotient

corrBatch = [_reasonableCorelation.index[0:outputFeatureLength].append(
    _reasonableCorelation.index[outputFeatureLength+(corrBatchSizeForInspection*itr):outputFeatureLength+
                                (corrBatchSizeForInspection*(itr+1))]) for itr in range(quotient)]

result= None
if reminder>0:
    corrBatch.append(_reasonableCorelation.index[outputFeatureLength+(quotient*corrBatchSizeForInspection):])

#corrBatch
correlationForInspection = [_reasonableCorelation[corrBatch[corrItr]].corr()  for corrItr in range(len(corrBatch))]

#_reasonableCorelation[corrBatch[0]].corr()[['open','close','high','low']]

correlationForInspection[0][['open','close','high','low']]
correlationForInspection[1][['open','close','high','low']]
# Out:
#                               open     close      high       low
# open                      1.000000  0.999087  0.999572  0.999605
# high                      0.999572  0.999772  1.000000  0.999672
# low                       0.999605  0.999666  0.999672  1.000000
# close                     0.999087  1.000000  0.999772  0.999666
# open_high_diff_exp_2     -0.438843 -0.473692 -0.464128 -0.456641
# close_high_diff_exp_2    -0.651322 -0.625361 -0.641073 -0.636728
# open_low_diff_exp_inv_2  -0.543057 -0.511260 -0.524337 -0.520283
# close_low_diff_exp_inv_2 -0.532326 -0.560102 -0.550284 -0.539337
# high_low_diff_exp_inv_2  -0.883195 -0.884932 -0.888593 -0.878151
# open_high_diff_exp_3     -0.416207 -0.451426 -0.441431 -0.434716
# close_high_diff_exp_3    -0.632943 -0.606876 -0.622478 -0.618933
# open_low_diff_exp_inv_3  -0.522171 -0.489836 -0.502652 -0.499490
# close_low_diff_exp_inv_3 -0.517196 -0.544889 -0.534591 -0.524309
# high_low_diff_exp_inv_3  -0.878613 -0.879915 -0.883277 -0.873878

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(_reasonableCorelation)
# print('done')

# %%
manullyDecidedIndexList=['open','high','low','close',
                                             'open_high_diff_exp_1','close_high_diff_exp_1',
                                            'open_low_diff_exp_inv_1','close_low_diff_exp_inv_2',
                                             'high_low_diff_exp_inv_2'
                                            ]
manuallyDecidedListDf = _reasonableCorelation[manullyDecidedIndexList]

manuallyDecidedListDf[manuallyDecidedListDf.index.isin(manullyDecidedIndexList)]
# Out:
#                               open      high       low     close  \
# open                      1.000000  0.999541  0.999531  0.999298
# high                      0.999541  1.000000  0.999257  0.999678
# low                       0.999531  0.999257  1.000000  0.999613
# close                     0.999298  0.999678  0.999613  1.000000
# open_high_diff_exp_1     -0.266702 -0.293119 -0.273983 -0.291301
# close_high_diff_exp_1    -0.363132 -0.366613 -0.344964 -0.345216
# open_low_diff_exp_inv_1  -0.301008 -0.293140 -0.275037 -0.277944
# close_low_diff_exp_inv_2 -0.290095 -0.307125 -0.285133 -0.307312
# high_low_diff_exp_inv_2  -0.453788 -0.466815 -0.440574 -0.454519
#
#                           open_high_diff_exp_1  close_high_diff_exp_1  \
# open                                 -0.266702              -0.363132
# high                                 -0.293119              -0.366613
# low                                  -0.273983              -0.344964
# close                                -0.291301              -0.345216
# open_high_diff_exp_1                  1.000000               0.186521
# close_high_diff_exp_1                 0.186521               1.000000
# open_low_diff_exp_inv_1              -0.230885               0.686746
# close_low_diff_exp_inv_2              0.661281               0.061976
# high_low_diff_exp_inv_2               0.585127               0.693611
#
#                           open_low_diff_exp_inv_1  close_low_diff_exp_inv_2  \
# open                                    -0.301008                 -0.290095
# high                                    -0.293140                 -0.307125
# low                                     -0.275037                 -0.285133
# close                                   -0.277944                 -0.307312
# open_high_diff_exp_1                    -0.230885                  0.661281
# close_high_diff_exp_1                    0.686746                  0.061976
# open_low_diff_exp_inv_1                  1.000000                  0.208128
# close_low_diff_exp_inv_2                 0.208128                  1.000000
# high_low_diff_exp_inv_2                  0.595424                  0.694446
#
#                           high_low_diff_exp_inv_2
# open                                    -0.453788
# high                                    -0.466815
# low                                     -0.440574
# close                                   -0.454519
# open_high_diff_exp_1                     0.585127
# close_high_diff_exp_1                    0.693611
# open_low_diff_exp_inv_1                  0.595424
# close_low_diff_exp_inv_2                 0.694446
# high_low_diff_exp_inv_2                  1.000000

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(manuallyDecidedListDf)
print('done')
# Out:
# done
