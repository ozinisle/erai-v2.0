# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "005_"

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *
from config import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData



_basicDf = doBasicOperation(dataName,dataFrequency)

print('done')
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
#temporary stuff
import traceback

traceback_template = '''Traceback (most recent call last):
  File "%(filename)s", line %(lineno)s, in %(name)s
%(type)s: %(message)s\n''' # Skipping the "actual line" item

print('done')
# Out:
# done

# %%
import pandas as pd
import numpy as np
from config.environment import getAppConfigData
from utilities.fileFolderManipulations import getJupyterRootDirectory

featureOfInterest = 'prior_days'
#_basicDf=_basicDf[1:10]


projectRootDirectory = getJupyterRootDirectory()
configData=getAppConfigData()
inputRawProcessedDataDF = pd.read_csv(projectRootDirectory+'/'+configData[dataName][dataFrequency]['preProcessedDataFilePath']) 

featureName=['prior_holidays','scarcity_by_prior_holidays','magnitudeTimesScarcity_by_prior_holidays']

priorHolidaysDataDf = inputRawProcessedDataDF[['open','close','high','low','prior_holidays']]
m = priorHolidaysDataDf.shape[0]

prior_holidays_unique_values = priorHolidaysDataDf[featureName[0]].unique()

dataByScarcityOfPriorHolidays=priorHolidaysDataDf[featureName[0]].rename(featureName[1])

priorHolidaysDataDf=pd.concat([priorHolidaysDataDf,dataByScarcityOfPriorHolidays],axis=1)

for unq_val in prior_holidays_unique_values:
    matches=priorHolidaysDataDf.loc[priorHolidaysDataDf[featureName[0]]==unq_val]    
    priorHolidaysDataDf[featureName[0]][priorHolidaysDataDf[featureName[1]]==unq_val]=100*(m-matches.shape[0])/m
  
magnitudeDf= np.divide(np.sqrt(np.sum(np.square(priorHolidaysDataDf[['open','close','high','low']]),axis=1)),4)

magnitudeTimesScarcityDf = np.multiply(magnitudeDf,dataByScarcityOfPriorHolidays)

priorHolidaysDataDf=pd.concat([priorHolidaysDataDf,magnitudeTimesScarcityDf.rename(featureName[2])],axis=1)            

newFeatureDf=priorHolidaysDataDf.drop({'open','close','high','low'},axis=1)
#priorHolidaysDataDf.corr()

_basicDf=inputRawProcessedDataDF[['open','close','high','low']]

_trainableFeaturesDf = prepareFeatureWithData(dataName,dataFrequency,newFeatureDf,
            _basicDf,featureIndexStamp)


print('done')
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.7
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py:158: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/005_prior_holidays_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/005_prior_holidays_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/005_prior_holidays_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/005_prior_holidays_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/005_prior_holidays_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/005_prior_holidays_variations_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/005_prior_holidays_variations_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/005_prior_holidays_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/005_prior_holidays_variations_list.csv
# done

# %%
_trainableFeaturesDf[1]
# Out:
#            open     close      high       low  prior_holidays  \
# open   1.000000  0.999298  0.999541  0.999531        0.032368
# close  0.999298  1.000000  0.999678  0.999613        0.032364
# high   0.999541  0.999678  1.000000  0.999257        0.032451
# low    0.999531  0.999613  0.999257  1.000000        0.031944
#
#        scarcity_by_prior_holidays  magnitudeTimesScarcity_by_prior_holidays  \
# open                     0.035911                                  0.130670
# close                    0.035667                                  0.130433
# high                     0.035656                                  0.130394
# low                      0.035809                                  0.130601
#
#        prior_holidays_exp_1  scarcity_by_prior_holidays_exp_1  \
# open               0.030424                          0.037843
# close              0.029916                          0.037531
# high               0.029841                          0.037460
# low                0.030594                          0.038111
#
#        magnitudeTimesScarcity_by_prior_holidays_exp_1  ...  \
# open                                         0.062504  ...
# close                                        0.062449  ...
# high                                         0.062318  ...
# low                                          0.062341  ...
#
#        magnitudeTimesScarcity_by_prior_holidays_pow_18  prior_holidays_exp_19  \
# open                                          0.037826                    0.0
# close                                         0.037507                   -0.0
# high                                          0.037447                   -0.0
# low                                           0.038085                    0.0
#
#        scarcity_by_prior_holidays_exp_19  \
# open                                 0.0
# close                                0.0
# high                                 0.0
# low                                  0.0
#
#        magnitudeTimesScarcity_by_prior_holidays_exp_19  \
# open                                               NaN
# close                                              NaN
# high                                               NaN
# low                                                NaN
#
#        prior_holidays_exp_inv_19  scarcity_by_prior_holidays_exp_inv_19  \
# open                         NaN                              -0.024866
# close                        NaN                              -0.024937
# high                         NaN                              -0.025006
# low                          NaN                              -0.024416
#
#        magnitudeTimesScarcity_by_prior_holidays_exp_inv_19  \
# open                                           -0.024866
# close                                          -0.024937
# high                                           -0.025006
# low                                            -0.024416
#
#        prior_holidays_pow_19  scarcity_by_prior_holidays_pow_19  \
# open                0.063920                           0.037843
# close               0.063391                           0.037531
# high                0.063537                           0.037460
# low                 0.063877                           0.038111
#
#        magnitudeTimesScarcity_by_prior_holidays_pow_19
# open                                          0.037823
# close                                         0.037504
# high                                          0.037445
# low                                           0.038082
#
# [4 rows x 178 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_trainableFeaturesDf[1])
print('done')
