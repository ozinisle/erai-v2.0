# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "012_"
requiredMinimumCorrelation = -1

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *
from config import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import getQuantityBasedFeatures
from dataPreparation.featurePreparation import prepareFeatureWithData

_basicDf = doBasicOperation(dataName, dataFrequency)
print('done')
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
newFeatureDf=getQuantityBasedFeatures(dataName,dataFrequency)
    
featureOfInterest = 'quantity_value_difference'

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf = prepareFeatureWithData(dataName,dataFrequency,newFeatureDf,
             _basicDf,featureIndexStamp,requiredMinimumCorrelation=requiredMinimumCorrelation)

_newTrainingSetDf.shape,_trainableFeaturesDf
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.7
# _createNewTrainingSetWithFeatureVariations check point 1 >>> variation_degree >>> 20
# _createNewTrainingSetWithFeatureVariations check point 2
# _createNewTrainingSetWithFeatureVariations check point 3
# _createNewTrainingSetWithFeatureVariations check point 4
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# _createNewTrainingSetWithFeatureVariations check point 5
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/012_quantity_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/012_quantity_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/012_quantity_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/012_quantity_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/012_quantity_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/012_quantity_variations_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/012_quantity_variations_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/012_quantity_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/012_quantity_variations_list.csv
# ((8350, 120), None)

# %%
_correlation.corr().sort_values('open',ascending=True)
# Out:
#                          open      high       low     close  quantity  \
# quantity_pow_6      -0.185760 -0.163049 -0.219648 -0.196618  0.735396
# quantity_pow_4      -0.185398 -0.160443 -0.218982 -0.193902  0.780513
# quantity_pow_8      -0.177286 -0.155777 -0.211161 -0.189235  0.710993
# quantity_exp_inv_19 -0.174025 -0.207877 -0.141404 -0.174973 -0.965792
# quantity_exp_inv_18 -0.172668 -0.206558 -0.140035 -0.173639 -0.966664
# ...                       ...       ...       ...       ...       ...
# quantity_pow_1       0.079087  0.113700  0.044292  0.078586  1.000000
# low                  0.999296  0.997520  1.000000  0.999390  0.044292
# high                 0.999368  1.000000  0.997520  0.999300  0.113700
# close                0.999835  0.999300  0.999390  1.000000  0.078586
# open                 1.000000  0.999368  0.999296  0.999835  0.079087
#
#                      quantity  quantity_exp_1  quantity_exp_1  \
# quantity_pow_6       0.616261        0.774556        0.716840
# quantity_pow_4       0.563522        0.807416        0.677177
# quantity_pow_8       0.653307        0.756710        0.743532
# quantity_exp_inv_19 -0.633949       -0.944995       -0.712160
# quantity_exp_inv_18 -0.635752       -0.945951       -0.713791
# ...                       ...             ...             ...
# quantity_pow_1       0.775157        0.996363        0.843857
# low                 -0.008925        0.015173       -0.037838
# high                 0.048600        0.084901        0.024441
# close                0.017801        0.049030       -0.009069
# open                 0.021876        0.050788       -0.004335
#
#                      quantity_exp_inv_1  quantity_exp_inv_1  ...  \
# quantity_pow_6                -0.708800           -0.506849  ...
# quantity_pow_4                -0.762008           -0.428728  ...
# quantity_pow_8                -0.679866           -0.561034  ...
# quantity_exp_inv_19            0.977420            0.496756  ...
# quantity_exp_inv_18            0.978196            0.498635  ...
# ...                                 ...                 ...  ...
# quantity_pow_1                -0.998242           -0.652842  ...
# low                           -0.065294           -0.012359  ...
# high                          -0.134236           -0.061740  ...
# close                         -0.099727           -0.034842  ...
# open                          -0.099451           -0.039362  ...
#
#                      quantity_exp_inv_18  quantity_exp_inv_18  \
# quantity_pow_6                 -0.666565            -0.117949
# quantity_pow_4                 -0.735767             0.046350
# quantity_pow_8                 -0.626150            -0.226601
# quantity_exp_inv_19             0.999991            -0.154000
# quantity_exp_inv_18             1.000000            -0.153040
# ...                                  ...                  ...
# quantity_pow_1                 -0.966664            -0.011734
# low                            -0.140035            -0.054557
# high                           -0.206558            -0.059268
# close                          -0.173639            -0.052282
# open                           -0.172668            -0.062308
#
#                      quantity_pow_18  quantity_pow_18  quantity_exp_19  \
# quantity_pow_6              0.936136         0.951111         0.936200
# quantity_pow_4              0.860787         0.882348         0.860976
# quantity_pow_8              0.969493         0.979672         0.969518
# quantity_exp_inv_19        -0.529088        -0.547825        -0.529918
# quantity_exp_inv_18        -0.529340        -0.548027        -0.530174
# ...                              ...              ...              ...
# quantity_pow_1              0.647962         0.660591         0.648944
# low                        -0.179340        -0.186259        -0.179289
# high                       -0.127826        -0.133899        -0.127719
# close                      -0.160035        -0.166448        -0.159949
# open                       -0.146553        -0.153156        -0.146483
#
#                      quantity_exp_19  quantity_exp_inv_19  \
# quantity_pow_6              0.936044            -0.666602
# quantity_pow_4              0.860532            -0.735804
# quantity_pow_8              0.969453            -0.626123
# quantity_exp_inv_19        -0.528034             1.000000
# quantity_exp_inv_18        -0.528280             0.999991
# ...                              ...                  ...
# quantity_pow_1              0.646684            -0.965792
# low                        -0.179375            -0.141404
# high                       -0.127929            -0.207877
# close                      -0.160113            -0.174973
# open                       -0.146610            -0.174025
#
#                      quantity_exp_inv_19  quantity_pow_19  quantity_pow_19
# quantity_pow_6                 -0.118081         0.936114         0.922202
# quantity_pow_4                  0.046135         0.860724         0.841243
# quantity_pow_8                 -0.226699         0.969484         0.959542
# quantity_exp_inv_19            -0.153996        -0.528817        -0.510730
# quantity_exp_inv_18            -0.153038        -0.529068        -0.511011
# ...                                  ...              ...              ...
# quantity_pow_1                 -0.011652         0.647637         0.633977
# low                            -0.054541        -0.179351        -0.173460
# high                           -0.059238        -0.127854        -0.122863
# close                          -0.052256        -0.160057        -0.154691
# open                           -0.062288        -0.146569        -0.141031
#
# [120 rows x 120 columns]

# %%
_reasonableCorelation.sort_values('open')
# Out:
#            open      high       low     close  quantity  quantity  \
# close  0.999298  0.999678  0.999613  1.000000  0.029486 -0.001082
# low    0.999531  0.999257  1.000000  0.999613  0.015763 -0.010902
# high   0.999541  1.000000  0.999257  0.999678  0.039495  0.006037
# open   1.000000  0.999541  0.999531  0.999298  0.025084 -0.004065
#
#        quantity_exp_1  quantity_exp_1  quantity_exp_inv_1  quantity_exp_inv_1  \
# close        0.024976        0.000689           -0.033261            0.002680
# low          0.012116       -0.009573           -0.019077            0.011275
# high         0.034973        0.009017           -0.043292           -0.003130
# open         0.021522       -0.001475           -0.028374            0.005734
#
#        ...  quantity_exp_inv_18  quantity_exp_inv_18  quantity_pow_18  \
# close  ...            -0.061984            -0.001120         0.000591
# low    ...            -0.048629            -0.001225         0.000255
# high   ...            -0.072202            -0.001141         0.008334
# open   ...            -0.058467            -0.001176         0.008565
#
#        quantity_pow_18  quantity_exp_19  quantity_exp_19  quantity_exp_inv_19  \
# close         0.000678         0.000550         0.000713            -0.062947
# low           0.000334         0.000209         0.000373            -0.049675
# high          0.008399         0.008296         0.008454            -0.073147
# open          0.008627         0.008522         0.008683            -0.059514
#
#        quantity_exp_inv_19  quantity_pow_19  quantity_pow_19
# close            -0.000975         0.000618         0.000747
# low              -0.001076         0.000282         0.000415
# high             -0.000994         0.008360         0.008474
# open             -0.001027         0.008590         0.008706
#
# [4 rows x 120 columns]

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(_reasonableCorelation)
# print('done')

_reasonableCorelation.shape
# Out:
# (4, 120)

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(_reasonableCorelation)
# print('done')

# %%
# manullyDecidedIndexList=['open','high','low','close',
#                                              'open_high_diff_exp_1','close_high_diff_exp_1',
#                                             'open_low_diff_exp_inv_1','close_low_diff_exp_inv_2',
#                                              'high_low_diff_exp_inv_2'
#                                             ]
# manuallyDecidedListDf = _reasonableCorelation[manullyDecidedIndexList]

# manuallyDecidedListDf[manuallyDecidedListDf.index.isin(manullyDecidedIndexList)]

# %%
# from utilities.dataVisuvalization import displayHeatMap
# displayHeatMap(manuallyDecidedListDf)
# print('done')
