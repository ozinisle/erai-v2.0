# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "006_"

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData

_basicDf = doBasicOperation(dataName,dataFrequency)

print('done')
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
#temporary stuff
import traceback

traceback_template = '''Traceback (most recent call last):
  File "%(filename)s", line %(lineno)s, in %(name)s
%(type)s: %(message)s\n''' # Skipping the "actual line" item

print('done')
# Out:
# done

# %%
import pandas as pd
import numpy as np
from config.environment import getAppConfigData
from utilities.fileFolderManipulations import getJupyterRootDirectory

featureOfInterest = 'is_Red_Or_Green_Candle'

projectRootDirectory = getJupyterRootDirectory()
configData=getAppConfigData()
inputRawProcessedDataDF = pd.read_csv(projectRootDirectory+'/'+configData[dataName][dataFrequency]['preProcessedDataFilePath']) 

featureName=['is_red_candle','is_green_candle','green_candle_magnitude','red_candle_magnitude','green_red_vector']

m = _basicDf.shape[0]

greenRedCandleDf = _basicDf['close']- _basicDf['open'] 

greenCandleDf = greenRedCandleDf>0
redCandleDf = greenRedCandleDf<0

greenCandleDf[greenCandleDf==True] = 1
redCandleDf[redCandleDf==True] = 1

dataMagnitudeDf = np.divide(np.sqrt(np.sum(np.square(_basicDf),axis=1)),4)
greenCandle_dataMagnitudeDf = np.multiply(greenCandleDf,dataMagnitudeDf)
redCandle_dataMagnitudeDf = np.multiply(redCandleDf,dataMagnitudeDf)

greenRedCandleVectorDf = _basicDf['close']- _basicDf['open'] 
greenRedCandleVectorDf[greenRedCandleVectorDf>0] = 1
greenRedCandleVectorDf[greenRedCandleVectorDf<0] = -1
greenRedCandleVectorDf = np.multiply(greenRedCandleVectorDf,dataMagnitudeDf)

newFeatureDf = pd.concat([greenCandleDf.rename(featureName[0]),redCandleDf.rename(featureName[1]),
                         greenCandle_dataMagnitudeDf.rename(featureName[2]),
                         redCandle_dataMagnitudeDf.rename(featureName[3]),
                         greenRedCandleVectorDf.rename(featureName[4])],axis=1)

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf= prepareFeatureWithData(dataName,dataFrequency,newFeatureDf,
            _basicDf,featureIndexStamp)


print('done')
# Out:
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# requiredMinimumCorrelation is >>> 0.7
# /opt/anaconda3/lib/python3.7/site-packages/tqdm/std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/featurePreparation.py:158: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# preprocessedFolderPath interim test >>> /data/adani/processed/1h/preProcessedData
# outputFolderPath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
# featuresFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
# rawFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
# filteredFeaturesFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
# correlationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations
#  checking if folder existis >>>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# reasonableCorrelationsFolder interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations
# trainableFeaturesListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/006_is_red_candle_trainableFeaturesList.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/006_is_red_candle_variations_list.csv
# currentFeatureCorrelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/006_is_red_candle_variations_correlation_list.csv
# reasonableCorelationListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/006_is_red_candle_variations_reasonable_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/006_is_red_candle_trainableFeaturesList.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/006_is_red_candle_variations_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/006_is_red_candle_variations_correlation_list.csv
# cannot delete file as the file does not exist >>/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/correlations/reasonableCorrelations/006_is_red_candle_variations_reasonable_correlation_list.csv
# currentFeatureListFilePath interim test >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/rawFeatures/006_is_red_candle_variations_list.csv
# newTrainingSetDf shape>>>8350,294
# trainableFeaturesDf shape>>>8350,4
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  updating config file >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
#  successfully updated config file >>> (try block) /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json with data >>>{"variationDegreeForFeatureGeneration": 20, "requiredMinimumFeatureCorrelationWithOutputData": 0.7, "adani": {"1h": {"preProcessedDataFilePath": "/data/adani/processed/1h/preProcessedData/processedRawData.csv", "trainableFeaturesListFile": "/Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/data/adani/processed/1h/features/filteredFeatures/006_is_red_candle_trainableFeaturesList.csv"}}}
# done

# %%
_reasonableCorelation
# Out:
#                             open      high       low     close  is_red_candle  \
# open                    1.000000  0.999541  0.999531  0.999298      -0.002075
# high                    0.999541  1.000000  0.999257  0.999678       0.012612
# low                     0.999531  0.999257  1.000000  0.999613       0.009335
# close                   0.999298  0.999678  0.999613  1.000000       0.020213
# green_red_vector_pow_2  0.901418  0.902617  0.900237  0.901416       0.107564
# green_red_vector_pow_4  0.888903  0.889730  0.888481  0.889054       0.055274
# green_red_vector_pow_6  0.815109  0.815847  0.815000  0.815328       0.040768
# green_red_vector_pow_8  0.736926  0.737623  0.736964  0.737163       0.034591
#
#                         is_green_candle  green_candle_magnitude  \
# open                           0.054314                0.261408
# high                           0.041403                0.276261
# low                            0.041136                0.272912
# close                          0.032113                0.283951
# green_red_vector_pow_2         0.144847                0.345561
# green_red_vector_pow_4         0.077779                0.299763
# green_red_vector_pow_6         0.053025                0.267969
# green_red_vector_pow_8         0.040035                0.241541
#
#                         red_candle_magnitude  green_red_vector  \
# open                                0.339642         -0.047212
# high                                0.326637         -0.032039
# low                                 0.326802         -0.033930
# close                               0.317606         -0.022912
# green_red_vector_pow_2              0.401818         -0.036341
# green_red_vector_pow_4              0.341519         -0.027630
# green_red_vector_pow_6              0.296858         -0.020035
# green_red_vector_pow_8              0.260788         -0.014304
#
#                         is_red_candle_exp_1  ...  is_red_candle_exp_inv_19  \
# open                              -0.002075  ...                  0.002075
# high                               0.012612  ...                 -0.012612
# low                                0.009335  ...                 -0.009335
# close                              0.020213  ...                 -0.020213
# green_red_vector_pow_2             0.107564  ...                 -0.107564
# green_red_vector_pow_4             0.055274  ...                 -0.055274
# green_red_vector_pow_6             0.040768  ...                 -0.040768
# green_red_vector_pow_8             0.034591  ...                 -0.034591
#
#                         is_green_candle_exp_inv_19  \
# open                                     -0.054314
# high                                     -0.041403
# low                                      -0.041136
# close                                    -0.032113
# green_red_vector_pow_2                   -0.144847
# green_red_vector_pow_4                   -0.077779
# green_red_vector_pow_6                   -0.053025
# green_red_vector_pow_8                   -0.040035
#
#                         green_candle_magnitude_exp_inv_19  \
# open                                             0.002075
# high                                            -0.012612
# low                                             -0.009335
# close                                           -0.020213
# green_red_vector_pow_2                          -0.107564
# green_red_vector_pow_4                          -0.055274
# green_red_vector_pow_6                          -0.040768
# green_red_vector_pow_8                          -0.034591
#
#                         red_candle_magnitude_exp_inv_19  \
# open                                          -0.054314
# high                                          -0.041403
# low                                           -0.041136
# close                                         -0.032113
# green_red_vector_pow_2                        -0.144847
# green_red_vector_pow_4                        -0.077779
# green_red_vector_pow_6                        -0.053025
# green_red_vector_pow_8                        -0.040035
#
#                         green_red_vector_exp_inv_19  is_red_candle_pow_19  \
# open                                            0.0             -0.002075
# high                                            0.0              0.012612
# low                                             0.0              0.009335
# close                                           0.0              0.020213
# green_red_vector_pow_2                          0.0              0.107564
# green_red_vector_pow_4                          0.0              0.055274
# green_red_vector_pow_6                          NaN              0.040768
# green_red_vector_pow_8                          NaN              0.034591
#
#                         is_green_candle_pow_19  green_candle_magnitude_pow_19  \
# open                                  0.054314                       0.277706
# high                                  0.041403                       0.281284
# low                                   0.041136                       0.280201
# close                                 0.032113                       0.282778
# green_red_vector_pow_2                0.144847                       0.319893
# green_red_vector_pow_4                0.077779                       0.421548
# green_red_vector_pow_6                0.053025                       0.499889
# green_red_vector_pow_8                0.040035                       0.562760
#
#                         red_candle_magnitude_pow_19  green_red_vector_pow_19
# open                                       0.307370                -0.017909
# high                                       0.304372                -0.013288
# low                                        0.304920                -0.014436
# close                                      0.302402                -0.010857
# green_red_vector_pow_2                     0.346610                -0.015433
# green_red_vector_pow_4                     0.453166                -0.017834
# green_red_vector_pow_6                     0.532577                -0.017797
# green_red_vector_pow_8                     0.593642                -0.015910
#
# [8 rows x 294 columns]

# %%
_correlation
# Out:
#                                    open      high       low     close  \
# open                           1.000000  0.999541  0.999531  0.999298
# high                           0.999541  1.000000  0.999257  0.999678
# low                            0.999531  0.999257  1.000000  0.999613
# close                          0.999298  0.999678  0.999613  1.000000
# is_red_candle                 -0.002075  0.012612  0.009335  0.020213
# ...                                 ...       ...       ...       ...
# is_red_candle_exp_inv_19       0.002075 -0.012612 -0.009335 -0.020213
# is_green_candle_exp_inv_19    -0.054314 -0.041403 -0.041136 -0.032113
# green_candle_magnitude_pow_19  0.277706  0.281284  0.280201  0.282778
# red_candle_magnitude_pow_19    0.307370  0.304372  0.304920  0.302402
# green_red_vector_pow_19       -0.017909 -0.013288 -0.014436 -0.010857
#
#                                is_red_candle  is_green_candle  \
# open                               -0.002075         0.054314
# high                                0.012612         0.041403
# low                                 0.009335         0.041136
# close                               0.020213         0.032113
# is_red_candle                       1.000000        -0.817279
# ...                                      ...              ...
# is_red_candle_exp_inv_19           -1.000000         0.817279
# is_green_candle_exp_inv_19          0.817279        -1.000000
# green_candle_magnitude_pow_19       0.130617        -0.106751
# red_candle_magnitude_pow_19        -0.104681         0.128085
# green_red_vector_pow_19             0.165381        -0.164819
#
#                                green_candle_magnitude  red_candle_magnitude  \
# open                                         0.261408              0.339642
# high                                         0.276261              0.326637
# low                                          0.272912              0.326802
# close                                        0.283951              0.317606
# is_red_candle                                0.916319             -0.744329
# ...                                               ...                   ...
# is_red_candle_exp_inv_19                    -0.916319              0.744329
# is_green_candle_exp_inv_19                   0.748889             -0.910741
# green_candle_magnitude_pow_19                0.288981             -0.097222
# red_candle_magnitude_pow_19                 -0.095921              0.293190
# green_red_vector_pow_19                      0.271283             -0.273209
#
#                                green_red_vector  is_red_candle_exp_1  ...  \
# open                                  -0.047212            -0.002075  ...
# high                                  -0.032039             0.012612  ...
# low                                   -0.033930             0.009335  ...
# close                                 -0.022912             0.020213  ...
# is_red_candle                          0.904086             1.000000  ...
# ...                                         ...                  ...  ...
# is_red_candle_exp_inv_19              -0.904086            -1.000000  ...
# is_green_candle_exp_inv_19             0.906063             0.817279  ...
# green_candle_magnitude_pow_19          0.209105             0.130617  ...
# red_candle_magnitude_pow_19           -0.213641            -0.104681  ...
# green_red_vector_pow_19                0.296874             0.165381  ...
#
#                                is_red_candle_exp_inv_19  \
# open                                           0.002075
# high                                          -0.012612
# low                                           -0.009335
# close                                         -0.020213
# is_red_candle                                 -1.000000
# ...                                                 ...
# is_red_candle_exp_inv_19                       1.000000
# is_green_candle_exp_inv_19                    -0.817279
# green_candle_magnitude_pow_19                 -0.130617
# red_candle_magnitude_pow_19                    0.104681
# green_red_vector_pow_19                       -0.165381
#
#                                is_green_candle_exp_inv_19  \
# open                                            -0.054314
# high                                            -0.041403
# low                                             -0.041136
# close                                           -0.032113
# is_red_candle                                    0.817279
# ...                                                   ...
# is_red_candle_exp_inv_19                        -0.817279
# is_green_candle_exp_inv_19                       1.000000
# green_candle_magnitude_pow_19                    0.106751
# red_candle_magnitude_pow_19                     -0.128085
# green_red_vector_pow_19                          0.164819
#
#                                green_candle_magnitude_exp_inv_19  \
# open                                                    0.002075
# high                                                   -0.012612
# low                                                    -0.009335
# close                                                  -0.020213
# is_red_candle                                          -1.000000
# ...                                                          ...
# is_red_candle_exp_inv_19                                1.000000
# is_green_candle_exp_inv_19                             -0.817279
# green_candle_magnitude_pow_19                          -0.130617
# red_candle_magnitude_pow_19                             0.104681
# green_red_vector_pow_19                                -0.165381
#
#                                red_candle_magnitude_exp_inv_19  \
# open                                                 -0.054314
# high                                                 -0.041403
# low                                                  -0.041136
# close                                                -0.032113
# is_red_candle                                         0.817279
# ...                                                        ...
# is_red_candle_exp_inv_19                             -0.817279
# is_green_candle_exp_inv_19                            1.000000
# green_candle_magnitude_pow_19                         0.106751
# red_candle_magnitude_pow_19                          -0.128085
# green_red_vector_pow_19                               0.164819
#
#                                green_red_vector_exp_inv_19  \
# open                                                   0.0
# high                                                   0.0
# low                                                    0.0
# close                                                  0.0
# is_red_candle                                         -0.0
# ...                                                    ...
# is_red_candle_exp_inv_19                               0.0
# is_green_candle_exp_inv_19                            -0.0
# green_candle_magnitude_pow_19                          NaN
# red_candle_magnitude_pow_19                            NaN
# green_red_vector_pow_19                                NaN
#
#                                is_red_candle_pow_19  is_green_candle_pow_19  \
# open                                      -0.002075                0.054314
# high                                       0.012612                0.041403
# low                                        0.009335                0.041136
# close                                      0.020213                0.032113
# is_red_candle                              1.000000               -0.817279
# ...                                             ...                     ...
# is_red_candle_exp_inv_19                  -1.000000                0.817279
# is_green_candle_exp_inv_19                 0.817279               -1.000000
# green_candle_magnitude_pow_19              0.130617               -0.106751
# red_candle_magnitude_pow_19               -0.104681                0.128085
# green_red_vector_pow_19                    0.165381               -0.164819
#
#                                green_candle_magnitude_pow_19  \
# open                                                0.277706
# high                                                0.281284
# low                                                 0.280201
# close                                               0.282778
# is_red_candle                                       0.130617
# ...                                                      ...
# is_red_candle_exp_inv_19                           -0.130617
# is_green_candle_exp_inv_19                          0.106751
# green_candle_magnitude_pow_19                       1.000000
# red_candle_magnitude_pow_19                        -0.013673
# green_red_vector_pow_19                             0.716836
#
#                                red_candle_magnitude_pow_19  \
# open                                              0.307370
# high                                              0.304372
# low                                               0.304920
# close                                             0.302402
# is_red_candle                                    -0.104681
# ...                                                    ...
# is_red_candle_exp_inv_19                          0.104681
# is_green_candle_exp_inv_19                       -0.128085
# green_candle_magnitude_pow_19                    -0.013673
# red_candle_magnitude_pow_19                       1.000000
# green_red_vector_pow_19                          -0.706978
#
#                                green_red_vector_pow_19
# open                                         -0.017909
# high                                         -0.013288
# low                                          -0.014436
# close                                        -0.010857
# is_red_candle                                 0.165381
# ...                                                ...
# is_red_candle_exp_inv_19                     -0.165381
# is_green_candle_exp_inv_19                    0.164819
# green_candle_magnitude_pow_19                 0.716836
# red_candle_magnitude_pow_19                  -0.706978
# green_red_vector_pow_19                       1.000000
#
# [181 rows x 294 columns]

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)
print('done')
# Out:
# done

# %% [markdown]
# # Manual process for feature Selection

# %%
_reasonableCorelation.sort_values('open',ascending=False)
# Out:
#                             open      high       low     close  is_red_candle  \
# open                    1.000000  0.999541  0.999531  0.999298      -0.002075
# high                    0.999541  1.000000  0.999257  0.999678       0.012612
# low                     0.999531  0.999257  1.000000  0.999613       0.009335
# close                   0.999298  0.999678  0.999613  1.000000       0.020213
# green_red_vector_pow_2  0.901418  0.902617  0.900237  0.901416       0.107564
# green_red_vector_pow_4  0.888903  0.889730  0.888481  0.889054       0.055274
# green_red_vector_pow_6  0.815109  0.815847  0.815000  0.815328       0.040768
# green_red_vector_pow_8  0.736926  0.737623  0.736964  0.737163       0.034591
#
#                         is_green_candle  green_candle_magnitude  \
# open                           0.054314                0.261408
# high                           0.041403                0.276261
# low                            0.041136                0.272912
# close                          0.032113                0.283951
# green_red_vector_pow_2         0.144847                0.345561
# green_red_vector_pow_4         0.077779                0.299763
# green_red_vector_pow_6         0.053025                0.267969
# green_red_vector_pow_8         0.040035                0.241541
#
#                         red_candle_magnitude  green_red_vector  \
# open                                0.339642         -0.047212
# high                                0.326637         -0.032039
# low                                 0.326802         -0.033930
# close                               0.317606         -0.022912
# green_red_vector_pow_2              0.401818         -0.036341
# green_red_vector_pow_4              0.341519         -0.027630
# green_red_vector_pow_6              0.296858         -0.020035
# green_red_vector_pow_8              0.260788         -0.014304
#
#                         is_red_candle_exp_1  ...  is_red_candle_exp_inv_19  \
# open                              -0.002075  ...                  0.002075
# high                               0.012612  ...                 -0.012612
# low                                0.009335  ...                 -0.009335
# close                              0.020213  ...                 -0.020213
# green_red_vector_pow_2             0.107564  ...                 -0.107564
# green_red_vector_pow_4             0.055274  ...                 -0.055274
# green_red_vector_pow_6             0.040768  ...                 -0.040768
# green_red_vector_pow_8             0.034591  ...                 -0.034591
#
#                         is_green_candle_exp_inv_19  \
# open                                     -0.054314
# high                                     -0.041403
# low                                      -0.041136
# close                                    -0.032113
# green_red_vector_pow_2                   -0.144847
# green_red_vector_pow_4                   -0.077779
# green_red_vector_pow_6                   -0.053025
# green_red_vector_pow_8                   -0.040035
#
#                         green_candle_magnitude_exp_inv_19  \
# open                                             0.002075
# high                                            -0.012612
# low                                             -0.009335
# close                                           -0.020213
# green_red_vector_pow_2                          -0.107564
# green_red_vector_pow_4                          -0.055274
# green_red_vector_pow_6                          -0.040768
# green_red_vector_pow_8                          -0.034591
#
#                         red_candle_magnitude_exp_inv_19  \
# open                                          -0.054314
# high                                          -0.041403
# low                                           -0.041136
# close                                         -0.032113
# green_red_vector_pow_2                        -0.144847
# green_red_vector_pow_4                        -0.077779
# green_red_vector_pow_6                        -0.053025
# green_red_vector_pow_8                        -0.040035
#
#                         green_red_vector_exp_inv_19  is_red_candle_pow_19  \
# open                                            0.0             -0.002075
# high                                            0.0              0.012612
# low                                             0.0              0.009335
# close                                           0.0              0.020213
# green_red_vector_pow_2                          0.0              0.107564
# green_red_vector_pow_4                          0.0              0.055274
# green_red_vector_pow_6                          NaN              0.040768
# green_red_vector_pow_8                          NaN              0.034591
#
#                         is_green_candle_pow_19  green_candle_magnitude_pow_19  \
# open                                  0.054314                       0.277706
# high                                  0.041403                       0.281284
# low                                   0.041136                       0.280201
# close                                 0.032113                       0.282778
# green_red_vector_pow_2                0.144847                       0.319893
# green_red_vector_pow_4                0.077779                       0.421548
# green_red_vector_pow_6                0.053025                       0.499889
# green_red_vector_pow_8                0.040035                       0.562760
#
#                         red_candle_magnitude_pow_19  green_red_vector_pow_19
# open                                       0.307370                -0.017909
# high                                       0.304372                -0.013288
# low                                        0.304920                -0.014436
# close                                      0.302402                -0.010857
# green_red_vector_pow_2                     0.346610                -0.015433
# green_red_vector_pow_4                     0.453166                -0.017834
# green_red_vector_pow_6                     0.532577                -0.017797
# green_red_vector_pow_8                     0.593642                -0.015910
#
# [8 rows x 294 columns]
