# %%
dataName = 'adani'
dataFrequency = '1h'
featureIndexStamp = "011_"

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  
module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)
print('done')

from dataPreparation import *
from dataPreprocessing import *
from utilities import *

from dataPreparation.featurePreparation import doBasicOperation
from dataPreparation.featurePreparation import prepareFeatureWithData
from dataPreparation.resolveDataPatterns import getComplexDataPatternFeatures

_basicDf= doBasicOperation(dataName,dataFrequency)

print('done')
# Out:
# done
# into method doBasicOperation
#  retrieving values configured in >>> /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/config/config.json
# added INPUT FEATURES >>> 4 count >>> open-high-low-close
# before return statement of method doBasicOperation
# done

# %%
import pandas as pd
import numpy as np

featureOfInterest = 'getComplexDataPatternBasedFeatures'

m = _basicDf.shape[0]

newFeatureDf = getComplexDataPatternFeatures(_basicDf)
# Out:
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:482: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_red'][calcDf['open']>calcDf['close']]=1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_green'][calcDf['open']<calcDf['close']]=1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:488: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_doji'][calcDf['open']==calcDf['close']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:511: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prevGreen'][calcDf['prevClose']>calcDf['prevOpen']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:514: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prev2Green'][calcDf['prev2Close']>calcDf['prev2Open']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prev3Green'][calcDf['prev3Close']>calcDf['prev3Open']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:520: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prev4Green'][calcDf['prev4Close']>calcDf['prev4Open']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prevRed'][calcDf['prevClose']<calcDf['prevOpen']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prev2Red'][calcDf['prev2Close']<calcDf['prev2Open']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prev3Red'][calcDf['prev3Close']<calcDf['prev3Open']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:532: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prev4Red'][calcDf['prev4Close']<calcDf['prev4Open']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:535: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calcDf['is_prevDoji'][calcDf['prevClose']==calcDf['prevOpen']] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:549: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:561: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:578: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:595: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:608: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:620: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:633: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:644: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:655: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:686: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:696: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:713: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:729: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:742: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:761: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ]=1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:780: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ]=1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:791: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:802: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:820: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:831: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ]= 1
# /Users/493055/Desktop/dev/erai-v2.0/erai-v2.0/eraiVersion2/src/dataPreparation/resolveDataPatterns.py:838: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ] = 1

# %%
newFeatureDf['fallingWindow'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
newFeatureDf.corr()
# Out:
#                              open     close      high       low      test  \
# open                     1.000000  0.999298  0.999541  0.999531 -0.002663
# close                    0.999298  1.000000  0.999678  0.999613  0.006323
# high                     0.999541  0.999678  1.000000  0.999257  0.005110
# low                      0.999531  0.999613  0.999257  1.000000  0.001114
# test                    -0.002663  0.006323  0.005110  0.001114  1.000000
# risingWindow            -0.011355 -0.012887 -0.009771 -0.014708 -0.015001
# piercingLine            -0.008813 -0.006226 -0.006521 -0.008470 -0.013573
# tweezerBottoms          -0.037138 -0.035777 -0.036744 -0.035201 -0.026013
# tweezerTops             -0.050667 -0.051725 -0.052225 -0.050876 -0.024724
# threeWhiteSoldiers       0.009481  0.012971  0.012121  0.009857  0.193829
# threeBlackCrows         -0.017953 -0.020183 -0.018373 -0.019317 -0.017448
# onNeckline              -0.017305 -0.016968 -0.017629 -0.017009 -0.015776
# morningStar                   NaN       NaN       NaN       NaN       NaN
# morningDojiStar               NaN       NaN       NaN       NaN       NaN
# fallingWindow           -0.002713 -0.002409 -0.002566 -0.002720 -0.007428
# eveningStar                   NaN       NaN       NaN       NaN       NaN
# eveningDojiStar               NaN       NaN       NaN       NaN       NaN
# engulfingBullish         0.023021  0.027781  0.026866  0.024092 -0.023762
# engulfingBearishLine     0.034550  0.029444  0.032961  0.030521 -0.028751
# darkCloudOver            0.005782  0.004547  0.005395  0.004935 -0.012874
# bearishHarami            0.019114  0.018005  0.018313  0.018973 -0.018227
# bullishHarami            0.026773  0.027782  0.027128  0.027751 -0.017711
# bearishHaramiCross      -0.008140 -0.008114 -0.008347 -0.007832 -0.009099
# bullishHaramiCross      -0.011994 -0.011960 -0.012464 -0.011503 -0.011751
# bearish3MethodFormation  0.022997  0.022967  0.023609  0.023028 -0.003031
# bullish3MethodFormation -0.001443  0.002694  0.003366 -0.001279 -0.003031
#
#                          risingWindow  piercingLine  tweezerBottoms  \
# open                        -0.011355     -0.008813       -0.037138
# close                       -0.012887     -0.006226       -0.035777
# high                        -0.009771     -0.006521       -0.036744
# low                         -0.014708     -0.008470       -0.035201
# test                        -0.015001     -0.013573       -0.026013
# risingWindow                 1.000000     -0.011077       -0.015249
# piercingLine                -0.011077      1.000000       -0.004602
# tweezerBottoms              -0.015249     -0.004602        1.000000
# tweezerTops                 -0.020179     -0.004374       -0.008383
# threeWhiteSoldiers           0.019066     -0.002631       -0.005042
# threeBlackCrows              0.003510     -0.003086       -0.005916
# onNeckline                  -0.012876     -0.002791       -0.005349
# morningStar                       NaN           NaN             NaN
# morningDojiStar                   NaN           NaN             NaN
# fallingWindow               -0.006062     -0.001314       -0.002518
# eveningStar                       NaN           NaN             NaN
# eveningDojiStar                   NaN           NaN             NaN
# engulfingBullish            -0.019394      0.427340       -0.008056
# engulfingBearishLine         0.160897     -0.005086       -0.009748
# darkCloudOver                0.205598     -0.002277       -0.004365
# bearishHarami               -0.014876     -0.003224       -0.006180
# bullishHarami               -0.014455     -0.003133       -0.006005
# bearishHaramiCross          -0.007426     -0.001610       -0.003085
# bullishHaramiCross          -0.009590     -0.002079       -0.003984
# bearish3MethodFormation     -0.002474     -0.000536       -0.001028
# bullish3MethodFormation     -0.002474     -0.000536       -0.001028
#
#                          tweezerTops  threeWhiteSoldiers  ...  \
# open                       -0.050667            0.009481  ...
# close                      -0.051725            0.012971  ...
# high                       -0.052225            0.012121  ...
# low                        -0.050876            0.009857  ...
# test                       -0.024724            0.193829  ...
# risingWindow               -0.020179            0.019066  ...
# piercingLine               -0.004374           -0.002631  ...
# tweezerBottoms             -0.008383           -0.005042  ...
# tweezerTops                 1.000000           -0.004792  ...
# threeWhiteSoldiers         -0.004792            1.000000  ...
# threeBlackCrows            -0.005622           -0.003382  ...
# onNeckline                 -0.005084           -0.003058  ...
# morningStar                      NaN                 NaN  ...
# morningDojiStar                  NaN                 NaN  ...
# fallingWindow              -0.002394           -0.001440  ...
# eveningStar                      NaN                 NaN  ...
# eveningDojiStar                  NaN                 NaN  ...
# engulfingBullish           -0.007657           -0.004606  ...
# engulfingBearishLine       -0.009265           -0.005573  ...
# darkCloudOver              -0.004149           -0.002495  ...
# bearishHarami              -0.005874           -0.003533  ...
# bullishHarami              -0.005707           -0.003433  ...
# bearishHaramiCross         -0.002932           -0.001764  ...
# bullishHaramiCross         -0.003787           -0.002278  ...
# bearish3MethodFormation    -0.000977           -0.000588  ...
# bullish3MethodFormation    -0.000977           -0.000588  ...
#
#                          eveningDojiStar  engulfingBullish  \
# open                                 NaN          0.023021
# close                                NaN          0.027781
# high                                 NaN          0.026866
# low                                  NaN          0.024092
# test                                 NaN         -0.023762
# risingWindow                         NaN         -0.019394
# piercingLine                         NaN          0.427340
# tweezerBottoms                       NaN         -0.008056
# tweezerTops                          NaN         -0.007657
# threeWhiteSoldiers                   NaN         -0.004606
# threeBlackCrows                      NaN         -0.005404
# onNeckline                           NaN         -0.004886
# morningStar                          NaN               NaN
# morningDojiStar                      NaN               NaN
# fallingWindow                        NaN         -0.002300
# eveningStar                          NaN               NaN
# eveningDojiStar                      NaN               NaN
# engulfingBullish                     NaN          1.000000
# engulfingBearishLine                 NaN         -0.008904
# darkCloudOver                        NaN         -0.003987
# bearishHarami                        NaN         -0.005645
# bullishHarami                        NaN         -0.005485
# bearishHaramiCross                   NaN         -0.002818
# bullishHaramiCross                   NaN         -0.003639
# bearish3MethodFormation              NaN         -0.000939
# bullish3MethodFormation              NaN         -0.000939
#
#                          engulfingBearishLine  darkCloudOver  bearishHarami  \
# open                                 0.034550       0.005782       0.019114
# close                                0.029444       0.004547       0.018005
# high                                 0.032961       0.005395       0.018313
# low                                  0.030521       0.004935       0.018973
# test                                -0.028751      -0.012874      -0.018227
# risingWindow                         0.160897       0.205598      -0.014876
# piercingLine                        -0.005086      -0.002277      -0.003224
# tweezerBottoms                      -0.009748      -0.004365      -0.006180
# tweezerTops                         -0.009265      -0.004149      -0.005874
# threeWhiteSoldiers                  -0.005573      -0.002495      -0.003533
# threeBlackCrows                     -0.006538      -0.002928      -0.004145
# onNeckline                          -0.005912      -0.002647      -0.003748
# morningStar                               NaN            NaN            NaN
# morningDojiStar                           NaN            NaN            NaN
# fallingWindow                       -0.002783      -0.001246      -0.001765
# eveningStar                               NaN            NaN            NaN
# eveningDojiStar                           NaN            NaN            NaN
# engulfingBullish                    -0.008904      -0.003987      -0.005645
# engulfingBearishLine                 1.000000      -0.004824      -0.006830
# darkCloudOver                       -0.004824       1.000000      -0.003058
# bearishHarami                       -0.006830      -0.003058       1.000000
# bullishHarami                       -0.006637      -0.002972      -0.004208
# bearishHaramiCross                  -0.003410      -0.001527      -0.002162
# bullishHaramiCross                  -0.004403      -0.001972      -0.002792
# bearish3MethodFormation             -0.001136      -0.000509      -0.000720
# bullish3MethodFormation             -0.001136      -0.000509      -0.000720
#
#                          bullishHarami  bearishHaramiCross  \
# open                          0.026773           -0.008140
# close                         0.027782           -0.008114
# high                          0.027128           -0.008347
# low                           0.027751           -0.007832
# test                         -0.017711           -0.009099
# risingWindow                 -0.014455           -0.007426
# piercingLine                 -0.003133           -0.001610
# tweezerBottoms               -0.006005           -0.003085
# tweezerTops                  -0.005707           -0.002932
# threeWhiteSoldiers           -0.003433           -0.001764
# threeBlackCrows              -0.004028           -0.002069
# onNeckline                   -0.003642           -0.001871
# morningStar                        NaN                 NaN
# morningDojiStar                    NaN                 NaN
# fallingWindow                -0.001715           -0.000881
# eveningStar                        NaN                 NaN
# eveningDojiStar                    NaN                 NaN
# engulfingBullish             -0.005485           -0.002818
# engulfingBearishLine         -0.006637           -0.003410
# darkCloudOver                -0.002972           -0.001527
# bearishHarami                -0.004208           -0.002162
# bullishHarami                 1.000000           -0.002100
# bearishHaramiCross           -0.002100            1.000000
# bullishHaramiCross           -0.002713           -0.001393
# bearish3MethodFormation      -0.000700           -0.000359
# bullish3MethodFormation      -0.000700           -0.000359
#
#                          bullishHaramiCross  bearish3MethodFormation  \
# open                              -0.011994                 0.022997
# close                             -0.011960                 0.022967
# high                              -0.012464                 0.023609
# low                               -0.011503                 0.023028
# test                              -0.011751                -0.003031
# risingWindow                      -0.009590                -0.002474
# piercingLine                      -0.002079                -0.000536
# tweezerBottoms                    -0.003984                -0.001028
# tweezerTops                       -0.003787                -0.000977
# threeWhiteSoldiers                -0.002278                -0.000588
# threeBlackCrows                   -0.002672                -0.000689
# onNeckline                        -0.002416                -0.000623
# morningStar                             NaN                      NaN
# morningDojiStar                         NaN                      NaN
# fallingWindow                     -0.001138                -0.000293
# eveningStar                             NaN                      NaN
# eveningDojiStar                         NaN                      NaN
# engulfingBullish                  -0.003639                -0.000939
# engulfingBearishLine              -0.004403                -0.001136
# darkCloudOver                     -0.001972                -0.000509
# bearishHarami                     -0.002792                -0.000720
# bullishHarami                     -0.002713                -0.000700
# bearishHaramiCross                -0.001393                -0.000359
# bullishHaramiCross                 1.000000                -0.000464
# bearish3MethodFormation           -0.000464                 1.000000
# bullish3MethodFormation           -0.000464                -0.000120
#
#                          bullish3MethodFormation
# open                                   -0.001443
# close                                   0.002694
# high                                    0.003366
# low                                    -0.001279
# test                                   -0.003031
# risingWindow                           -0.002474
# piercingLine                           -0.000536
# tweezerBottoms                         -0.001028
# tweezerTops                            -0.000977
# threeWhiteSoldiers                     -0.000588
# threeBlackCrows                        -0.000689
# onNeckline                             -0.000623
# morningStar                                  NaN
# morningDojiStar                              NaN
# fallingWindow                          -0.000293
# eveningStar                                  NaN
# eveningDojiStar                              NaN
# engulfingBullish                       -0.000939
# engulfingBearishLine                   -0.001136
# darkCloudOver                          -0.000509
# bearishHarami                          -0.000720
# bullishHarami                          -0.000700
# bearishHaramiCross                     -0.000359
# bullishHaramiCross                     -0.000464
# bearish3MethodFormation                -0.000120
# bullish3MethodFormation                 1.000000
#
# [26 rows x 26 columns]

# %%
import pandas as pd
import numpy as np

featureOfInterest = 'hanging_man'

m = _basicDf.shape[0]

newFeatureDf = getComplexDataPatternFeatures(_basicDf)

_correlation, _reasonableCorelation, _newTrainingSetDf, _trainableFeaturesDf= prepareFeatureWithData(newFeatureDf,
            _basicDf,_variation_degree,_preProcessedDataFilePath,
            _configFilePath,requiredMinimumCorrelation,featureIndexStamp,
            dataName,dataFrequency,useVersion2=True)
# Out:
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:485: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_red'][calcDf['open']>calcDf['close']]=1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:488: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_green'][calcDf['open']<calcDf['close']]=1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_doji'][calcDf['open']==calcDf['close']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:514: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prevGreen'][calcDf['prevClose']>calcDf['prevOpen']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prev2Green'][calcDf['prev2Close']>calcDf['prev2Open']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:520: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prev3Green'][calcDf['prev3Close']>calcDf['prev3Open']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prev4Green'][calcDf['prev4Close']>calcDf['prev4Open']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:526: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prevRed'][calcDf['prevClose']<calcDf['prevOpen']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:529: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prev2Red'][calcDf['prev2Close']<calcDf['prev2Open']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:532: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prev3Red'][calcDf['prev3Close']<calcDf['prev3Open']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:535: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prev4Red'][calcDf['prev4Close']<calcDf['prev4Open']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   calcDf['is_prevDoji'][calcDf['prevClose']==calcDf['prevOpen']] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:552: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:564: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:581: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:598: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:611: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:623: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:647: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:658: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:674: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:689: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:699: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:716: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:764: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ]=1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:783: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ]=1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:794: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:805: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:823: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:834: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ]= 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\resolveDataPatterns.py:841: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ] = 1
# C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py:433: RuntimeWarning: divide by zero encountered in power
#   ] for iterator in range(1,variation_degree+1)]
# Error executing method >>>
# Traceback (most recent call last):
#   File "C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py", line 527, in prepareFeatureWithData
#     (np.abs(correlation['close'])>requiredMinimumCorrelation)]
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py", line 1500, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py", line 1900, in _getitem_axis
#     raise ValueError('Cannot index with multidimensional key')
# ValueError: Cannot index with multidimensional key
#
# Traceback (most recent call last):
#   File "C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py", line 527, in prepareFeatureWithData
# ValueError: [<FrameSummary file C:\Users\kalagi01\Desktop\dev\eraiVersion2\src\dataPreparation\featurePreparation.py, line 527 in prepareFeatureWithData>, <FrameSummary file C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py, line 1500 in __getitem__>, <FrameSummary file C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py, line 1900 in _getitem_axis>]

# %%
_correlation.shape
#_correlation.sort_values('open',ascending=True)
# Out:
# (881, 1512)

# %%
_reasonableCorelation.sort_values('open',ascending=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-a49171536bce> in <module>
# ----> 1 _reasonableCorelation.sort_values('open',ascending=True)
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
_reasonableCorelation.sort_values('open',ascending=False)

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(_reasonableCorelation)

# %%
_newTrainingSetDf.corr()
print('done')
# Out:
# done

# %%
_newTrainingSetDf.shape
# Out:
# (8350, 1512)

# %%
_newTrainingSetDf.to_csv()
