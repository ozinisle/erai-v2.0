# %% [markdown]
# # NOTE ::: THIS FEATURE SEEMS TO BE REDUNDANT - AVOIDING IT
#
# reduces performance of the model

# %%
dataName = 'adani'
dataFrequency = '1h'
requiredMinimumCorrelation = .2
autoConfigFileRelativePath = '\\src\config\\autoConfig\\config.json'
KEY_finalTrainingFeaturesListFile='finalTrainingFeaturesListFile'
KEY_manuallyDecidedTrainingFeaturesListFile='manuallyDecidedTrainingFeaturesListFile'
prefixFor_KEY_manuallyDecidedTrainingFeaturesListFile = '006'

TIME_STEPS_CONFIG=60
BATCH_SIZE_CONFIG = 512
LEARNING_RATE_CONFIG=0.001
EPOCHS_CONFIG = 40

print('done')
# Out:
# done

# %%
# Include python files defined in the library folder to help facilitate the stock price Prediction 
import os
import sys  

module_path = os.path.abspath('../../'+os.path.join('.'))

sys.path.append(module_path)

from utilities import *
from trainModel import *

print('done')
# Out:
# done

# %%
import pandas as pd
import numpy as np

from config.environment import getAppConfigData
from utilities.fileFolderManipulations import getJupyterRootDirectory

configFilePath = getJupyterRootDirectory()+'\\'+autoConfigFileRelativePath
autoConfigData = getAppConfigData()

trainingDataFilePath = autoConfigData[dataName][dataFrequency][KEY_manuallyDecidedTrainingFeaturesListFile]
trainingDataFilePath = trainingDataFilePath.replace('***',prefixFor_KEY_manuallyDecidedTrainingFeaturesListFile)

trainingDataFilePath.replace('.csv','_interim_3.csv')

print('trainingDataFilePath is >>> ' + trainingDataFilePath)

trainingDataDf = pd.read_csv(trainingDataFilePath)

try:
    trainingDataDf=trainingDataDf.drop(columns={'Unnamed: 0'})
except KeyError:
    pass


trainingDataDf.head()
# Out:
#  retrieving values configured in >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\\src\config\autoConfig\config.json
# trainingDataFilePath is >>> C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\manuallyDecidedFeatures\006_manuallyDecidedFinalTrainingFeatureList.csv
#     open   high    low  close  open_high_diff_exp_1  open_low_diff_exp_inv_1  \
# 0  52.50  52.70  51.30  51.65              0.818731                 0.301194
# 1  51.70  52.30  51.70  51.85              0.548812                 1.000000
# 2  51.85  52.10  51.75  51.95              0.778801                 0.904837
# 3  51.90  52.15  51.90  52.05              0.778801                 1.000000
# 4  52.10  52.20  51.85  51.90              0.904837                 0.778801
#
#    close_low_diff_exp_inv_2  close_high_diff_exp_1  high_low_diff_exp_inv_2  \
# 0                  0.496585               0.349938                 0.060810
# 1                  0.740818               0.637628                 0.301194
# 2                  0.670320               0.860708                 0.496585
# 3                  0.740818               0.904837                 0.606531
# 4                  0.904837               0.740818                 0.496585
#
#    data_magnitude  green_red_vector_pow_2  red_candle_magnitude_pow_4  \
# 0       26.020368              677.059531                 458409.6089
# 1       25.944041              673.093281                      0.0000
# 2       25.956331              673.731094                      0.0000
# 3       26.000054              676.002813                      0.0000
# 4       26.006348              676.330156                 457422.4803
#
#    green_candle_magnitude_pow_4  redCandlesBySizeTimesMagnitude_pow_3
# 0                        0.0000                          -2202167.238
# 1                   453054.5653                                 0.000
# 2                   453913.5867                                 0.000
# 3                   456979.8025                                 0.000
# 4                        0.0000                           -474899.697

# %%
trainingDataDf.corr()
# Out:
#                                           open      high       low     close  \
# open                                  1.000000  0.999541  0.999531  0.999298
# high                                  0.999541  1.000000  0.999257  0.999678
# low                                   0.999531  0.999257  1.000000  0.999613
# close                                 0.999298  0.999678  0.999613  1.000000
# open_high_diff_exp_1                 -0.266702 -0.293119 -0.273983 -0.291301
# open_low_diff_exp_inv_1              -0.301008 -0.293140 -0.275037 -0.277944
# close_low_diff_exp_inv_2             -0.290095 -0.307125 -0.285133 -0.307312
# close_high_diff_exp_1                -0.363132 -0.366613 -0.344964 -0.345216
# high_low_diff_exp_inv_2              -0.453788 -0.466815 -0.440574 -0.454519
# data_magnitude                        0.999786  0.999819  0.999785  0.999840
# green_red_vector_pow_2                0.901418  0.902617  0.900237  0.901416
# red_candle_magnitude_pow_4            0.601855  0.593542  0.594226  0.587961
# green_candle_magnitude_pow_4          0.536609  0.546420  0.544062  0.551389
# redCandlesBySizeTimesMagnitude_pow_3 -0.464503 -0.457274 -0.450526 -0.446462
#
#                                       open_high_diff_exp_1  \
# open                                             -0.266702
# high                                             -0.293119
# low                                              -0.273983
# close                                            -0.291301
# open_high_diff_exp_1                              1.000000
# open_low_diff_exp_inv_1                          -0.230885
# close_low_diff_exp_inv_2                          0.661281
# close_high_diff_exp_1                             0.186521
# high_low_diff_exp_inv_2                           0.585127
# data_magnitude                                   -0.281468
# green_red_vector_pow_2                           -0.290342
# red_candle_magnitude_pow_4                        0.127356
# green_candle_magnitude_pow_4                     -0.492448
# redCandlesBySizeTimesMagnitude_pow_3             -0.139069
#
#                                       open_low_diff_exp_inv_1  \
# open                                                -0.301008
# high                                                -0.293140
# low                                                 -0.275037
# close                                               -0.277944
# open_high_diff_exp_1                                -0.230885
# open_low_diff_exp_inv_1                              1.000000
# close_low_diff_exp_inv_2                             0.208128
# close_high_diff_exp_1                                0.686746
# high_low_diff_exp_inv_2                              0.595424
# data_magnitude                                      -0.286970
# green_red_vector_pow_2                              -0.301783
# red_candle_magnitude_pow_4                          -0.456687
# green_candle_magnitude_pow_4                         0.124003
# redCandlesBySizeTimesMagnitude_pow_3                 0.594171
#
#                                       close_low_diff_exp_inv_2  \
# open                                                 -0.290095
# high                                                 -0.307125
# low                                                  -0.285133
# close                                                -0.307312
# open_high_diff_exp_1                                  0.661281
# open_low_diff_exp_inv_1                               0.208128
# close_low_diff_exp_inv_2                              1.000000
# close_high_diff_exp_1                                 0.061976
# high_low_diff_exp_inv_2                               0.694446
# data_magnitude                                       -0.297630
# green_red_vector_pow_2                               -0.311785
# red_candle_magnitude_pow_4                            0.055135
# green_candle_magnitude_pow_4                         -0.425764
# redCandlesBySizeTimesMagnitude_pow_3                 -0.013714
#
#                                       close_high_diff_exp_1  \
# open                                              -0.363132
# high                                              -0.366613
# low                                               -0.344964
# close                                             -0.345216
# open_high_diff_exp_1                               0.186521
# open_low_diff_exp_inv_1                            0.686746
# close_low_diff_exp_inv_2                           0.061976
# close_high_diff_exp_1                              1.000000
# high_low_diff_exp_inv_2                            0.693611
# data_magnitude                                    -0.355214
# green_red_vector_pow_2                            -0.371577
# red_candle_magnitude_pow_4                        -0.439237
# green_candle_magnitude_pow_4                       0.011834
# redCandlesBySizeTimesMagnitude_pow_3               0.569475
#
#                                       high_low_diff_exp_inv_2  data_magnitude  \
# open                                                -0.453788        0.999786
# high                                                -0.466815        0.999819
# low                                                 -0.440574        0.999785
# close                                               -0.454519        0.999840
# open_high_diff_exp_1                                 0.585127       -0.281468
# open_low_diff_exp_inv_1                              0.595424       -0.286970
# close_low_diff_exp_inv_2                             0.694446       -0.297630
# close_high_diff_exp_1                                0.693611       -0.355214
# high_low_diff_exp_inv_2                              1.000000       -0.454184
# data_magnitude                                      -0.454184        1.000000
# green_red_vector_pow_2                              -0.479960        0.901609
# red_candle_magnitude_pow_4                          -0.268461        0.594504
# green_candle_magnitude_pow_4                        -0.280188        0.544738
# redCandlesBySizeTimesMagnitude_pow_3                 0.361360       -0.454823
#
#                                       green_red_vector_pow_2  \
# open                                                0.901418
# high                                                0.902617
# low                                                 0.900237
# close                                               0.901416
# open_high_diff_exp_1                               -0.290342
# open_low_diff_exp_inv_1                            -0.301783
# close_low_diff_exp_inv_2                           -0.311785
# close_high_diff_exp_1                              -0.371577
# high_low_diff_exp_inv_2                            -0.479960
# data_magnitude                                      0.901609
# green_red_vector_pow_2                              1.000000
# red_candle_magnitude_pow_4                          0.634888
# green_candle_magnitude_pow_4                        0.584610
# redCandlesBySizeTimesMagnitude_pow_3               -0.485688
#
#                                       red_candle_magnitude_pow_4  \
# open                                                    0.601855
# high                                                    0.593542
# low                                                     0.594226
# close                                                   0.587961
# open_high_diff_exp_1                                    0.127356
# open_low_diff_exp_inv_1                                -0.456687
# close_low_diff_exp_inv_2                                0.055135
# close_high_diff_exp_1                                  -0.439237
# high_low_diff_exp_inv_2                                -0.268461
# data_magnitude                                          0.594504
# green_red_vector_pow_2                                  0.634888
# red_candle_magnitude_pow_4                              1.000000
# green_candle_magnitude_pow_4                           -0.178253
# redCandlesBySizeTimesMagnitude_pow_3                   -0.766268
#
#                                       green_candle_magnitude_pow_4  \
# open                                                      0.536609
# high                                                      0.546420
# low                                                       0.544062
# close                                                     0.551389
# open_high_diff_exp_1                                     -0.492448
# open_low_diff_exp_inv_1                                   0.124003
# close_low_diff_exp_inv_2                                 -0.425764
# close_high_diff_exp_1                                     0.011834
# high_low_diff_exp_inv_2                                  -0.280188
# data_magnitude                                            0.544738
# green_red_vector_pow_2                                    0.584610
# red_candle_magnitude_pow_4                               -0.178253
# green_candle_magnitude_pow_4                              1.000000
# redCandlesBySizeTimesMagnitude_pow_3                      0.141609
#
#                                       redCandlesBySizeTimesMagnitude_pow_3
# open                                                             -0.464503
# high                                                             -0.457274
# low                                                              -0.450526
# close                                                            -0.446462
# open_high_diff_exp_1                                             -0.139069
# open_low_diff_exp_inv_1                                           0.594171
# close_low_diff_exp_inv_2                                         -0.013714
# close_high_diff_exp_1                                             0.569475
# high_low_diff_exp_inv_2                                           0.361360
# data_magnitude                                                   -0.454823
# green_red_vector_pow_2                                           -0.485688
# red_candle_magnitude_pow_4                                       -0.766268
# green_candle_magnitude_pow_4                                      0.141609
# redCandlesBySizeTimesMagnitude_pow_3                              1.000000

# %%
from utilities.dataVisuvalization import displayHeatMap
displayHeatMap(trainingDataDf.corr())
print('done')
# Out:
# done

# %%
numberOfInputFeatures = trainingDataDf.shape[1]
numberOfOutputFeatures = 4

numberOfInputFeatures,numberOfOutputFeatures
# Out:
# (14, 4)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(trainingDataDf["open"])
plt.plot(trainingDataDf["high"])
plt.plot(trainingDataDf["low"])
plt.plot(trainingDataDf["close"])
plt.title('Stock price history')
plt.ylabel('Price (Rupees)')
plt.xlabel('Days')
plt.legend(['open','high','low','close'], loc='upper left')
plt.show()
print('done')
# Out:
# done

# %%
from trainModel.trainModel import trainLSTMModel
success, trainingData, min_max_scaler, x_t, y_t,x_test_t, y_test_t, lstm_model, history = trainLSTMModel(trainingDataFilePath, TIME_STEPS_CONFIG, BATCH_SIZE_CONFIG , LEARNING_RATE_CONFIG, EPOCHS_CONFIG)
print('isSuccess >>> ' + str(success))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0110 22:11:19.945848 10780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0110 22:11:19.987529 10780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0110 22:11:19.995528 10780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# checking if any null values are present
#  open                                    0
# high                                    0
# low                                     0
# close                                   0
# open_high_diff_exp_1                    0
# open_low_diff_exp_inv_1                 0
# close_low_diff_exp_inv_2                0
# close_high_diff_exp_1                   0
# high_low_diff_exp_inv_2                 0
# data_magnitude                          0
# green_red_vector_pow_2                  0
# red_candle_magnitude_pow_4              0
# green_candle_magnitude_pow_4            0
# redCandlesBySizeTimesMagnitude_pow_3    0
# dtype: int64
# Train and Test size 5010 3340
# length of time-series i/o (4950, 60, 14) (4950, 4)
# length of time-series i/o (3280, 60, 14) (3280, 4)
# W0110 22:11:20.360553 10780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\manuallyDecidedFeatures/logs
# W0110 22:11:20.579600 10780 deprecation.py:323] From C:\Users\kalagi01\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0110 22:11:21.085986 10780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0110 22:11:21.095988 10780 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Train on 4608 samples, validate on 1536 samples
# Epoch 1/40
#  - 2s - loss: 0.0516 - acc: 0.1152 - val_loss: 0.0646 - val_acc: 0.0430
# Epoch 2/40
#  - 1s - loss: 0.0368 - acc: 0.6066 - val_loss: 0.0588 - val_acc: 0.4870
# Epoch 3/40
#  - 1s - loss: 0.0349 - acc: 0.6647 - val_loss: 0.0565 - val_acc: 0.4870
# Epoch 4/40
#  - 1s - loss: 0.0339 - acc: 0.6163 - val_loss: 0.0548 - val_acc: 0.4870
# Epoch 5/40
#  - 1s - loss: 0.0326 - acc: 0.6163 - val_loss: 0.0532 - val_acc: 0.4870
# Epoch 6/40
#  - 1s - loss: 0.0317 - acc: 0.6146 - val_loss: 0.0514 - val_acc: 0.4870
# Epoch 7/40
#  - 1s - loss: 0.0305 - acc: 0.5579 - val_loss: 0.0495 - val_acc: 0.4870
# Epoch 8/40
#  - 1s - loss: 0.0295 - acc: 0.6172 - val_loss: 0.0471 - val_acc: 0.4896
# Epoch 9/40
#  - 1s - loss: 0.0274 - acc: 0.6161 - val_loss: 0.0440 - val_acc: 0.4896
# Epoch 10/40
#  - 1s - loss: 0.0252 - acc: 0.6174 - val_loss: 0.0403 - val_acc: 0.4876
# Epoch 11/40
#  - 1s - loss: 0.0226 - acc: 0.4824 - val_loss: 0.0356 - val_acc: 0.4805
# Epoch 12/40
#  - 1s - loss: 0.0190 - acc: 0.6148 - val_loss: 0.0298 - val_acc: 0.4792
# Epoch 13/40
#  - 1s - loss: 0.0149 - acc: 0.5877 - val_loss: 0.0241 - val_acc: 0.4668
# Epoch 14/40
#  - 1s - loss: 0.0113 - acc: 0.5343 - val_loss: 0.0193 - val_acc: 0.4518
# Epoch 15/40
#  - 1s - loss: 0.0089 - acc: 0.5645 - val_loss: 0.0164 - val_acc: 0.4479
# Epoch 16/40
#  - 1s - loss: 0.0077 - acc: 0.5145 - val_loss: 0.0156 - val_acc: 0.4473
# Epoch 17/40
#  - 1s - loss: 0.0071 - acc: 0.5621 - val_loss: 0.0149 - val_acc: 0.4505
# Epoch 18/40
#  - 1s - loss: 0.0064 - acc: 0.5510 - val_loss: 0.0142 - val_acc: 0.4512
# Epoch 19/40
#  - 1s - loss: 0.0057 - acc: 0.5629 - val_loss: 0.0136 - val_acc: 0.4577
# Epoch 20/40
#  - 1s - loss: 0.0052 - acc: 0.5629 - val_loss: 0.0131 - val_acc: 0.4583
# Epoch 21/40
#  - 1s - loss: 0.0047 - acc: 0.5792 - val_loss: 0.0126 - val_acc: 0.4421
# Epoch 22/40
#  - 1s - loss: 0.0042 - acc: 0.5564 - val_loss: 0.0121 - val_acc: 0.4056
# Epoch 23/40
#  - 1s - loss: 0.0038 - acc: 0.5768 - val_loss: 0.0118 - val_acc: 0.3750
# Epoch 24/40
#  - 1s - loss: 0.0035 - acc: 0.5143 - val_loss: 0.0114 - val_acc: 0.3522
# Epoch 25/40
#  - 1s - loss: 0.0033 - acc: 0.5273 - val_loss: 0.0111 - val_acc: 0.3203
# Epoch 26/40
#  - 1s - loss: 0.0031 - acc: 0.5271 - val_loss: 0.0106 - val_acc: 0.3203
# Epoch 27/40
#  - 1s - loss: 0.0030 - acc: 0.5280 - val_loss: 0.0101 - val_acc: 0.3340
# Epoch 28/40
#  - 1s - loss: 0.0028 - acc: 0.5213 - val_loss: 0.0096 - val_acc: 0.3639
# Epoch 29/40
#  - 1s - loss: 0.0028 - acc: 0.5295 - val_loss: 0.0093 - val_acc: 0.3822
# Epoch 30/40
#  - 1s - loss: 0.0026 - acc: 0.5328 - val_loss: 0.0086 - val_acc: 0.3900
# Epoch 31/40
#  - 1s - loss: 0.0026 - acc: 0.5534 - val_loss: 0.0084 - val_acc: 0.4375
# Epoch 32/40
#  - 1s - loss: 0.0023 - acc: 0.5250 - val_loss: 0.0075 - val_acc: 0.4518
# Epoch 33/40
#  - 1s - loss: 0.0025 - acc: 0.5612 - val_loss: 0.0078 - val_acc: 0.4219
# Epoch 34/40
#  - 1s - loss: 0.0021 - acc: 0.5182 - val_loss: 0.0062 - val_acc: 0.4609
# Epoch 35/40
#  - 1s - loss: 0.0027 - acc: 0.5664 - val_loss: 0.0071 - val_acc: 0.4329
# Epoch 36/40
#  - 1s - loss: 0.0019 - acc: 0.5106 - val_loss: 0.0056 - val_acc: 0.4551
# Epoch 37/40
#  - 1s - loss: 0.0026 - acc: 0.5734 - val_loss: 0.0066 - val_acc: 0.4375
# Epoch 38/40
#  - 1s - loss: 0.0018 - acc: 0.5139 - val_loss: 0.0053 - val_acc: 0.4551
# Epoch 39/40
#  - 1s - loss: 0.0025 - acc: 0.5764 - val_loss: 0.0061 - val_acc: 0.4434
# Epoch 40/40
#  - 1s - loss: 0.0018 - acc: 0.5241 - val_loss: 0.0050 - val_acc: 0.4707
# isSuccess >>> True

# %%
predicted_values = lstm_model.predict(x_test_t, batch_size=512)
predicted_values.shape
# Out:
# (1536, 4)

# %%
dummy_cols_data = np.random.random((predicted_values.shape[0],numberOfInputFeatures-numberOfOutputFeatures))
predicted_values_adj = np.append(predicted_values, dummy_cols_data, 1)
predicted_values_orig_scale_withDummies=min_max_scaler.inverse_transform(predicted_values_adj)

y_test_t_adj = np.append(y_test_t, dummy_cols_data, 1)
y_test_t_orig_scale_withDummies=min_max_scaler.inverse_transform(y_test_t_adj)
print('done')
# Out:
# done

# %%
predicted_values_orig_scale= predicted_values_orig_scale_withDummies[:, [i+1 for i in range(numberOfOutputFeatures)]] #[1,2,3,4]
y_test_t_orig_scale= y_test_t_orig_scale_withDummies[:, [i+1 for i in range(numberOfOutputFeatures)]] #[1,2,3,4]
predicted_values_orig_scale.shape
# Out:
# (1536, 4)

# %%
plt.figure(figsize=(16,9))
plt.clf()
predicted_open = predicted_values_orig_scale[:,[0]]
actual_open = y_test_t_orig_scale[:,[0]]

x_coord = [ index for index in range(predicted_values_orig_scale.shape[0]) ]

plt.plot(x_coord, predicted_open, 'g', label='Predicted Open')
plt.plot(x_coord, actual_open, 'y', label='Actual Open')
plt.title('Open -> Predicted vs Actual')
plt.xlabel('Range')
plt.ylabel('Open Price')
plt.legend()
plt.show()

# %% [markdown]
# # Save trained model for future use

# %%
import pickle
from utilities.fileFolderManipulations import getParentFolder
from utilities.fileFolderManipulations import createFolder

modelFolderPath=getParentFolder(trainingDataFilePath)+"\model"
modelFilePath = modelFolderPath+"\lstm_model_for_"+trainingDataFilePath[trainingDataFilePath.rfind('\\')+1:trainingDataFilePath.rfind('.csv')]+".sav"
createFolder(modelFolderPath)

pickle.dump(lstm_model, open(modelFilePath, 'wb'))
print('done')
# Out:
#  checking if folder existis >>>C:\Users\kalagi01\Desktop\dev\eraiVersion2\data\adani\processed\1h\features\manuallyDecidedFeatures\model
# done

# %% [markdown]
# # Load Model from disk

# %%
import pickle
lstm_model_loaded = pickle.load(open(modelFilePath, 'rb'))
result = lstm_model_loaded.evaluate(x_t, y_t, batch_size=512)
actual = lstm_model.evaluate(x_t, y_t, batch_size=512)
print('done')
actual, result
# Out:
# 4608/4608 [==============================] - 0s 81us/step
# 4608/4608 [==============================] - 0s 53us/step
# done
# ([0.0013116354885925022, 0.6236979166666666],
#  [0.0013116498206121225, 0.6236979166666666])
